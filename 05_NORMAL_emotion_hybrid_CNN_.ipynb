# %% [markdown]
# # Classification of emotion intensity - NORMAL

# %% [markdown]
# A parallel CNN - Transformer pytorch deep learning model is developed for audio emotion classification.
#
# Designed a five layer 2D CNN parallel to 2 layer transformer model.

# %%
# loading - data processing and visualization packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sn

import warnings
warnings.filterwarnings("ignore")

# %%
# loading deep learning Pytorch and librosa audio library
import torch
import torchaudio
import torch.nn as nn
import librosa
import librosa.display
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from torchsummary import summary

# %%
# Read the saved label data from CSV file to data frame
signal_data = pd.read_csv('data_normal.csv')
signal_data.head()
# Out:
#                                           Path  Emotion  Emotion_intensity  \
# 0  ./archive/Actor_01/03-01-01-01-01-01-01.wav        1                  1
# 1  ./archive/Actor_01/03-01-01-01-01-02-01.wav        1                  1
# 2  ./archive/Actor_01/03-01-01-01-02-01-01.wav        1                  1
# 3  ./archive/Actor_01/03-01-01-01-02-02-01.wav        1                  1
# 4  ./archive/Actor_01/03-01-02-01-01-01-01.wav        2                  1
#
#   Gender
# 0   male
# 1   male
# 2   male
# 3   male
# 4   male

# %%
signal_data['Emotion'].value_counts()  # value count of each emotion lables are returned
# Out:
# 0    96
# 1    96
# 2    96
# 3    96
# 4    96
# 5    96
# 6    96
# 7    96
# Name: Emotion, dtype: int64

# %%
import seaborn as sns  # for visualization
sns.countplot(x ='Emotion', data = signal_data)  # Count plot for each emotions using seaborn library
# Out:
# <AxesSubplot:xlabel='Emotion', ylabel='count'>

# %%
# assiging the sample rate to a variable that find out using librosa
sample_rate = 48000

# funtion that return the extracted features
def extract_features(waveforms, features, samplerate):

    # counter to track file processing
    file_count = 0
    #wave_lenght = len(waveforms)
    # process each waveform individually to get its mel-spectrogram data
    for waveform in waveforms:
        mel_spec = extract_melspectrogram(waveform, sample_rate)
        features.append(mel_spec)
        file_count += 1
        
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
        
    
    # return all features from list of waveforms
    return features

# funtion to extrac audio in signal format
def load_waveforms(file):
    # read the full 3 seconds of the file, cut off the first 0.5s of silence
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # making each vectors homogenious in nature
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return file's waveform                                      
    return waveform_homo

# function to compute mel spectrogram values corresponding to each audio signal.
def extract_melspectrogram(audio, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# %%
# extracting and storing each wave form vector
waveforms  = []
# counter to track file processing
file_count = 0
for file in signal_data.Path:
    waveform = load_waveforms(file)
    waveforms.append(waveform)
    file_count += 1
    print('\r'+f' Processed {file_count}/{len(signal_data)} waveforms',end='')
    
# verify the wave form stored
print('\n')
print(len(waveforms))
print(len(waveforms[0]))
print(type(waveforms))
# Out:
#  Processed 768/768 waveforms
#
# 768
# 144000
# <class 'list'>

# %%
# convert the list into numpy multi-dimentional array for test train split.
# convert waveforms to array for processing
signals = np.stack(waveforms,axis=0)
print(signals.ndim)
print(signals.shape)
print(type(signals))
# Out:
# 2
# (768, 144000)
# <class 'numpy.ndarray'>

# %% [markdown]
# # ===========================================================

# %%
# Create a dictionary and set surprised = 0 insted of 8  for PyTorch
EMOTIONS ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# %%
# initialize empty list for train, validation, test sets and their indices
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]

# %%
# process each emotion separately to make sure we builf balanced train/valid/test sets
for emotion in range(len(EMOTIONS)):
    # Extract and store all indices corrsponding to individual emotion seperately - ie one emotion per iteration
    emotion_ind = list(signal_data.loc[signal_data.Emotion==emotion,'Emotion'].index)
    # seed and shuffle indicies 
    emotion_ind = np.random.permutation(emotion_ind)
    # Assign length of the emotion list to make indices
    m = len(emotion_ind)
    
    # store indices of training, validation and test sets in 80/10/10 proportion - train set is first 80%
    ind_train = emotion_ind[:int(0.8*m)]
    # validation set is next 10% (between 80% and 90%)
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    # test set is last 10% (between 90% - end/100%)
    ind_test = emotion_ind[int(0.9*m):]
    
     # create train waveforms/labels sets
    X_train.append(signals[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    # create validation waveforms/labels sets
    X_val.append(signals[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(signals[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    
    # store indices for each emotion set to verify uniqueness between sets
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
    
# concatenate, in order, all waveforms back into one array     
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)

# print shape of each set
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# X_train:(608, 144000), Y_train:(608,)
# X_val:(80, 144000), Y_val:(80,)
# X_test:(80, 144000), Y_test:(80,)

# %% [markdown]
# ## Feature Extraction

# %%
# initialize feature arrays
# Extract Mel-spectrogram features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = extract_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = extract_features(X_val, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = extract_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (Mel-Spectrogram matrix) shape: {len(features_train[0])} x {len(features_train[0][1])}')
# Out:
# Train waveforms:
#  Processed 608/608 waveforms
#
# Validation waveforms:
#  Processed 80/80 waveforms
#
# Test waveforms:
#  Processed 80/80 waveforms
#
# Features set: 768 total, 608 train, 80 validation, 80 test samples
# Features (Mel-Spectrogram matrix) shape: 128 x 563

# %%
# Convert each list into numpy array for pytorch and stored them in corresponding train arrays
features_train = np.stack(features_train,axis=0)
features_valid = np.stack(features_valid,axis=0)
features_test = np.stack(features_test,axis=0)

# %%
print(type(features_train))
print(len(features_train))
# Out:
# <class 'numpy.ndarray'>
# 608

# %%
"""
Here we have 1 signal intensity channel, because we are using gray scale signal representation,
to feed the data in to a 2D convolutional network in pytorch we need to define a 4D Tensor Array
We need an input channel dim to expand to output channels using CNN filters. 
We create a dummy channel dim ie 1 to expand features into 2D-CNN-ready 4D tensor format: N x C x H x W.
"""

# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_val = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(Y_train)
y_val = np.array(Y_val)
y_test = np.array(Y_test)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
#Print (batch, channel, width, height)
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_val:{X_val.shape}, y_val:{y_val.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(608, 1, 128, 563), y_train:(608,)
# X_val:(80, 1, 128, 563), y_val:(80,)
# X_test:(80, 1, 128, 563), y_test:(80,)

# %% [markdown]
# ## Model Definition

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.conv2Dblock = nn.Sequential(
            # First convolutional layer   (input : 1x128x563)
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # First convolutional pooling layer
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # Second convolutional layer  (input : 16x64x281)
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # Second convolutional pooling layer
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # Third convolutional layer  (input : 32x32x140)
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # Third convolutional pooling layer
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # Fourth convolutional layer  (input : 64x16x70)
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # Fourth convolutional pooling layer 
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # Fifth convolutional layer  (input : 64x4x17)
            nn.Conv2d(in_channels=64,
                       out_channels=128,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # Fifth convolutional pooling layer  
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        """
        input in to the Linear block from CNN model (128x1x4 = 512, number of emotions = 8)
        Each full convolution block outputs (128*1*4) embedding flattened to dim 512 1D array
        """
        # Parallel Transformer implementation
        """
        First convert the input tensor 128 x 563 into 128 x 140  ie (128 x 563 ==> 128 x 140)
        using maxpooling with 1x4 rectangular kernal
        """
        self.transformer_maxpool = nn.MaxPool2d(kernel_size=[1,4], stride=[1,4])
        """
        Define a multi-head transformer encoder function with self attension mechanism.
        4 parallel self attention encoders are defined and feed forward networ is defined for all 4 self attention lays.
        intput to output is mapped using d-model and dim_feedforward varaibles.
        Its create 4 multi-head self-attention layers each with 40-->512--->40 feedforward network
        """
        transformer_enc = nn.TransformerEncoderLayer(d_model=128, nhead=4, dim_feedforward=512, dropout=0.4, activation='relu')
        # initialize the fransformer encoder function
        self.transformer_encoder = nn.TransformerEncoder(transformer_enc, num_layers=4)
        
        
        # Linear softmax layer will take final signal embedded tensor
        # That is 512 output features from CNN and 128 output features from transformer encoder
        self.out_linear = nn.Linear(640,8)
        self.dropout_linear = nn.Dropout(p=0)
        # Softmax layer for the 8 output logits from final fully connected linear layer 
        self.out_softmax = nn.Softmax(dim=1)
    def forward(self,x):
        # forward pass of input feature tensor
        # create final feature embedding from 2D convolutional sequence block 
        # input features pased through 4 sequential 2D convolutional layers
        signal_embedding = self.conv2Dblock(x)
        
        # flatten final 64*1*4 feature map from convolutional layers to length 256 1D array 
        # skip the 1st minibatch dimension when flattening ie start_dim=1
        conv_embedding = torch.flatten(signal_embedding, start_dim=1)
        
        # transformer embedding
        # Call transformer_maxpool for change the tensor shape using 1x4 kernal
        x_reduced = self.transformer_maxpool(x)
        # remove channel dim: 1*128*140 --> 128*140
        x_reduced = torch.squeeze(x_reduced,1)
        # Change maxpooled feature map format from - batch x freq x time ==> time x batch x freq format
        x_reduced = x_reduced.permute(2,0,1) 
        # call transformer encoder function and pass the converted feature map as parameter
        transformer_out = self.transformer_encoder(x_reduced)
        # calculate and assign mean in the time dimension from rearranged dimension
        transformer_embedding = torch.mean(transformer_out, dim=0)
        # concatenate
        complete_embedding = torch.cat([conv_embedding, transformer_embedding], dim=1) 
        
        # final fully connected linear layer, need logits for loss calculation
        output_logits = self.out_linear(complete_embedding)
        output_logits = self.dropout_linear(output_logits)
        
        # final Softmax layer for prediction
        output_softmax = self.out_softmax(output_logits)
        
        return output_logits, output_softmax

# %%
"""
Checking the model architectue based on temporary defined optimizer and loss fuction
"""
# instantiate the model
model = ConvNet()
# defining the optimizer
optimizer = Adam(model.parameters(), lr=0.01)
# defining the loss function
criterion = CrossEntropyLoss()
# checking if GPU is available
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()
    
print(model)
# Out:
# ConvNet(
#   (conv2Dblock): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.3, inplace=False)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.3, inplace=False)
#     (10): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.3, inplace=False)
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (19): Dropout(p=0.3, inplace=False)
#     (20): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (22): ReLU()
#     (23): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (24): Dropout(p=0.3, inplace=False)
#   )
#   (transformer_maxpool): MaxPool2d(kernel_size=[1, 4], stride=[1, 4], padding=0, dilation=1, ceil_mode=False)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=512, bias=True)
#         (dropout): Dropout(p=0.4, inplace=False)
#         (linear2): Linear(in_features=512, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.4, inplace=False)
#         (dropout2): Dropout(p=0.4, inplace=False)
#       )
#     )
#   )
#   (out_linear): Linear(in_features=640, out_features=8, bias=True)
#   (dropout_linear): Dropout(p=0, inplace=False)
#   (out_softmax): Softmax(dim=1)
# )

# %%
# model summary based on input feature shape.
summary(model, input_size=(1,128,563))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 128, 563]             160
#        BatchNorm2d-2         [-1, 16, 128, 563]              32
#               ReLU-3         [-1, 16, 128, 563]               0
#          MaxPool2d-4          [-1, 16, 64, 281]               0
#            Dropout-5          [-1, 16, 64, 281]               0
#             Conv2d-6          [-1, 32, 64, 281]           4,640
#        BatchNorm2d-7          [-1, 32, 64, 281]              64
#               ReLU-8          [-1, 32, 64, 281]               0
#          MaxPool2d-9          [-1, 32, 32, 140]               0
#           Dropout-10          [-1, 32, 32, 140]               0
#            Conv2d-11          [-1, 64, 32, 140]          18,496
#       BatchNorm2d-12          [-1, 64, 32, 140]             128
#              ReLU-13          [-1, 64, 32, 140]               0
#         MaxPool2d-14           [-1, 64, 16, 70]               0
#           Dropout-15           [-1, 64, 16, 70]               0
#            Conv2d-16           [-1, 64, 16, 70]          36,928
#       BatchNorm2d-17           [-1, 64, 16, 70]             128
#              ReLU-18           [-1, 64, 16, 70]               0
#         MaxPool2d-19            [-1, 64, 4, 17]               0
#           Dropout-20            [-1, 64, 4, 17]               0
#            Conv2d-21           [-1, 128, 4, 17]          73,856
#       BatchNorm2d-22           [-1, 128, 4, 17]             256
#              ReLU-23           [-1, 128, 4, 17]               0
#         MaxPool2d-24            [-1, 128, 1, 4]               0
#           Dropout-25            [-1, 128, 1, 4]               0
#         MaxPool2d-26          [-1, 1, 128, 140]               0
# MultiheadAttention-27  [[-1, 2, 128], [-1, 140, 140]]               0
#           Dropout-28               [-1, 2, 128]               0
#         LayerNorm-29               [-1, 2, 128]             256
#            Linear-30               [-1, 2, 512]          66,048
#           Dropout-31               [-1, 2, 512]               0
#            Linear-32               [-1, 2, 128]          65,664
#           Dropout-33               [-1, 2, 128]               0
#         LayerNorm-34               [-1, 2, 128]             256
# TransformerEncoderLayer-35               [-1, 2, 128]               0
# MultiheadAttention-36  [[-1, 2, 128], [-1, 140, 140]]               0
#           Dropout-37               [-1, 2, 128]               0
#         LayerNorm-38               [-1, 2, 128]             256
#            Linear-39               [-1, 2, 512]          66,048
#           Dropout-40               [-1, 2, 512]               0
#            Linear-41               [-1, 2, 128]          65,664
#           Dropout-42               [-1, 2, 128]               0
#         LayerNorm-43               [-1, 2, 128]             256
# TransformerEncoderLayer-44               [-1, 2, 128]               0
# MultiheadAttention-45  [[-1, 2, 128], [-1, 140, 140]]               0
#           Dropout-46               [-1, 2, 128]               0
#         LayerNorm-47               [-1, 2, 128]             256
#            Linear-48               [-1, 2, 512]          66,048
#           Dropout-49               [-1, 2, 512]               0
#            Linear-50               [-1, 2, 128]          65,664
#           Dropout-51               [-1, 2, 128]               0
#         LayerNorm-52               [-1, 2, 128]             256
# TransformerEncoderLayer-53               [-1, 2, 128]               0
# MultiheadAttention-54  [[-1, 2, 128], [-1, 140, 140]]               0
#           Dropout-55               [-1, 2, 128]               0
#         LayerNorm-56               [-1, 2, 128]             256
#            Linear-57               [-1, 2, 512]          66,048
#           Dropout-58               [-1, 2, 512]               0
#            Linear-59               [-1, 2, 128]          65,664
#           Dropout-60               [-1, 2, 128]               0
#         LayerNorm-61               [-1, 2, 128]             256
# TransformerEncoderLayer-62               [-1, 2, 128]               0
# TransformerEncoder-63               [-1, 2, 128]               0
#            Linear-64                    [-1, 8]           5,128
#           Dropout-65                    [-1, 8]               0
#           Softmax-66                    [-1, 8]               0
# ================================================================
# Total params: 668,712
# Trainable params: 668,712
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.27
# Forward/backward pass size (MB): 97.17
# Params size (MB): 2.55
# Estimated Total Size (MB): 99.99
# ----------------------------------------------------------------

# %%
#  loss function for the backwards pass of each training iteration
#  We use log softmax for faster gradient optimization.
def loss_function(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %%
# function to create a single step of the each iteration training phase
def train_step_function(model, loss_function, optimizer):
    # training step of the training phase
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass and output_logits, output_softmax values are returned
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss and defining back propagation
        loss = loss_function(output_logits, Y)
         # compute gradients for the optimizer to use 
        loss.backward()
        # update network parameters based on gradient stored
        optimizer.step()
        # zero out gradients for next pass (ie accumulates gradients from backwards passe)
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
# define the validation function for each iteration on validation mini batches
def validation_step_function(model,loss_function):
    def validate(X,Y):
        # use to save memory and compute in validation phase:
        with torch.no_grad():
            # initialize model for validation phase by turning off dropout and batchnorm layers
            model.eval()
            # compute model predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            # compute error
            loss = loss_function(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %%
# set epoch size
EPOCHS=700
# read and assign train set lenght to variable DATASET_SIZE for define the number of iterations
DATASET_SIZE = X_train.shape[0]
# set batch size
BATCH_SIZE = 32
# set computation device as CUDA if available or CPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
# Initialize the model in Selected device
model = ConvNet().to(device)
# set SGD as optimizer
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)
# call the training step function 
train_step = train_step_function(model, loss_function, optimizer=OPTIMIZER)
# Call the validation function
validate = validation_step_function(model,loss_function)
# define empty lists to store scalar performance metrics for ploating
losses=[]
val_losses = []

train_accuracy = []
val_accuracy = []
# Out:
# Selected device is cuda

# %%
# created a function for training each individual epoches loop for entire training set
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):
    for epoch in range(EPOCHS):
        
        # schuffle data to randomize minibatch order
        ind = np.random.permutation(DATASET_SIZE)
        
        # shuffle the training set for each epoch:
        X_train = X_train[ind,:,:,:]
        Y_train = Y_train[ind]
        
        epoch_acc = 0
        epoch_loss = 0
        
        # Define number of iterations per epoch to process the entire train set
        iters = int(DATASET_SIZE / BATCH_SIZE)
         # create a loop for each minibatch of 32 samples:
        for i in range(iters):
            # track and update minibatch position based on iteration number to make sure all all data in the samples processd
            batch_start = i * BATCH_SIZE
            # Define bounds of our training set
            batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start
            # set training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:]
            # Set training minibatch labels 
            Y = Y_train[batch_start:batch_end]
            
            # Convert the train set and lables in to torch tensor format- train in to tensor flot and lables into long double
            X_tensor = torch.tensor(X,device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
             # Call the training function and train the model on train set features and lablels for each minibaches
            loss, acc = train_step(X_tensor,Y_tensor)
            
            # Keep track of loss and accuracy chage by aggrigating in to the variable for  measure the training and validation
            epoch_acc += acc*actual_batch_size/DATASET_SIZE
            epoch_loss += loss*actual_batch_size/DATASET_SIZE
            
            # Print details iteration wise training progress
            print(f"\r Epoch {epoch}: iteration {i+1}/{iters}",end='')
            
        # create tensors from validation set
        X_val_tensor = torch.tensor(X_valid,device=device).float()
        Y_val_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # call validation function and keep track of validation set performance
        val_loss, val_acc, predictions = validate(X_val_tensor,Y_val_tensor)
        
        # append scalar performance metrics at each epoch to track and plot later
        losses.append(epoch_loss)
        val_losses.append(val_loss)
        
        train_accuracy.append(epoch_acc)
        val_accuracy.append(val_acc)
        
        print('')
        print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")

# %%
# call the train function and train the model
train(OPTIMIZER, model, EPOCHS, X_train, y_train, X_val, y_val)
# Out:
#  Epoch 0: iteration 19/19
# Epoch 0 --> loss:4.4272, acc:14.64%, val_loss:2.6444, val_acc:13.75%
#  Epoch 1: iteration 19/19
# Epoch 1 --> loss:2.6299, acc:19.41%, val_loss:2.2655, val_acc:12.50%
#  Epoch 2: iteration 19/19
# Epoch 2 --> loss:2.2152, acc:18.42%, val_loss:2.1669, val_acc:12.50%
#  Epoch 3: iteration 19/19
# Epoch 3 --> loss:2.1420, acc:22.86%, val_loss:2.1339, val_acc:21.25%
#  Epoch 4: iteration 19/19
# Epoch 4 --> loss:2.0989, acc:22.70%, val_loss:1.9951, val_acc:20.00%
#  Epoch 5: iteration 19/19
# Epoch 5 --> loss:2.1358, acc:21.38%, val_loss:2.0376, val_acc:26.25%
#  Epoch 6: iteration 19/19
# Epoch 6 --> loss:1.9738, acc:27.96%, val_loss:2.1829, val_acc:23.75%
#  Epoch 7: iteration 19/19
# Epoch 7 --> loss:1.8359, acc:28.78%, val_loss:1.8142, val_acc:25.00%
#  Epoch 8: iteration 19/19
# Epoch 8 --> loss:1.9270, acc:28.95%, val_loss:2.0990, val_acc:22.50%
#  Epoch 9: iteration 19/19
# Epoch 9 --> loss:1.9846, acc:29.28%, val_loss:1.8956, val_acc:28.75%
#  Epoch 10: iteration 19/19
# Epoch 10 --> loss:1.9682, acc:29.44%, val_loss:2.0474, val_acc:17.50%
#  Epoch 11: iteration 19/19
# Epoch 11 --> loss:1.8882, acc:31.74%, val_loss:2.1148, val_acc:31.25%
#  Epoch 12: iteration 19/19
# Epoch 12 --> loss:1.9313, acc:28.62%, val_loss:2.7531, val_acc:20.00%
#  Epoch 13: iteration 19/19
# Epoch 13 --> loss:1.9402, acc:31.09%, val_loss:1.9773, val_acc:36.25%
#  Epoch 14: iteration 19/19
# Epoch 14 --> loss:1.7252, acc:34.38%, val_loss:1.9287, val_acc:26.25%
#  Epoch 15: iteration 19/19
# Epoch 15 --> loss:1.6129, acc:38.32%, val_loss:2.4123, val_acc:20.00%
#  Epoch 16: iteration 19/19
# Epoch 16 --> loss:1.7702, acc:35.53%, val_loss:2.0681, val_acc:21.25%
#  Epoch 17: iteration 19/19
# Epoch 17 --> loss:1.7189, acc:36.02%, val_loss:1.8295, val_acc:35.00%
#  Epoch 18: iteration 19/19
# Epoch 18 --> loss:1.6688, acc:38.82%, val_loss:1.8405, val_acc:30.00%
#  Epoch 19: iteration 19/19
# Epoch 19 --> loss:1.6639, acc:41.94%, val_loss:2.1278, val_acc:20.00%
#  Epoch 20: iteration 19/19
# Epoch 20 --> loss:1.6711, acc:37.99%, val_loss:1.9974, val_acc:20.00%
#  Epoch 21: iteration 19/19
# Epoch 21 --> loss:1.6030, acc:40.46%, val_loss:1.8030, val_acc:36.25%
#  Epoch 22: iteration 19/19
# Epoch 22 --> loss:1.6950, acc:39.64%, val_loss:1.7233, val_acc:28.75%
#  Epoch 23: iteration 19/19
# Epoch 23 --> loss:1.6587, acc:39.97%, val_loss:1.9080, val_acc:20.00%
#  Epoch 24: iteration 19/19
# Epoch 24 --> loss:1.5803, acc:42.43%, val_loss:2.1277, val_acc:26.25%
#  Epoch 25: iteration 19/19
# Epoch 25 --> loss:1.5105, acc:43.09%, val_loss:2.5778, val_acc:23.75%
#  Epoch 26: iteration 19/19
# Epoch 26 --> loss:1.4801, acc:45.89%, val_loss:2.7752, val_acc:23.75%
#  Epoch 27: iteration 19/19
# Epoch 27 --> loss:1.3916, acc:46.71%, val_loss:2.4997, val_acc:22.50%
#  Epoch 28: iteration 19/19
# Epoch 28 --> loss:1.4284, acc:48.03%, val_loss:2.7261, val_acc:23.75%
#  Epoch 29: iteration 19/19
# Epoch 29 --> loss:1.5920, acc:41.45%, val_loss:2.6278, val_acc:18.75%
#  Epoch 30: iteration 19/19
# Epoch 30 --> loss:1.3596, acc:49.34%, val_loss:2.3062, val_acc:18.75%
#  Epoch 31: iteration 19/19
# Epoch 31 --> loss:1.4300, acc:47.53%, val_loss:3.0065, val_acc:21.25%
#  Epoch 32: iteration 19/19
# Epoch 32 --> loss:1.3380, acc:50.00%, val_loss:3.7323, val_acc:18.75%
#  Epoch 33: iteration 19/19
# Epoch 33 --> loss:1.3581, acc:48.03%, val_loss:2.6327, val_acc:26.25%
#  Epoch 34: iteration 19/19
# Epoch 34 --> loss:1.4546, acc:47.04%, val_loss:4.0054, val_acc:17.50%
#  Epoch 35: iteration 19/19
# Epoch 35 --> loss:1.3835, acc:47.53%, val_loss:4.1829, val_acc:16.25%
#  Epoch 36: iteration 19/19
# Epoch 36 --> loss:1.3588, acc:49.67%, val_loss:3.7987, val_acc:17.50%
#  Epoch 37: iteration 19/19
# Epoch 37 --> loss:1.2896, acc:53.45%, val_loss:3.4604, val_acc:27.50%
#  Epoch 38: iteration 19/19
# Epoch 38 --> loss:1.2020, acc:58.39%, val_loss:3.6695, val_acc:26.25%
#  Epoch 39: iteration 19/19
# Epoch 39 --> loss:1.2540, acc:52.80%, val_loss:3.2800, val_acc:27.50%
#  Epoch 40: iteration 19/19
# Epoch 40 --> loss:1.3318, acc:52.47%, val_loss:4.0548, val_acc:21.25%
#  Epoch 41: iteration 19/19
# Epoch 41 --> loss:1.2146, acc:54.28%, val_loss:3.7513, val_acc:16.25%
#  Epoch 42: iteration 19/19
# Epoch 42 --> loss:1.1826, acc:56.25%, val_loss:3.4533, val_acc:28.75%
#  Epoch 43: iteration 19/19
# Epoch 43 --> loss:1.2833, acc:52.47%, val_loss:3.9004, val_acc:23.75%
#  Epoch 44: iteration 19/19
# Epoch 44 --> loss:1.3019, acc:52.30%, val_loss:3.1546, val_acc:28.75%
#  Epoch 45: iteration 19/19
# Epoch 45 --> loss:1.1827, acc:55.43%, val_loss:3.9388, val_acc:26.25%
#  Epoch 46: iteration 19/19
# Epoch 46 --> loss:1.1581, acc:54.77%, val_loss:4.4116, val_acc:26.25%
#  Epoch 47: iteration 19/19
# Epoch 47 --> loss:1.1078, acc:59.38%, val_loss:2.4611, val_acc:32.50%
#  Epoch 48: iteration 19/19
# Epoch 48 --> loss:1.2925, acc:52.80%, val_loss:3.9636, val_acc:25.00%
#  Epoch 49: iteration 19/19
# Epoch 49 --> loss:1.1825, acc:55.43%, val_loss:3.2945, val_acc:27.50%
#  Epoch 50: iteration 19/19
# Epoch 50 --> loss:1.0527, acc:58.06%, val_loss:4.3887, val_acc:18.75%
#  Epoch 51: iteration 19/19
# Epoch 51 --> loss:1.0042, acc:62.50%, val_loss:3.6088, val_acc:25.00%
#  Epoch 52: iteration 19/19
# Epoch 52 --> loss:0.9336, acc:67.27%, val_loss:4.0665, val_acc:20.00%
#  Epoch 53: iteration 19/19
# Epoch 53 --> loss:1.1254, acc:59.38%, val_loss:4.3824, val_acc:26.25%
#  Epoch 54: iteration 19/19
# Epoch 54 --> loss:1.0424, acc:60.86%, val_loss:3.4380, val_acc:26.25%
#  Epoch 55: iteration 19/19
# Epoch 55 --> loss:1.0610, acc:62.66%, val_loss:5.2999, val_acc:17.50%
#  Epoch 56: iteration 19/19
# Epoch 56 --> loss:1.0803, acc:59.87%, val_loss:3.1457, val_acc:25.00%
#  Epoch 57: iteration 19/19
# Epoch 57 --> loss:0.9490, acc:64.47%, val_loss:5.0174, val_acc:20.00%
#  Epoch 58: iteration 19/19
# Epoch 58 --> loss:0.9608, acc:63.65%, val_loss:4.0928, val_acc:25.00%
#  Epoch 59: iteration 19/19
# Epoch 59 --> loss:1.1016, acc:61.68%, val_loss:4.4671, val_acc:20.00%
#  Epoch 60: iteration 19/19
# Epoch 60 --> loss:1.0041, acc:63.65%, val_loss:3.3308, val_acc:28.75%
#  Epoch 61: iteration 19/19
# Epoch 61 --> loss:1.0662, acc:62.34%, val_loss:5.2925, val_acc:28.75%
#  Epoch 62: iteration 19/19
# Epoch 62 --> loss:1.1269, acc:61.02%, val_loss:5.0355, val_acc:28.75%
#  Epoch 63: iteration 19/19
# Epoch 63 --> loss:0.9387, acc:65.30%, val_loss:4.2288, val_acc:23.75%
#  Epoch 64: iteration 19/19
# Epoch 64 --> loss:0.9138, acc:67.60%, val_loss:3.3841, val_acc:30.00%
#  Epoch 65: iteration 19/19
# Epoch 65 --> loss:1.1058, acc:60.03%, val_loss:4.2131, val_acc:28.75%
#  Epoch 66: iteration 19/19
# Epoch 66 --> loss:0.9204, acc:64.64%, val_loss:4.1629, val_acc:23.75%
#  Epoch 67: iteration 19/19
# Epoch 67 --> loss:0.8313, acc:68.75%, val_loss:5.0672, val_acc:26.25%
#  Epoch 68: iteration 19/19
# Epoch 68 --> loss:0.9528, acc:64.97%, val_loss:4.7172, val_acc:20.00%
#  Epoch 69: iteration 19/19
# Epoch 69 --> loss:0.8727, acc:64.97%, val_loss:4.6101, val_acc:21.25%
#  Epoch 70: iteration 19/19
# Epoch 70 --> loss:0.8874, acc:67.11%, val_loss:4.8840, val_acc:22.50%
#  Epoch 71: iteration 19/19
# Epoch 71 --> loss:0.9057, acc:65.95%, val_loss:4.5999, val_acc:28.75%
#  Epoch 72: iteration 19/19
# Epoch 72 --> loss:0.7343, acc:74.67%, val_loss:3.5165, val_acc:27.50%
#  Epoch 73: iteration 19/19
# Epoch 73 --> loss:0.7785, acc:70.72%, val_loss:3.6873, val_acc:28.75%
#  Epoch 74: iteration 19/19
# Epoch 74 --> loss:0.7668, acc:71.05%, val_loss:4.0850, val_acc:25.00%
#  Epoch 75: iteration 19/19
# Epoch 75 --> loss:0.8544, acc:67.60%, val_loss:4.2424, val_acc:25.00%
#  Epoch 76: iteration 19/19
# Epoch 76 --> loss:0.8336, acc:68.59%, val_loss:3.4661, val_acc:31.25%
#  Epoch 77: iteration 19/19
# Epoch 77 --> loss:0.9436, acc:65.13%, val_loss:3.0147, val_acc:30.00%
#  Epoch 78: iteration 19/19
# Epoch 78 --> loss:0.7742, acc:71.05%, val_loss:3.2687, val_acc:30.00%
#  Epoch 79: iteration 19/19
# Epoch 79 --> loss:0.9022, acc:67.60%, val_loss:3.1843, val_acc:33.75%
#  Epoch 80: iteration 19/19
# Epoch 80 --> loss:0.9580, acc:61.84%, val_loss:3.3302, val_acc:27.50%
#  Epoch 81: iteration 19/19
# Epoch 81 --> loss:0.7601, acc:73.03%, val_loss:3.2805, val_acc:32.50%
#  Epoch 82: iteration 19/19
# Epoch 82 --> loss:0.7280, acc:73.85%, val_loss:4.8376, val_acc:25.00%
#  Epoch 83: iteration 19/19
# Epoch 83 --> loss:0.6240, acc:78.12%, val_loss:3.1216, val_acc:32.50%
#  Epoch 84: iteration 19/19
# Epoch 84 --> loss:0.6571, acc:75.16%, val_loss:3.4159, val_acc:28.75%
#  Epoch 85: iteration 19/19
# Epoch 85 --> loss:0.6987, acc:72.86%, val_loss:5.2427, val_acc:22.50%
#  Epoch 86: iteration 19/19
# Epoch 86 --> loss:0.6934, acc:75.82%, val_loss:2.0749, val_acc:36.25%
#  Epoch 87: iteration 19/19
# Epoch 87 --> loss:0.7834, acc:71.05%, val_loss:6.0577, val_acc:23.75%
#  Epoch 88: iteration 19/19
# Epoch 88 --> loss:0.9922, acc:64.97%, val_loss:3.3868, val_acc:22.50%
#  Epoch 89: iteration 19/19
# Epoch 89 --> loss:0.7583, acc:72.04%, val_loss:4.3967, val_acc:23.75%
#  Epoch 90: iteration 19/19
# Epoch 90 --> loss:0.7444, acc:73.68%, val_loss:1.4603, val_acc:48.75%
#  Epoch 91: iteration 19/19
# Epoch 91 --> loss:0.7124, acc:74.01%, val_loss:4.3973, val_acc:28.75%
#  Epoch 92: iteration 19/19
# Epoch 92 --> loss:0.6284, acc:78.95%, val_loss:2.9964, val_acc:30.00%
#  Epoch 93: iteration 19/19
# Epoch 93 --> loss:0.5526, acc:80.76%, val_loss:2.9880, val_acc:40.00%
#  Epoch 94: iteration 19/19
# Epoch 94 --> loss:0.7070, acc:75.49%, val_loss:2.6900, val_acc:35.00%
#  Epoch 95: iteration 19/19
# Epoch 95 --> loss:0.6537, acc:76.81%, val_loss:4.1446, val_acc:33.75%
#  Epoch 96: iteration 19/19
# Epoch 96 --> loss:0.6985, acc:74.01%, val_loss:4.5951, val_acc:25.00%
#  Epoch 97: iteration 19/19
# Epoch 97 --> loss:0.7508, acc:70.39%, val_loss:2.3009, val_acc:37.50%
#  Epoch 98: iteration 19/19
# Epoch 98 --> loss:0.6534, acc:74.18%, val_loss:2.2141, val_acc:46.25%
#  Epoch 99: iteration 19/19
# Epoch 99 --> loss:0.5102, acc:82.07%, val_loss:3.8642, val_acc:28.75%
#  Epoch 100: iteration 19/19
# Epoch 100 --> loss:0.5859, acc:79.44%, val_loss:4.4327, val_acc:27.50%
#  Epoch 101: iteration 19/19
# Epoch 101 --> loss:0.4383, acc:83.88%, val_loss:5.1391, val_acc:27.50%
#  Epoch 102: iteration 19/19
# Epoch 102 --> loss:0.5883, acc:76.97%, val_loss:5.3006, val_acc:27.50%
#  Epoch 103: iteration 19/19
# Epoch 103 --> loss:0.5085, acc:82.07%, val_loss:3.9699, val_acc:28.75%
#  Epoch 104: iteration 19/19
# Epoch 104 --> loss:0.4053, acc:86.02%, val_loss:2.9468, val_acc:35.00%
#  Epoch 105: iteration 19/19
# Epoch 105 --> loss:0.5700, acc:78.29%, val_loss:4.0035, val_acc:26.25%
#  Epoch 106: iteration 19/19
# Epoch 106 --> loss:0.4361, acc:84.21%, val_loss:2.0235, val_acc:36.25%
#  Epoch 107: iteration 19/19
# Epoch 107 --> loss:0.6217, acc:78.78%, val_loss:5.3009, val_acc:21.25%
#  Epoch 108: iteration 19/19
# Epoch 108 --> loss:0.8182, acc:69.08%, val_loss:5.1833, val_acc:23.75%
#  Epoch 109: iteration 19/19
# Epoch 109 --> loss:0.5427, acc:79.93%, val_loss:3.1789, val_acc:30.00%
#  Epoch 110: iteration 19/19
# Epoch 110 --> loss:0.5089, acc:81.25%, val_loss:4.3779, val_acc:25.00%
#  Epoch 111: iteration 19/19
# Epoch 111 --> loss:0.6007, acc:76.97%, val_loss:4.3284, val_acc:22.50%
#  Epoch 112: iteration 19/19
# Epoch 112 --> loss:0.4429, acc:84.38%, val_loss:1.5893, val_acc:52.50%
#  Epoch 113: iteration 19/19
# Epoch 113 --> loss:0.3761, acc:86.18%, val_loss:2.2766, val_acc:35.00%
#  Epoch 114: iteration 19/19
# Epoch 114 --> loss:0.3593, acc:87.17%, val_loss:3.0172, val_acc:33.75%
#  Epoch 115: iteration 19/19
# Epoch 115 --> loss:0.3506, acc:87.99%, val_loss:2.3682, val_acc:42.50%
#  Epoch 116: iteration 19/19
# Epoch 116 --> loss:0.4731, acc:82.24%, val_loss:2.8153, val_acc:35.00%
#  Epoch 117: iteration 19/19
# Epoch 117 --> loss:0.4848, acc:82.89%, val_loss:5.3824, val_acc:23.75%
#  Epoch 118: iteration 19/19
# Epoch 118 --> loss:0.5484, acc:79.61%, val_loss:3.6245, val_acc:31.25%
#  Epoch 119: iteration 19/19
# Epoch 119 --> loss:0.6465, acc:74.51%, val_loss:2.7103, val_acc:36.25%
#  Epoch 120: iteration 19/19
# Epoch 120 --> loss:0.6085, acc:77.80%, val_loss:4.3887, val_acc:25.00%
#  Epoch 121: iteration 19/19
# Epoch 121 --> loss:0.4427, acc:82.40%, val_loss:4.2815, val_acc:23.75%
#  Epoch 122: iteration 19/19
# Epoch 122 --> loss:0.4011, acc:85.86%, val_loss:2.8756, val_acc:40.00%
#  Epoch 123: iteration 19/19
# Epoch 123 --> loss:0.3661, acc:86.68%, val_loss:3.7182, val_acc:31.25%
#  Epoch 124: iteration 19/19
# Epoch 124 --> loss:0.3939, acc:85.69%, val_loss:1.5651, val_acc:46.25%
#  Epoch 125: iteration 19/19
# Epoch 125 --> loss:0.3917, acc:86.35%, val_loss:4.0395, val_acc:26.25%
#  Epoch 126: iteration 19/19
# Epoch 126 --> loss:0.3927, acc:86.35%, val_loss:4.3709, val_acc:32.50%
#  Epoch 127: iteration 19/19
# Epoch 127 --> loss:0.4712, acc:82.57%, val_loss:1.6180, val_acc:48.75%
#  Epoch 128: iteration 19/19
# Epoch 128 --> loss:0.3485, acc:86.51%, val_loss:4.2862, val_acc:37.50%
#  Epoch 129: iteration 19/19
# Epoch 129 --> loss:0.3425, acc:85.69%, val_loss:3.0703, val_acc:31.25%
#  Epoch 130: iteration 19/19
# Epoch 130 --> loss:0.3493, acc:86.68%, val_loss:2.4122, val_acc:45.00%
#  Epoch 131: iteration 19/19
# Epoch 131 --> loss:0.4711, acc:83.06%, val_loss:2.2877, val_acc:41.25%
#  Epoch 132: iteration 19/19
# Epoch 132 --> loss:0.6271, acc:77.96%, val_loss:4.6540, val_acc:26.25%
#  Epoch 133: iteration 19/19
# Epoch 133 --> loss:0.4846, acc:82.73%, val_loss:5.2379, val_acc:22.50%
#  Epoch 134: iteration 19/19
# Epoch 134 --> loss:0.3838, acc:85.53%, val_loss:1.9908, val_acc:40.00%
#  Epoch 135: iteration 19/19
# Epoch 135 --> loss:0.3669, acc:86.84%, val_loss:3.5418, val_acc:30.00%
#  Epoch 136: iteration 19/19
# Epoch 136 --> loss:0.4094, acc:86.68%, val_loss:4.7388, val_acc:26.25%
#  Epoch 137: iteration 19/19
# Epoch 137 --> loss:0.3352, acc:88.16%, val_loss:4.4236, val_acc:30.00%
#  Epoch 138: iteration 19/19
# Epoch 138 --> loss:0.2265, acc:94.24%, val_loss:5.8139, val_acc:26.25%
#  Epoch 139: iteration 19/19
# Epoch 139 --> loss:0.2888, acc:89.97%, val_loss:2.4071, val_acc:37.50%
#  Epoch 140: iteration 19/19
# Epoch 140 --> loss:0.2761, acc:89.97%, val_loss:3.4039, val_acc:35.00%
#  Epoch 141: iteration 19/19
# Epoch 141 --> loss:0.2693, acc:90.30%, val_loss:2.4937, val_acc:36.25%
#  Epoch 142: iteration 19/19
# Epoch 142 --> loss:0.3131, acc:88.82%, val_loss:4.3660, val_acc:27.50%
#  Epoch 143: iteration 19/19
# Epoch 143 --> loss:0.2154, acc:93.91%, val_loss:4.1458, val_acc:31.25%
#  Epoch 144: iteration 19/19
# Epoch 144 --> loss:0.2862, acc:88.98%, val_loss:4.1042, val_acc:27.50%
#  Epoch 145: iteration 19/19
# Epoch 145 --> loss:0.2557, acc:90.62%, val_loss:2.6595, val_acc:40.00%
#  Epoch 146: iteration 19/19
# Epoch 146 --> loss:0.2542, acc:91.45%, val_loss:4.4064, val_acc:26.25%
#  Epoch 147: iteration 19/19
# Epoch 147 --> loss:0.3215, acc:89.80%, val_loss:4.6613, val_acc:27.50%
#  Epoch 148: iteration 19/19
# Epoch 148 --> loss:0.3109, acc:88.49%, val_loss:1.8167, val_acc:45.00%
#  Epoch 149: iteration 19/19
# Epoch 149 --> loss:0.4359, acc:84.05%, val_loss:3.3046, val_acc:35.00%
#  Epoch 150: iteration 19/19
# Epoch 150 --> loss:0.2562, acc:89.80%, val_loss:5.3398, val_acc:26.25%
#  Epoch 151: iteration 19/19
# Epoch 151 --> loss:0.3409, acc:88.65%, val_loss:3.9519, val_acc:28.75%
#  Epoch 152: iteration 19/19
# Epoch 152 --> loss:0.3176, acc:88.98%, val_loss:4.2146, val_acc:32.50%
#  Epoch 153: iteration 19/19
# Epoch 153 --> loss:0.3701, acc:85.69%, val_loss:3.1615, val_acc:32.50%
#  Epoch 154: iteration 19/19
# Epoch 154 --> loss:0.3055, acc:90.79%, val_loss:4.1640, val_acc:38.75%
#  Epoch 155: iteration 19/19
# Epoch 155 --> loss:0.3116, acc:87.50%, val_loss:4.7559, val_acc:30.00%
#  Epoch 156: iteration 19/19
# Epoch 156 --> loss:0.1881, acc:93.75%, val_loss:2.8412, val_acc:40.00%
#  Epoch 157: iteration 19/19
# Epoch 157 --> loss:0.1374, acc:96.22%, val_loss:4.3318, val_acc:27.50%
#  Epoch 158: iteration 19/19
# Epoch 158 --> loss:0.1644, acc:94.24%, val_loss:3.9396, val_acc:33.75%
#  Epoch 159: iteration 19/19
# Epoch 159 --> loss:0.3050, acc:88.49%, val_loss:2.8595, val_acc:40.00%
#  Epoch 160: iteration 19/19
# Epoch 160 --> loss:0.3871, acc:85.69%, val_loss:5.0132, val_acc:22.50%
#  Epoch 161: iteration 19/19
# Epoch 161 --> loss:0.4690, acc:85.53%, val_loss:3.1523, val_acc:30.00%
#  Epoch 162: iteration 19/19
# Epoch 162 --> loss:0.2538, acc:92.27%, val_loss:5.8205, val_acc:27.50%
#  Epoch 163: iteration 19/19
# Epoch 163 --> loss:0.2114, acc:91.94%, val_loss:4.4871, val_acc:26.25%
#  Epoch 164: iteration 19/19
# Epoch 164 --> loss:0.1894, acc:94.08%, val_loss:2.6067, val_acc:41.25%
#  Epoch 165: iteration 19/19
# Epoch 165 --> loss:0.2479, acc:90.62%, val_loss:4.1614, val_acc:31.25%
#  Epoch 166: iteration 19/19
# Epoch 166 --> loss:0.2257, acc:90.46%, val_loss:6.1589, val_acc:28.75%
#  Epoch 167: iteration 19/19
# Epoch 167 --> loss:0.1322, acc:96.88%, val_loss:4.4365, val_acc:32.50%
#  Epoch 168: iteration 19/19
# Epoch 168 --> loss:0.1431, acc:95.89%, val_loss:4.5476, val_acc:33.75%
#  Epoch 169: iteration 19/19
# Epoch 169 --> loss:0.2386, acc:92.27%, val_loss:4.4933, val_acc:33.75%
#  Epoch 170: iteration 19/19
# Epoch 170 --> loss:0.6527, acc:76.32%, val_loss:3.3595, val_acc:31.25%
#  Epoch 171: iteration 19/19
# Epoch 171 --> loss:0.4313, acc:81.41%, val_loss:5.7908, val_acc:18.75%
#  Epoch 172: iteration 19/19
# Epoch 172 --> loss:0.2733, acc:91.12%, val_loss:4.2159, val_acc:37.50%
#  Epoch 173: iteration 19/19
# Epoch 173 --> loss:0.2028, acc:93.26%, val_loss:4.5301, val_acc:33.75%
#  Epoch 174: iteration 19/19
# Epoch 174 --> loss:0.2296, acc:91.28%, val_loss:3.6627, val_acc:38.75%
#  Epoch 175: iteration 19/19
# Epoch 175 --> loss:0.1623, acc:95.72%, val_loss:2.2498, val_acc:47.50%
#  Epoch 176: iteration 19/19
# Epoch 176 --> loss:0.2684, acc:90.13%, val_loss:2.8587, val_acc:33.75%
#  Epoch 177: iteration 19/19
# Epoch 177 --> loss:0.2818, acc:90.79%, val_loss:3.5908, val_acc:32.50%
#  Epoch 178: iteration 19/19
# Epoch 178 --> loss:0.1922, acc:93.75%, val_loss:4.3386, val_acc:33.75%
#  Epoch 179: iteration 19/19
# Epoch 179 --> loss:0.2424, acc:90.95%, val_loss:3.1677, val_acc:35.00%
#  Epoch 180: iteration 19/19
# Epoch 180 --> loss:0.2208, acc:92.11%, val_loss:3.2413, val_acc:41.25%
#  Epoch 181: iteration 19/19
# Epoch 181 --> loss:0.2591, acc:90.95%, val_loss:6.0378, val_acc:30.00%
#  Epoch 182: iteration 19/19
# Epoch 182 --> loss:0.2728, acc:88.98%, val_loss:4.7613, val_acc:31.25%
#  Epoch 183: iteration 19/19
# Epoch 183 --> loss:0.2620, acc:89.80%, val_loss:4.0753, val_acc:31.25%
#  Epoch 184: iteration 19/19
# Epoch 184 --> loss:0.2814, acc:89.80%, val_loss:2.2901, val_acc:40.00%
#  Epoch 185: iteration 19/19
# Epoch 185 --> loss:0.2797, acc:90.13%, val_loss:3.7079, val_acc:32.50%
#  Epoch 186: iteration 19/19
# Epoch 186 --> loss:0.2689, acc:90.30%, val_loss:1.7906, val_acc:46.25%
#  Epoch 187: iteration 19/19
# Epoch 187 --> loss:0.4368, acc:84.87%, val_loss:5.9965, val_acc:37.50%
#  Epoch 188: iteration 19/19
# Epoch 188 --> loss:0.3199, acc:88.82%, val_loss:3.5863, val_acc:33.75%
#  Epoch 189: iteration 19/19
# Epoch 189 --> loss:0.3397, acc:85.69%, val_loss:2.0611, val_acc:46.25%
#  Epoch 190: iteration 19/19
# Epoch 190 --> loss:0.3391, acc:88.82%, val_loss:3.1534, val_acc:37.50%
#  Epoch 191: iteration 19/19
# Epoch 191 --> loss:0.2354, acc:92.60%, val_loss:2.8149, val_acc:41.25%
#  Epoch 192: iteration 19/19
# Epoch 192 --> loss:0.1873, acc:94.41%, val_loss:4.1080, val_acc:36.25%
#  Epoch 193: iteration 19/19
# Epoch 193 --> loss:0.1633, acc:94.41%, val_loss:4.5307, val_acc:35.00%
#  Epoch 194: iteration 19/19
# Epoch 194 --> loss:0.2219, acc:91.78%, val_loss:2.8056, val_acc:36.25%
#  Epoch 195: iteration 19/19
# Epoch 195 --> loss:0.2456, acc:92.11%, val_loss:2.0173, val_acc:41.25%
#  Epoch 196: iteration 19/19
# Epoch 196 --> loss:0.3285, acc:88.82%, val_loss:5.7791, val_acc:30.00%
#  Epoch 197: iteration 19/19
# Epoch 197 --> loss:0.2241, acc:92.11%, val_loss:3.9574, val_acc:31.25%
#  Epoch 198: iteration 19/19
# Epoch 198 --> loss:0.2922, acc:89.31%, val_loss:5.1657, val_acc:33.75%
#  Epoch 199: iteration 19/19
# Epoch 199 --> loss:0.1483, acc:95.89%, val_loss:3.9469, val_acc:31.25%
#  Epoch 200: iteration 19/19
# Epoch 200 --> loss:0.1649, acc:94.90%, val_loss:3.0772, val_acc:31.25%
#  Epoch 201: iteration 19/19
# Epoch 201 --> loss:0.1511, acc:95.89%, val_loss:3.6897, val_acc:30.00%
#  Epoch 202: iteration 19/19
# Epoch 202 --> loss:0.1644, acc:94.41%, val_loss:2.5718, val_acc:36.25%
#  Epoch 203: iteration 19/19
# Epoch 203 --> loss:0.1809, acc:93.75%, val_loss:3.7985, val_acc:33.75%
#  Epoch 204: iteration 19/19
# Epoch 204 --> loss:0.2419, acc:91.61%, val_loss:4.4066, val_acc:28.75%
#  Epoch 205: iteration 19/19
# Epoch 205 --> loss:0.5823, acc:79.44%, val_loss:4.1882, val_acc:32.50%
#  Epoch 206: iteration 19/19
# Epoch 206 --> loss:0.3327, acc:87.50%, val_loss:4.2044, val_acc:27.50%
#  Epoch 207: iteration 19/19
# Epoch 207 --> loss:0.2440, acc:91.61%, val_loss:5.3852, val_acc:28.75%
#  Epoch 208: iteration 19/19
# Epoch 208 --> loss:0.3307, acc:87.50%, val_loss:1.6805, val_acc:48.75%
#  Epoch 209: iteration 19/19
# Epoch 209 --> loss:0.3451, acc:88.65%, val_loss:4.5814, val_acc:35.00%
#  Epoch 210: iteration 19/19
# Epoch 210 --> loss:0.2090, acc:93.09%, val_loss:3.9169, val_acc:30.00%
#  Epoch 211: iteration 19/19
# Epoch 211 --> loss:0.1941, acc:92.93%, val_loss:4.3664, val_acc:30.00%
#  Epoch 212: iteration 19/19
# Epoch 212 --> loss:0.1465, acc:95.23%, val_loss:3.9137, val_acc:33.75%
#  Epoch 213: iteration 19/19
# Epoch 213 --> loss:0.1790, acc:93.75%, val_loss:2.6374, val_acc:41.25%
#  Epoch 214: iteration 19/19
# Epoch 214 --> loss:0.2671, acc:91.78%, val_loss:4.5157, val_acc:33.75%
#  Epoch 215: iteration 19/19
# Epoch 215 --> loss:0.1612, acc:95.56%, val_loss:1.3899, val_acc:61.25%
#  Epoch 216: iteration 19/19
# Epoch 216 --> loss:0.1626, acc:95.39%, val_loss:4.2618, val_acc:33.75%
#  Epoch 217: iteration 19/19
# Epoch 217 --> loss:0.1854, acc:94.24%, val_loss:5.6857, val_acc:28.75%
#  Epoch 218: iteration 19/19
# Epoch 218 --> loss:0.2262, acc:91.78%, val_loss:2.9319, val_acc:41.25%
#  Epoch 219: iteration 19/19
# Epoch 219 --> loss:0.1910, acc:94.24%, val_loss:4.0506, val_acc:36.25%
#  Epoch 220: iteration 19/19
# Epoch 220 --> loss:0.2000, acc:92.93%, val_loss:2.3889, val_acc:38.75%
#  Epoch 221: iteration 19/19
# Epoch 221 --> loss:0.2252, acc:92.11%, val_loss:4.5855, val_acc:33.75%
#  Epoch 222: iteration 19/19
# Epoch 222 --> loss:0.1545, acc:94.41%, val_loss:4.3316, val_acc:30.00%
#  Epoch 223: iteration 19/19
# Epoch 223 --> loss:0.2585, acc:90.79%, val_loss:1.7233, val_acc:57.50%
#  Epoch 224: iteration 19/19
# Epoch 224 --> loss:0.1576, acc:94.74%, val_loss:2.1477, val_acc:48.75%
#  Epoch 225: iteration 19/19
# Epoch 225 --> loss:0.1402, acc:95.72%, val_loss:4.4372, val_acc:33.75%
#  Epoch 226: iteration 19/19
# Epoch 226 --> loss:0.0977, acc:96.38%, val_loss:3.7592, val_acc:35.00%
#  Epoch 227: iteration 19/19
# Epoch 227 --> loss:0.1073, acc:97.20%, val_loss:3.2025, val_acc:38.75%
#  Epoch 228: iteration 19/19
# Epoch 228 --> loss:0.1370, acc:96.22%, val_loss:1.8467, val_acc:48.75%
#  Epoch 229: iteration 19/19
# Epoch 229 --> loss:0.1755, acc:93.75%, val_loss:2.7931, val_acc:41.25%
#  Epoch 230: iteration 19/19
# Epoch 230 --> loss:0.1645, acc:94.57%, val_loss:3.0427, val_acc:45.00%
#  Epoch 231: iteration 19/19
# Epoch 231 --> loss:0.1529, acc:94.90%, val_loss:4.7872, val_acc:32.50%
#  Epoch 232: iteration 19/19
# Epoch 232 --> loss:0.1114, acc:96.71%, val_loss:2.9367, val_acc:40.00%
#  Epoch 233: iteration 19/19
# Epoch 233 --> loss:0.1311, acc:95.56%, val_loss:6.1799, val_acc:23.75%
#  Epoch 234: iteration 19/19
# Epoch 234 --> loss:0.1663, acc:94.24%, val_loss:3.1284, val_acc:37.50%
#  Epoch 235: iteration 19/19
# Epoch 235 --> loss:0.0908, acc:97.86%, val_loss:3.2042, val_acc:40.00%
#  Epoch 236: iteration 19/19
# Epoch 236 --> loss:0.1209, acc:96.38%, val_loss:3.5359, val_acc:36.25%
#  Epoch 237: iteration 19/19
# Epoch 237 --> loss:0.0797, acc:97.70%, val_loss:3.1959, val_acc:42.50%
#  Epoch 238: iteration 19/19
# Epoch 238 --> loss:0.1218, acc:96.38%, val_loss:3.9549, val_acc:40.00%
#  Epoch 239: iteration 19/19
# Epoch 239 --> loss:0.1177, acc:96.22%, val_loss:5.2431, val_acc:28.75%
#  Epoch 240: iteration 19/19
# Epoch 240 --> loss:0.2786, acc:90.30%, val_loss:3.9608, val_acc:37.50%
#  Epoch 241: iteration 19/19
# Epoch 241 --> loss:0.5395, acc:81.25%, val_loss:4.1877, val_acc:36.25%
#  Epoch 242: iteration 19/19
# Epoch 242 --> loss:0.3560, acc:86.51%, val_loss:1.8335, val_acc:55.00%
#  Epoch 243: iteration 19/19
# Epoch 243 --> loss:0.2173, acc:92.43%, val_loss:4.9536, val_acc:30.00%
#  Epoch 244: iteration 19/19
# Epoch 244 --> loss:0.2417, acc:92.60%, val_loss:3.1434, val_acc:45.00%
#  Epoch 245: iteration 19/19
# Epoch 245 --> loss:0.1487, acc:95.07%, val_loss:3.2271, val_acc:36.25%
#  Epoch 246: iteration 19/19
# Epoch 246 --> loss:0.1487, acc:95.23%, val_loss:2.9801, val_acc:46.25%
#  Epoch 247: iteration 19/19
# Epoch 247 --> loss:0.1280, acc:95.89%, val_loss:2.5189, val_acc:42.50%
#  Epoch 248: iteration 19/19
# Epoch 248 --> loss:0.0808, acc:98.36%, val_loss:3.6959, val_acc:37.50%
#  Epoch 249: iteration 19/19
# Epoch 249 --> loss:0.1193, acc:96.38%, val_loss:3.9793, val_acc:35.00%
#  Epoch 250: iteration 19/19
# Epoch 250 --> loss:0.0938, acc:97.04%, val_loss:3.3704, val_acc:37.50%
#  Epoch 251: iteration 19/19
# Epoch 251 --> loss:0.0920, acc:97.70%, val_loss:4.3042, val_acc:36.25%
#  Epoch 252: iteration 19/19
# Epoch 252 --> loss:0.1097, acc:96.71%, val_loss:4.0733, val_acc:35.00%
#  Epoch 253: iteration 19/19
# Epoch 253 --> loss:0.0659, acc:98.52%, val_loss:1.7992, val_acc:63.75%
#  Epoch 254: iteration 19/19
# Epoch 254 --> loss:0.1353, acc:95.39%, val_loss:3.3075, val_acc:38.75%
#  Epoch 255: iteration 19/19
# Epoch 255 --> loss:0.1266, acc:96.71%, val_loss:2.9362, val_acc:41.25%
#  Epoch 256: iteration 19/19
# Epoch 256 --> loss:0.0995, acc:97.53%, val_loss:3.1727, val_acc:42.50%
#  Epoch 257: iteration 19/19
# Epoch 257 --> loss:0.1116, acc:97.04%, val_loss:2.8503, val_acc:38.75%
#  Epoch 258: iteration 19/19
# Epoch 258 --> loss:0.1131, acc:96.55%, val_loss:1.9274, val_acc:56.25%
#  Epoch 259: iteration 19/19
# Epoch 259 --> loss:0.1150, acc:96.05%, val_loss:3.6835, val_acc:37.50%
#  Epoch 260: iteration 19/19
# Epoch 260 --> loss:0.0764, acc:97.70%, val_loss:3.6387, val_acc:38.75%
#  Epoch 261: iteration 19/19
# Epoch 261 --> loss:0.1034, acc:97.04%, val_loss:3.5665, val_acc:36.25%
#  Epoch 262: iteration 19/19
# Epoch 262 --> loss:0.0920, acc:96.22%, val_loss:4.4592, val_acc:35.00%
#  Epoch 263: iteration 19/19
# Epoch 263 --> loss:0.0795, acc:98.03%, val_loss:3.3265, val_acc:42.50%
#  Epoch 264: iteration 19/19
# Epoch 264 --> loss:0.0708, acc:97.86%, val_loss:2.5912, val_acc:40.00%
#  Epoch 265: iteration 19/19
# Epoch 265 --> loss:0.0945, acc:96.55%, val_loss:2.8331, val_acc:40.00%
#  Epoch 266: iteration 19/19
# Epoch 266 --> loss:0.0620, acc:98.68%, val_loss:3.7500, val_acc:37.50%
#  Epoch 267: iteration 19/19
# Epoch 267 --> loss:0.1284, acc:95.07%, val_loss:2.8537, val_acc:43.75%
#  Epoch 268: iteration 19/19
# Epoch 268 --> loss:0.1845, acc:93.26%, val_loss:5.0251, val_acc:26.25%
#  Epoch 269: iteration 19/19
# Epoch 269 --> loss:0.0890, acc:97.70%, val_loss:3.1262, val_acc:40.00%
#  Epoch 270: iteration 19/19
# Epoch 270 --> loss:0.0623, acc:98.85%, val_loss:3.1722, val_acc:37.50%
#  Epoch 271: iteration 19/19
# Epoch 271 --> loss:0.0390, acc:99.34%, val_loss:2.9843, val_acc:37.50%
#  Epoch 272: iteration 19/19
# Epoch 272 --> loss:0.0379, acc:99.67%, val_loss:2.8995, val_acc:43.75%
#  Epoch 273: iteration 19/19
# Epoch 273 --> loss:0.0399, acc:99.34%, val_loss:3.2191, val_acc:38.75%
#  Epoch 274: iteration 19/19
# Epoch 274 --> loss:0.0420, acc:99.34%, val_loss:3.4536, val_acc:42.50%
#  Epoch 275: iteration 19/19
# Epoch 275 --> loss:0.0322, acc:99.67%, val_loss:3.1687, val_acc:38.75%
#  Epoch 276: iteration 19/19
# Epoch 276 --> loss:0.0863, acc:97.04%, val_loss:2.5659, val_acc:47.50%
#  Epoch 277: iteration 19/19
# Epoch 277 --> loss:0.1290, acc:95.56%, val_loss:4.7959, val_acc:28.75%
#  Epoch 278: iteration 19/19
# Epoch 278 --> loss:0.1676, acc:94.08%, val_loss:4.2875, val_acc:35.00%
#  Epoch 279: iteration 19/19
# Epoch 279 --> loss:0.0927, acc:97.37%, val_loss:2.8605, val_acc:42.50%
#  Epoch 280: iteration 19/19
# Epoch 280 --> loss:0.1018, acc:97.37%, val_loss:2.9651, val_acc:42.50%
#  Epoch 281: iteration 19/19
# Epoch 281 --> loss:0.0780, acc:98.19%, val_loss:2.6457, val_acc:50.00%
#  Epoch 282: iteration 19/19
# Epoch 282 --> loss:0.0751, acc:97.86%, val_loss:4.0555, val_acc:37.50%
#  Epoch 283: iteration 19/19
# Epoch 283 --> loss:0.0577, acc:98.68%, val_loss:4.2399, val_acc:38.75%
#  Epoch 284: iteration 19/19
# Epoch 284 --> loss:0.0363, acc:99.51%, val_loss:2.5886, val_acc:46.25%
#  Epoch 285: iteration 19/19
# Epoch 285 --> loss:0.0410, acc:99.18%, val_loss:3.6977, val_acc:43.75%
#  Epoch 286: iteration 19/19
# Epoch 286 --> loss:0.1055, acc:96.55%, val_loss:4.8816, val_acc:33.75%
#  Epoch 287: iteration 19/19
# Epoch 287 --> loss:0.3132, acc:89.80%, val_loss:2.7736, val_acc:51.25%
#  Epoch 288: iteration 19/19
# Epoch 288 --> loss:0.2688, acc:90.13%, val_loss:5.5048, val_acc:33.75%
#  Epoch 289: iteration 19/19
# Epoch 289 --> loss:0.1122, acc:96.71%, val_loss:2.0639, val_acc:55.00%
#  Epoch 290: iteration 19/19
# Epoch 290 --> loss:0.0877, acc:97.20%, val_loss:3.2369, val_acc:41.25%
#  Epoch 291: iteration 19/19
# Epoch 291 --> loss:0.1142, acc:96.05%, val_loss:1.6767, val_acc:56.25%
#  Epoch 292: iteration 19/19
# Epoch 292 --> loss:0.0607, acc:98.68%, val_loss:4.5847, val_acc:36.25%
#  Epoch 293: iteration 19/19
# Epoch 293 --> loss:0.0499, acc:99.18%, val_loss:1.7923, val_acc:53.75%
#  Epoch 294: iteration 19/19
# Epoch 294 --> loss:0.0633, acc:97.70%, val_loss:1.7136, val_acc:52.50%
#  Epoch 295: iteration 19/19
# Epoch 295 --> loss:0.0434, acc:99.18%, val_loss:3.4189, val_acc:40.00%
#  Epoch 296: iteration 19/19
# Epoch 296 --> loss:0.0261, acc:99.84%, val_loss:2.4097, val_acc:45.00%
#  Epoch 297: iteration 19/19
# Epoch 297 --> loss:0.0325, acc:99.34%, val_loss:2.9428, val_acc:41.25%
#  Epoch 298: iteration 19/19
# Epoch 298 --> loss:0.0486, acc:98.85%, val_loss:3.9707, val_acc:38.75%
#  Epoch 299: iteration 19/19
# Epoch 299 --> loss:0.0364, acc:99.18%, val_loss:4.3580, val_acc:37.50%
#  Epoch 300: iteration 19/19
# Epoch 300 --> loss:0.0588, acc:98.36%, val_loss:3.5882, val_acc:42.50%
#  Epoch 301: iteration 19/19
# Epoch 301 --> loss:0.0736, acc:97.70%, val_loss:2.1644, val_acc:52.50%
#  Epoch 302: iteration 19/19
# Epoch 302 --> loss:0.1235, acc:95.56%, val_loss:2.5219, val_acc:46.25%
#  Epoch 303: iteration 19/19
# Epoch 303 --> loss:0.0475, acc:99.01%, val_loss:3.9724, val_acc:41.25%
#  Epoch 304: iteration 19/19
# Epoch 304 --> loss:0.0327, acc:99.67%, val_loss:3.6952, val_acc:40.00%
#  Epoch 305: iteration 19/19
# Epoch 305 --> loss:0.0345, acc:99.34%, val_loss:2.6596, val_acc:47.50%
#  Epoch 306: iteration 19/19
# Epoch 306 --> loss:0.0341, acc:99.67%, val_loss:2.4454, val_acc:48.75%
#  Epoch 307: iteration 19/19
# Epoch 307 --> loss:0.0334, acc:99.51%, val_loss:2.4862, val_acc:50.00%
#  Epoch 308: iteration 19/19
# Epoch 308 --> loss:0.0289, acc:99.51%, val_loss:3.4569, val_acc:43.75%
#  Epoch 309: iteration 19/19
# Epoch 309 --> loss:0.0237, acc:99.84%, val_loss:3.4856, val_acc:42.50%
#  Epoch 310: iteration 19/19
# Epoch 310 --> loss:0.0256, acc:99.84%, val_loss:2.2656, val_acc:52.50%
#  Epoch 311: iteration 19/19
# Epoch 311 --> loss:0.0231, acc:99.67%, val_loss:2.0332, val_acc:50.00%
#  Epoch 312: iteration 19/19
# Epoch 312 --> loss:0.0207, acc:99.84%, val_loss:3.1231, val_acc:50.00%
#  Epoch 313: iteration 19/19
# Epoch 313 --> loss:0.0154, acc:99.67%, val_loss:2.4849, val_acc:43.75%
#  Epoch 314: iteration 19/19
# Epoch 314 --> loss:0.0248, acc:99.67%, val_loss:2.5657, val_acc:51.25%
#  Epoch 315: iteration 19/19
# Epoch 315 --> loss:0.0879, acc:97.04%, val_loss:3.9576, val_acc:41.25%
#  Epoch 316: iteration 19/19
# Epoch 316 --> loss:0.0850, acc:96.88%, val_loss:3.2224, val_acc:43.75%
#  Epoch 317: iteration 19/19
# Epoch 317 --> loss:0.0623, acc:98.03%, val_loss:3.3759, val_acc:47.50%
#  Epoch 318: iteration 19/19
# Epoch 318 --> loss:0.0649, acc:97.86%, val_loss:3.0456, val_acc:43.75%
#  Epoch 319: iteration 19/19
# Epoch 319 --> loss:0.0358, acc:99.34%, val_loss:2.6091, val_acc:43.75%
#  Epoch 320: iteration 19/19
# Epoch 320 --> loss:0.0332, acc:99.51%, val_loss:3.6023, val_acc:43.75%
#  Epoch 321: iteration 19/19
# Epoch 321 --> loss:0.0192, acc:99.84%, val_loss:2.6645, val_acc:45.00%
#  Epoch 322: iteration 19/19
# Epoch 322 --> loss:0.0178, acc:100.00%, val_loss:3.1398, val_acc:45.00%
#  Epoch 323: iteration 19/19
# Epoch 323 --> loss:0.0128, acc:100.00%, val_loss:2.7783, val_acc:48.75%
#  Epoch 324: iteration 19/19
# Epoch 324 --> loss:0.0137, acc:100.00%, val_loss:2.6267, val_acc:46.25%
#  Epoch 325: iteration 19/19
# Epoch 325 --> loss:0.0165, acc:100.00%, val_loss:2.1215, val_acc:50.00%
#  Epoch 326: iteration 19/19
# Epoch 326 --> loss:0.0187, acc:99.84%, val_loss:2.9253, val_acc:45.00%
#  Epoch 327: iteration 19/19
# Epoch 327 --> loss:0.0199, acc:99.67%, val_loss:3.4426, val_acc:43.75%
#  Epoch 328: iteration 19/19
# Epoch 328 --> loss:0.0198, acc:99.67%, val_loss:3.4410, val_acc:41.25%
#  Epoch 329: iteration 19/19
# Epoch 329 --> loss:0.0176, acc:99.84%, val_loss:2.4627, val_acc:48.75%
#  Epoch 330: iteration 19/19
# Epoch 330 --> loss:0.0195, acc:99.67%, val_loss:2.8035, val_acc:48.75%
#  Epoch 331: iteration 19/19
# Epoch 331 --> loss:0.0303, acc:99.51%, val_loss:1.9834, val_acc:52.50%
#  Epoch 332: iteration 19/19
# Epoch 332 --> loss:0.0173, acc:100.00%, val_loss:3.2458, val_acc:43.75%
#  Epoch 333: iteration 19/19
# Epoch 333 --> loss:0.0316, acc:99.51%, val_loss:2.7604, val_acc:46.25%
#  Epoch 334: iteration 19/19
# Epoch 334 --> loss:0.0298, acc:99.51%, val_loss:3.3714, val_acc:46.25%
#  Epoch 335: iteration 19/19
# Epoch 335 --> loss:0.0158, acc:100.00%, val_loss:3.6968, val_acc:41.25%
#  Epoch 336: iteration 19/19
# Epoch 336 --> loss:0.0157, acc:100.00%, val_loss:3.0402, val_acc:45.00%
#  Epoch 337: iteration 19/19
# Epoch 337 --> loss:0.0122, acc:100.00%, val_loss:2.7450, val_acc:47.50%
#  Epoch 338: iteration 19/19
# Epoch 338 --> loss:0.0100, acc:100.00%, val_loss:2.3205, val_acc:47.50%
#  Epoch 339: iteration 19/19
# Epoch 339 --> loss:0.0223, acc:99.67%, val_loss:2.5309, val_acc:45.00%
#  Epoch 340: iteration 19/19
# Epoch 340 --> loss:0.0140, acc:100.00%, val_loss:2.3869, val_acc:47.50%
#  Epoch 341: iteration 19/19
# Epoch 341 --> loss:0.0121, acc:100.00%, val_loss:3.6411, val_acc:45.00%
#  Epoch 342: iteration 19/19
# Epoch 342 --> loss:0.0161, acc:99.67%, val_loss:3.6409, val_acc:38.75%
#  Epoch 343: iteration 19/19
# Epoch 343 --> loss:0.0124, acc:100.00%, val_loss:2.7241, val_acc:46.25%
#  Epoch 344: iteration 19/19
# Epoch 344 --> loss:0.0113, acc:100.00%, val_loss:3.2267, val_acc:42.50%
#  Epoch 345: iteration 19/19
# Epoch 345 --> loss:0.0131, acc:99.84%, val_loss:3.1240, val_acc:47.50%
#  Epoch 346: iteration 19/19
# Epoch 346 --> loss:0.0123, acc:100.00%, val_loss:2.2828, val_acc:48.75%
#  Epoch 347: iteration 19/19
# Epoch 347 --> loss:0.0084, acc:100.00%, val_loss:3.0028, val_acc:43.75%
#  Epoch 348: iteration 19/19
# Epoch 348 --> loss:0.0112, acc:99.84%, val_loss:2.7659, val_acc:46.25%
#  Epoch 349: iteration 19/19
# Epoch 349 --> loss:0.0154, acc:99.84%, val_loss:3.5397, val_acc:41.25%
#  Epoch 350: iteration 19/19
# Epoch 350 --> loss:0.0224, acc:99.51%, val_loss:2.6857, val_acc:46.25%
#  Epoch 351: iteration 19/19
# Epoch 351 --> loss:0.0417, acc:98.85%, val_loss:2.3796, val_acc:46.25%
#  Epoch 352: iteration 19/19
# Epoch 352 --> loss:0.0239, acc:99.84%, val_loss:2.7227, val_acc:50.00%
#  Epoch 353: iteration 19/19
# Epoch 353 --> loss:0.0222, acc:99.84%, val_loss:3.0176, val_acc:41.25%
#  Epoch 354: iteration 19/19
# Epoch 354 --> loss:0.0271, acc:99.51%, val_loss:1.9951, val_acc:53.75%
#  Epoch 355: iteration 19/19
# Epoch 355 --> loss:0.0381, acc:99.34%, val_loss:3.6448, val_acc:40.00%
#  Epoch 356: iteration 19/19
# Epoch 356 --> loss:0.0165, acc:100.00%, val_loss:2.0682, val_acc:51.25%
#  Epoch 357: iteration 19/19
# Epoch 357 --> loss:0.0124, acc:100.00%, val_loss:1.8363, val_acc:53.75%
#  Epoch 358: iteration 19/19
# Epoch 358 --> loss:0.0387, acc:98.68%, val_loss:4.2314, val_acc:41.25%
#  Epoch 359: iteration 19/19
# Epoch 359 --> loss:0.2198, acc:91.94%, val_loss:3.0094, val_acc:51.25%
#  Epoch 360: iteration 19/19
# Epoch 360 --> loss:0.1371, acc:94.90%, val_loss:3.2038, val_acc:42.50%
#  Epoch 361: iteration 19/19
# Epoch 361 --> loss:0.2061, acc:93.59%, val_loss:3.3111, val_acc:42.50%
#  Epoch 362: iteration 19/19
# Epoch 362 --> loss:0.0947, acc:97.53%, val_loss:4.4050, val_acc:42.50%
#  Epoch 363: iteration 19/19
# Epoch 363 --> loss:0.0311, acc:99.51%, val_loss:2.9944, val_acc:41.25%
#  Epoch 364: iteration 19/19
# Epoch 364 --> loss:0.0357, acc:99.34%, val_loss:2.8521, val_acc:47.50%
#  Epoch 365: iteration 19/19
# Epoch 365 --> loss:0.0268, acc:99.84%, val_loss:3.1923, val_acc:42.50%
#  Epoch 366: iteration 19/19
# Epoch 366 --> loss:0.0169, acc:100.00%, val_loss:3.1483, val_acc:50.00%
#  Epoch 367: iteration 19/19
# Epoch 367 --> loss:0.0206, acc:99.51%, val_loss:3.1030, val_acc:43.75%
#  Epoch 368: iteration 19/19
# Epoch 368 --> loss:0.0207, acc:99.84%, val_loss:3.2268, val_acc:42.50%
#  Epoch 369: iteration 19/19
# Epoch 369 --> loss:0.0202, acc:99.67%, val_loss:2.7203, val_acc:45.00%
#  Epoch 370: iteration 19/19
# Epoch 370 --> loss:0.0451, acc:98.19%, val_loss:4.5386, val_acc:38.75%
#  Epoch 371: iteration 19/19
# Epoch 371 --> loss:0.0508, acc:98.19%, val_loss:3.0705, val_acc:38.75%
#  Epoch 372: iteration 19/19
# Epoch 372 --> loss:0.0457, acc:98.68%, val_loss:4.3717, val_acc:36.25%
#  Epoch 373: iteration 19/19
# Epoch 373 --> loss:0.0241, acc:99.84%, val_loss:2.8770, val_acc:46.25%
#  Epoch 374: iteration 19/19
# Epoch 374 --> loss:0.0266, acc:99.18%, val_loss:2.5418, val_acc:42.50%
#  Epoch 375: iteration 19/19
# Epoch 375 --> loss:0.0124, acc:100.00%, val_loss:2.8325, val_acc:47.50%
#  Epoch 376: iteration 19/19
# Epoch 376 --> loss:0.0113, acc:100.00%, val_loss:2.7923, val_acc:45.00%
#  Epoch 377: iteration 19/19
# Epoch 377 --> loss:0.0133, acc:99.84%, val_loss:2.2161, val_acc:50.00%
#  Epoch 378: iteration 19/19
# Epoch 378 --> loss:0.0120, acc:100.00%, val_loss:2.9244, val_acc:45.00%
#  Epoch 379: iteration 19/19
# Epoch 379 --> loss:0.0110, acc:100.00%, val_loss:2.6040, val_acc:47.50%
#  Epoch 380: iteration 19/19
# Epoch 380 --> loss:0.0125, acc:100.00%, val_loss:1.9678, val_acc:60.00%
#  Epoch 381: iteration 19/19
# Epoch 381 --> loss:0.0104, acc:100.00%, val_loss:3.0120, val_acc:43.75%
#  Epoch 382: iteration 19/19
# Epoch 382 --> loss:0.0095, acc:100.00%, val_loss:2.8075, val_acc:47.50%
#  Epoch 383: iteration 19/19
# Epoch 383 --> loss:0.0180, acc:99.51%, val_loss:2.3553, val_acc:55.00%
#  Epoch 384: iteration 19/19
# Epoch 384 --> loss:0.0142, acc:100.00%, val_loss:2.5687, val_acc:47.50%
#  Epoch 385: iteration 19/19
# Epoch 385 --> loss:0.0082, acc:100.00%, val_loss:2.7370, val_acc:50.00%
#  Epoch 386: iteration 19/19
# Epoch 386 --> loss:0.0094, acc:100.00%, val_loss:2.1714, val_acc:55.00%
#  Epoch 387: iteration 19/19
# Epoch 387 --> loss:0.0089, acc:100.00%, val_loss:2.5334, val_acc:48.75%
#  Epoch 388: iteration 19/19
# Epoch 388 --> loss:0.0075, acc:100.00%, val_loss:2.3292, val_acc:50.00%
#  Epoch 389: iteration 19/19
# Epoch 389 --> loss:0.0095, acc:100.00%, val_loss:2.6398, val_acc:48.75%
#  Epoch 390: iteration 19/19
# Epoch 390 --> loss:0.0139, acc:99.84%, val_loss:2.0154, val_acc:48.75%
#  Epoch 391: iteration 19/19
# Epoch 391 --> loss:0.0104, acc:100.00%, val_loss:2.5905, val_acc:48.75%
#  Epoch 392: iteration 19/19
# Epoch 392 --> loss:0.0074, acc:100.00%, val_loss:2.4974, val_acc:50.00%
#  Epoch 393: iteration 19/19
# Epoch 393 --> loss:0.0106, acc:100.00%, val_loss:2.7622, val_acc:47.50%
#  Epoch 394: iteration 19/19
# Epoch 394 --> loss:0.0078, acc:100.00%, val_loss:2.5979, val_acc:48.75%
#  Epoch 395: iteration 19/19
# Epoch 395 --> loss:0.0107, acc:99.84%, val_loss:2.9163, val_acc:46.25%
#  Epoch 396: iteration 19/19
# Epoch 396 --> loss:0.0081, acc:100.00%, val_loss:2.9182, val_acc:43.75%
#  Epoch 397: iteration 19/19
# Epoch 397 --> loss:0.0068, acc:100.00%, val_loss:2.0984, val_acc:50.00%
#  Epoch 398: iteration 19/19
# Epoch 398 --> loss:0.0067, acc:100.00%, val_loss:2.4458, val_acc:46.25%
#  Epoch 399: iteration 19/19
# Epoch 399 --> loss:0.0117, acc:99.84%, val_loss:1.8686, val_acc:52.50%
#  Epoch 400: iteration 19/19
# Epoch 400 --> loss:0.0073, acc:100.00%, val_loss:2.4844, val_acc:50.00%
#  Epoch 401: iteration 19/19
# Epoch 401 --> loss:0.0065, acc:100.00%, val_loss:2.4162, val_acc:52.50%
#  Epoch 402: iteration 19/19
# Epoch 402 --> loss:0.0059, acc:100.00%, val_loss:2.4810, val_acc:52.50%
#  Epoch 403: iteration 19/19
# Epoch 403 --> loss:0.0102, acc:100.00%, val_loss:3.0513, val_acc:42.50%
#  Epoch 404: iteration 19/19
# Epoch 404 --> loss:0.0152, acc:100.00%, val_loss:3.1873, val_acc:45.00%
#  Epoch 405: iteration 19/19
# Epoch 405 --> loss:0.0079, acc:100.00%, val_loss:2.5199, val_acc:48.75%
#  Epoch 406: iteration 19/19
# Epoch 406 --> loss:0.0078, acc:100.00%, val_loss:2.4710, val_acc:47.50%
#  Epoch 407: iteration 19/19
# Epoch 407 --> loss:0.0073, acc:100.00%, val_loss:2.3506, val_acc:47.50%
#  Epoch 408: iteration 19/19
# Epoch 408 --> loss:0.0080, acc:100.00%, val_loss:2.6987, val_acc:48.75%
#  Epoch 409: iteration 19/19
# Epoch 409 --> loss:0.0076, acc:100.00%, val_loss:2.4661, val_acc:46.25%
#  Epoch 410: iteration 19/19
# Epoch 410 --> loss:0.0083, acc:100.00%, val_loss:2.6076, val_acc:47.50%
#  Epoch 411: iteration 19/19
# Epoch 411 --> loss:0.0060, acc:100.00%, val_loss:2.4264, val_acc:50.00%
#  Epoch 412: iteration 19/19
# Epoch 412 --> loss:0.0063, acc:100.00%, val_loss:2.2169, val_acc:47.50%
#  Epoch 413: iteration 19/19
# Epoch 413 --> loss:0.0087, acc:100.00%, val_loss:2.1715, val_acc:50.00%
#  Epoch 414: iteration 19/19
# Epoch 414 --> loss:0.0111, acc:100.00%, val_loss:2.3163, val_acc:48.75%
#  Epoch 415: iteration 19/19
# Epoch 415 --> loss:0.0080, acc:100.00%, val_loss:2.8503, val_acc:50.00%
#  Epoch 416: iteration 19/19
# Epoch 416 --> loss:0.0171, acc:99.67%, val_loss:2.1369, val_acc:50.00%
#  Epoch 417: iteration 19/19
# Epoch 417 --> loss:0.0170, acc:99.84%, val_loss:2.5268, val_acc:43.75%
#  Epoch 418: iteration 19/19
# Epoch 418 --> loss:0.0412, acc:98.52%, val_loss:2.0334, val_acc:50.00%
#  Epoch 419: iteration 19/19
# Epoch 419 --> loss:0.0637, acc:98.36%, val_loss:2.8210, val_acc:43.75%
#  Epoch 420: iteration 19/19
# Epoch 420 --> loss:0.0569, acc:98.52%, val_loss:1.7074, val_acc:53.75%
#  Epoch 421: iteration 19/19
# Epoch 421 --> loss:0.1606, acc:95.07%, val_loss:2.9130, val_acc:42.50%
#  Epoch 422: iteration 19/19
# Epoch 422 --> loss:0.1506, acc:94.57%, val_loss:3.5223, val_acc:38.75%
#  Epoch 423: iteration 19/19
# Epoch 423 --> loss:0.0506, acc:98.68%, val_loss:2.1011, val_acc:46.25%
#  Epoch 424: iteration 19/19
# Epoch 424 --> loss:0.0220, acc:99.84%, val_loss:2.6490, val_acc:42.50%
#  Epoch 425: iteration 19/19
# Epoch 425 --> loss:0.0276, acc:99.84%, val_loss:3.0961, val_acc:43.75%
#  Epoch 426: iteration 19/19
# Epoch 426 --> loss:0.0740, acc:97.37%, val_loss:3.3986, val_acc:45.00%
#  Epoch 427: iteration 19/19
# Epoch 427 --> loss:0.0808, acc:97.37%, val_loss:3.1401, val_acc:42.50%
#  Epoch 428: iteration 19/19
# Epoch 428 --> loss:0.0854, acc:97.20%, val_loss:4.2946, val_acc:38.75%
#  Epoch 429: iteration 19/19
# Epoch 429 --> loss:0.0401, acc:99.34%, val_loss:2.4294, val_acc:43.75%
#  Epoch 430: iteration 19/19
# Epoch 430 --> loss:0.0531, acc:98.85%, val_loss:3.8520, val_acc:38.75%
#  Epoch 431: iteration 19/19
# Epoch 431 --> loss:0.1673, acc:94.08%, val_loss:1.7593, val_acc:56.25%
#  Epoch 432: iteration 19/19
# Epoch 432 --> loss:0.0592, acc:99.01%, val_loss:3.4819, val_acc:35.00%
#  Epoch 433: iteration 19/19
# Epoch 433 --> loss:0.0249, acc:99.84%, val_loss:3.1069, val_acc:41.25%
#  Epoch 434: iteration 19/19
# Epoch 434 --> loss:0.0416, acc:98.85%, val_loss:3.6582, val_acc:38.75%
#  Epoch 435: iteration 19/19
# Epoch 435 --> loss:0.0249, acc:99.51%, val_loss:2.0047, val_acc:47.50%
#  Epoch 436: iteration 19/19
# Epoch 436 --> loss:0.0152, acc:100.00%, val_loss:2.4254, val_acc:43.75%
#  Epoch 437: iteration 19/19
# Epoch 437 --> loss:0.0152, acc:100.00%, val_loss:2.6960, val_acc:40.00%
#  Epoch 438: iteration 19/19
# Epoch 438 --> loss:0.0240, acc:99.34%, val_loss:2.7892, val_acc:42.50%
#  Epoch 439: iteration 19/19
# Epoch 439 --> loss:0.0264, acc:99.51%, val_loss:3.9812, val_acc:36.25%
#  Epoch 440: iteration 19/19
# Epoch 440 --> loss:0.0171, acc:99.84%, val_loss:2.0234, val_acc:47.50%
#  Epoch 441: iteration 19/19
# Epoch 441 --> loss:0.0106, acc:100.00%, val_loss:2.4563, val_acc:47.50%
#  Epoch 442: iteration 19/19
# Epoch 442 --> loss:0.0126, acc:100.00%, val_loss:2.0021, val_acc:48.75%
#  Epoch 443: iteration 19/19
# Epoch 443 --> loss:0.0180, acc:99.51%, val_loss:1.7276, val_acc:53.75%
#  Epoch 444: iteration 19/19
# Epoch 444 --> loss:0.0140, acc:99.84%, val_loss:2.5779, val_acc:45.00%
#  Epoch 445: iteration 19/19
# Epoch 445 --> loss:0.0135, acc:99.84%, val_loss:1.6089, val_acc:56.25%
#  Epoch 446: iteration 19/19
# Epoch 446 --> loss:0.0145, acc:100.00%, val_loss:2.8467, val_acc:42.50%
#  Epoch 447: iteration 19/19
# Epoch 447 --> loss:0.0110, acc:100.00%, val_loss:2.3238, val_acc:43.75%
#  Epoch 448: iteration 19/19
# Epoch 448 --> loss:0.0133, acc:100.00%, val_loss:3.1124, val_acc:41.25%
#  Epoch 449: iteration 19/19
# Epoch 449 --> loss:0.0128, acc:100.00%, val_loss:2.6359, val_acc:40.00%
#  Epoch 450: iteration 19/19
# Epoch 450 --> loss:0.0198, acc:99.84%, val_loss:3.0715, val_acc:33.75%
#  Epoch 451: iteration 19/19
# Epoch 451 --> loss:0.0113, acc:100.00%, val_loss:2.6884, val_acc:42.50%
#  Epoch 452: iteration 19/19
# Epoch 452 --> loss:0.0121, acc:100.00%, val_loss:2.4704, val_acc:41.25%
#  Epoch 453: iteration 19/19
# Epoch 453 --> loss:0.0233, acc:99.84%, val_loss:2.4768, val_acc:43.75%
#  Epoch 454: iteration 19/19
# Epoch 454 --> loss:0.0946, acc:96.71%, val_loss:3.8116, val_acc:40.00%
#  Epoch 455: iteration 19/19
# Epoch 455 --> loss:0.0873, acc:97.20%, val_loss:2.3778, val_acc:47.50%
#  Epoch 456: iteration 19/19
# Epoch 456 --> loss:0.1358, acc:95.56%, val_loss:4.1645, val_acc:36.25%
#  Epoch 457: iteration 19/19
# Epoch 457 --> loss:0.3922, acc:87.99%, val_loss:3.6846, val_acc:35.00%
#  Epoch 458: iteration 19/19
# Epoch 458 --> loss:0.1875, acc:93.26%, val_loss:1.8860, val_acc:53.75%
#  Epoch 459: iteration 19/19
# Epoch 459 --> loss:0.0600, acc:98.68%, val_loss:1.8139, val_acc:48.75%
#  Epoch 460: iteration 19/19
# Epoch 460 --> loss:0.0595, acc:98.36%, val_loss:3.2041, val_acc:37.50%
#  Epoch 461: iteration 19/19
# Epoch 461 --> loss:0.0401, acc:98.85%, val_loss:3.0859, val_acc:41.25%
#  Epoch 462: iteration 19/19
# Epoch 462 --> loss:0.0357, acc:99.18%, val_loss:1.8773, val_acc:52.50%
#  Epoch 463: iteration 19/19
# Epoch 463 --> loss:0.0259, acc:100.00%, val_loss:2.7897, val_acc:41.25%
#  Epoch 464: iteration 19/19
# Epoch 464 --> loss:0.0898, acc:97.20%, val_loss:1.3904, val_acc:65.00%
#  Epoch 465: iteration 19/19
# Epoch 465 --> loss:0.0900, acc:97.04%, val_loss:2.9574, val_acc:38.75%
#  Epoch 466: iteration 19/19
# Epoch 466 --> loss:0.0345, acc:99.18%, val_loss:2.5718, val_acc:43.75%
#  Epoch 467: iteration 19/19
# Epoch 467 --> loss:0.0217, acc:99.67%, val_loss:2.4349, val_acc:48.75%
#  Epoch 468: iteration 19/19
# Epoch 468 --> loss:0.0210, acc:99.67%, val_loss:2.3846, val_acc:47.50%
#  Epoch 469: iteration 19/19
# Epoch 469 --> loss:0.0454, acc:98.85%, val_loss:3.7711, val_acc:41.25%
#  Epoch 470: iteration 19/19
# Epoch 470 --> loss:0.0457, acc:98.85%, val_loss:2.1408, val_acc:51.25%
#  Epoch 471: iteration 19/19
# Epoch 471 --> loss:0.0296, acc:99.51%, val_loss:2.3775, val_acc:48.75%
#  Epoch 472: iteration 19/19
# Epoch 472 --> loss:0.0253, acc:99.67%, val_loss:2.6518, val_acc:45.00%
#  Epoch 473: iteration 19/19
# Epoch 473 --> loss:0.0168, acc:100.00%, val_loss:2.2574, val_acc:45.00%
#  Epoch 474: iteration 19/19
# Epoch 474 --> loss:0.0110, acc:100.00%, val_loss:3.0382, val_acc:41.25%
#  Epoch 475: iteration 19/19
# Epoch 475 --> loss:0.0139, acc:100.00%, val_loss:2.4615, val_acc:45.00%
#  Epoch 476: iteration 19/19
# Epoch 476 --> loss:0.0149, acc:99.84%, val_loss:2.1216, val_acc:48.75%
#  Epoch 477: iteration 19/19
# Epoch 477 --> loss:0.0171, acc:99.67%, val_loss:2.5095, val_acc:47.50%
#  Epoch 478: iteration 19/19
# Epoch 478 --> loss:0.0114, acc:100.00%, val_loss:2.3434, val_acc:45.00%
#  Epoch 479: iteration 19/19
# Epoch 479 --> loss:0.0165, acc:100.00%, val_loss:2.2966, val_acc:46.25%
#  Epoch 480: iteration 19/19
# Epoch 480 --> loss:0.0266, acc:99.51%, val_loss:2.5796, val_acc:43.75%
#  Epoch 481: iteration 19/19
# Epoch 481 --> loss:0.0326, acc:99.51%, val_loss:1.8843, val_acc:51.25%
#  Epoch 482: iteration 19/19
# Epoch 482 --> loss:0.0169, acc:100.00%, val_loss:2.2357, val_acc:45.00%
#  Epoch 483: iteration 19/19
# Epoch 483 --> loss:0.0136, acc:100.00%, val_loss:2.3079, val_acc:46.25%
#  Epoch 484: iteration 19/19
# Epoch 484 --> loss:0.0126, acc:100.00%, val_loss:2.3515, val_acc:47.50%
#  Epoch 485: iteration 19/19
# Epoch 485 --> loss:0.1687, acc:95.72%, val_loss:4.7839, val_acc:38.75%
#  Epoch 486: iteration 19/19
# ...
#  Epoch 540: iteration 19/19
# Epoch 540 --> loss:0.0077, acc:100.00%, val_loss:2.3876, val_acc:42.50%
#  Epoch 541: iteration 19/19
# Epoch 541 --> loss:0.0092, acc:100.00%, val_loss:2.3109, val_acc:41.25%
#  Epoch 542: iteration 19/19
# Epoch 542 --> loss:0.0109, acc:100.00%, val_loss:2.3455, val_acc:42.50%
#  Epoch 543: iteration 19/19
# Epoch 543 --> loss:0.0083, acc:100.00%, val_loss:2.1159, val_acc:46.25%
#  Epoch 544: iteration 19/19
# Epoch 544 --> loss:0.0077, acc:100.00%, val_loss:2.2804, val_acc:45.00%
#  Epoch 545: iteration 19/19
# Epoch 545 --> loss:0.0081, acc:100.00%, val_loss:2.7026, val_acc:38.75%
#  Epoch 546: iteration 19/19
# Epoch 546 --> loss:0.0071, acc:100.00%, val_loss:2.4184, val_acc:40.00%
#  Epoch 547: iteration 19/19
# Epoch 547 --> loss:0.0077, acc:100.00%, val_loss:2.2082, val_acc:45.00%
#  Epoch 548: iteration 19/19
# Epoch 548 --> loss:0.0073, acc:100.00%, val_loss:2.1060, val_acc:50.00%
#  Epoch 549: iteration 19/19
# Epoch 549 --> loss:0.0069, acc:100.00%, val_loss:2.2155, val_acc:43.75%
#  Epoch 550: iteration 19/19
# Epoch 550 --> loss:0.0082, acc:100.00%, val_loss:2.3018, val_acc:40.00%
#  Epoch 551: iteration 19/19
# Epoch 551 --> loss:0.0056, acc:100.00%, val_loss:2.1720, val_acc:42.50%
#  Epoch 552: iteration 19/19
# Epoch 552 --> loss:0.0052, acc:100.00%, val_loss:2.1881, val_acc:41.25%
#  Epoch 553: iteration 19/19
# Epoch 553 --> loss:0.0078, acc:100.00%, val_loss:2.4275, val_acc:42.50%
#  Epoch 554: iteration 19/19
# Epoch 554 --> loss:0.0053, acc:100.00%, val_loss:2.3487, val_acc:42.50%
#  Epoch 555: iteration 19/19
# Epoch 555 --> loss:0.0079, acc:100.00%, val_loss:2.4381, val_acc:42.50%
#  Epoch 556: iteration 19/19
# Epoch 556 --> loss:0.0069, acc:100.00%, val_loss:2.2731, val_acc:43.75%
#  Epoch 557: iteration 19/19
# Epoch 557 --> loss:0.0099, acc:100.00%, val_loss:2.4890, val_acc:41.25%
#  Epoch 558: iteration 19/19
# Epoch 558 --> loss:0.0064, acc:100.00%, val_loss:2.2651, val_acc:40.00%
#  Epoch 559: iteration 19/19
# Epoch 559 --> loss:0.0064, acc:100.00%, val_loss:2.1642, val_acc:42.50%
#  Epoch 560: iteration 19/19
# Epoch 560 --> loss:0.0116, acc:99.84%, val_loss:2.1813, val_acc:45.00%
#  Epoch 561: iteration 19/19
# Epoch 561 --> loss:0.0095, acc:99.84%, val_loss:2.7800, val_acc:38.75%
#  Epoch 562: iteration 19/19
# Epoch 562 --> loss:0.0115, acc:99.84%, val_loss:2.1794, val_acc:42.50%
#  Epoch 563: iteration 19/19
# Epoch 563 --> loss:0.0085, acc:99.84%, val_loss:2.1585, val_acc:45.00%
#  Epoch 564: iteration 19/19
# Epoch 564 --> loss:0.0083, acc:100.00%, val_loss:1.9715, val_acc:47.50%
#  Epoch 565: iteration 19/19
# Epoch 565 --> loss:0.0112, acc:99.84%, val_loss:2.3940, val_acc:41.25%
#  Epoch 566: iteration 19/19
# Epoch 566 --> loss:0.0104, acc:100.00%, val_loss:2.6875, val_acc:43.75%
#  Epoch 567: iteration 19/19
# Epoch 567 --> loss:0.0075, acc:100.00%, val_loss:2.3669, val_acc:42.50%
#  Epoch 568: iteration 19/19
# Epoch 568 --> loss:0.0085, acc:100.00%, val_loss:2.2473, val_acc:41.25%
#  Epoch 569: iteration 19/19
# Epoch 569 --> loss:0.0094, acc:100.00%, val_loss:2.0245, val_acc:47.50%
#  Epoch 570: iteration 19/19
# Epoch 570 --> loss:0.0072, acc:100.00%, val_loss:2.2590, val_acc:43.75%
#  Epoch 571: iteration 19/19
# Epoch 571 --> loss:0.0096, acc:100.00%, val_loss:2.8825, val_acc:43.75%
#  Epoch 572: iteration 19/19
# Epoch 572 --> loss:0.0066, acc:100.00%, val_loss:2.0295, val_acc:45.00%
#  Epoch 573: iteration 19/19
# Epoch 573 --> loss:0.0072, acc:100.00%, val_loss:1.9787, val_acc:46.25%
#  Epoch 574: iteration 19/19
# Epoch 574 --> loss:0.0092, acc:99.84%, val_loss:2.1720, val_acc:43.75%
#  Epoch 575: iteration 19/19
# Epoch 575 --> loss:0.0062, acc:100.00%, val_loss:2.0201, val_acc:43.75%
#  Epoch 576: iteration 19/19
# Epoch 576 --> loss:0.0077, acc:100.00%, val_loss:2.0195, val_acc:41.25%
#  Epoch 577: iteration 19/19
# Epoch 577 --> loss:0.0059, acc:100.00%, val_loss:2.2853, val_acc:45.00%
#  Epoch 578: iteration 19/19
# Epoch 578 --> loss:0.0061, acc:100.00%, val_loss:2.3870, val_acc:41.25%
#  Epoch 579: iteration 19/19
# Epoch 579 --> loss:0.0076, acc:100.00%, val_loss:2.1820, val_acc:45.00%
#  Epoch 580: iteration 19/19
# Epoch 580 --> loss:0.0066, acc:100.00%, val_loss:1.9676, val_acc:45.00%
#  Epoch 581: iteration 19/19
# Epoch 581 --> loss:0.0054, acc:100.00%, val_loss:2.3327, val_acc:40.00%
#  Epoch 582: iteration 19/19
# Epoch 582 --> loss:0.0065, acc:100.00%, val_loss:2.2942, val_acc:46.25%
#  Epoch 583: iteration 19/19
# Epoch 583 --> loss:0.0068, acc:100.00%, val_loss:2.0065, val_acc:42.50%
#  Epoch 584: iteration 19/19
# Epoch 584 --> loss:0.0068, acc:100.00%, val_loss:2.3173, val_acc:38.75%
#  Epoch 585: iteration 19/19
# Epoch 585 --> loss:0.0064, acc:100.00%, val_loss:2.0929, val_acc:43.75%
#  Epoch 586: iteration 19/19
# Epoch 586 --> loss:0.0060, acc:100.00%, val_loss:1.9755, val_acc:43.75%
#  Epoch 587: iteration 19/19
# Epoch 587 --> loss:0.0069, acc:100.00%, val_loss:2.0446, val_acc:41.25%
#  Epoch 588: iteration 19/19
# Epoch 588 --> loss:0.0067, acc:100.00%, val_loss:2.1978, val_acc:46.25%
#  Epoch 589: iteration 19/19
# Epoch 589 --> loss:0.0083, acc:100.00%, val_loss:2.2194, val_acc:40.00%
#  Epoch 590: iteration 19/19
# Epoch 590 --> loss:0.0074, acc:100.00%, val_loss:2.1276, val_acc:45.00%
#  Epoch 591: iteration 19/19
# Epoch 591 --> loss:0.0062, acc:100.00%, val_loss:2.0608, val_acc:46.25%
#  Epoch 592: iteration 19/19
# Epoch 592 --> loss:0.0074, acc:100.00%, val_loss:2.0749, val_acc:38.75%
#  Epoch 593: iteration 19/19
# Epoch 593 --> loss:0.0067, acc:100.00%, val_loss:1.9323, val_acc:42.50%
#  Epoch 594: iteration 19/19
# Epoch 594 --> loss:0.0054, acc:100.00%, val_loss:2.0512, val_acc:47.50%
#  Epoch 595: iteration 19/19
# Epoch 595 --> loss:0.0065, acc:100.00%, val_loss:2.5559, val_acc:40.00%
#  Epoch 596: iteration 19/19
# Epoch 596 --> loss:0.0074, acc:100.00%, val_loss:1.8398, val_acc:50.00%
#  Epoch 597: iteration 19/19
# Epoch 597 --> loss:0.0062, acc:100.00%, val_loss:2.0813, val_acc:43.75%
#  Epoch 598: iteration 19/19
# Epoch 598 --> loss:0.0105, acc:99.84%, val_loss:2.5402, val_acc:40.00%
#  Epoch 599: iteration 19/19
# Epoch 599 --> loss:0.0070, acc:100.00%, val_loss:2.1776, val_acc:38.75%
#  Epoch 600: iteration 19/19
# Epoch 600 --> loss:0.0064, acc:100.00%, val_loss:2.0832, val_acc:41.25%
#  Epoch 601: iteration 19/19
# Epoch 601 --> loss:0.0063, acc:100.00%, val_loss:1.9735, val_acc:42.50%
#  Epoch 602: iteration 19/19
# Epoch 602 --> loss:0.0058, acc:100.00%, val_loss:1.7881, val_acc:46.25%
#  Epoch 603: iteration 19/19
# Epoch 603 --> loss:0.0056, acc:100.00%, val_loss:2.3098, val_acc:42.50%
#  Epoch 604: iteration 19/19
# Epoch 604 --> loss:0.0059, acc:100.00%, val_loss:2.5375, val_acc:41.25%
#  Epoch 605: iteration 19/19
# Epoch 605 --> loss:0.0062, acc:100.00%, val_loss:2.7408, val_acc:37.50%
#  Epoch 606: iteration 19/19
# Epoch 606 --> loss:0.0076, acc:100.00%, val_loss:1.7222, val_acc:46.25%
#  Epoch 607: iteration 19/19
# Epoch 607 --> loss:0.0114, acc:100.00%, val_loss:2.7437, val_acc:40.00%
#  Epoch 608: iteration 19/19
# Epoch 608 --> loss:0.0080, acc:100.00%, val_loss:2.3885, val_acc:43.75%
#  Epoch 609: iteration 19/19
# Epoch 609 --> loss:0.0054, acc:100.00%, val_loss:2.0799, val_acc:46.25%
#  Epoch 610: iteration 19/19
# Epoch 610 --> loss:0.0055, acc:100.00%, val_loss:1.8131, val_acc:42.50%
#  Epoch 611: iteration 19/19
# Epoch 611 --> loss:0.0055, acc:100.00%, val_loss:2.2462, val_acc:40.00%
#  Epoch 612: iteration 19/19
# Epoch 612 --> loss:0.0080, acc:100.00%, val_loss:2.3482, val_acc:41.25%
#  Epoch 613: iteration 19/19
# Epoch 613 --> loss:0.0083, acc:99.84%, val_loss:2.1964, val_acc:40.00%
#  Epoch 614: iteration 19/19
# Epoch 614 --> loss:0.0074, acc:100.00%, val_loss:2.3064, val_acc:42.50%
#  Epoch 615: iteration 19/19
# Epoch 615 --> loss:0.0061, acc:100.00%, val_loss:2.1748, val_acc:42.50%
#  Epoch 616: iteration 19/19
# Epoch 616 --> loss:0.0062, acc:100.00%, val_loss:2.0938, val_acc:42.50%
#  Epoch 617: iteration 19/19
# Epoch 617 --> loss:0.0070, acc:100.00%, val_loss:2.0229, val_acc:43.75%
#  Epoch 618: iteration 19/19
# Epoch 618 --> loss:0.0052, acc:100.00%, val_loss:1.9485, val_acc:45.00%
#  Epoch 619: iteration 19/19
# Epoch 619 --> loss:0.0057, acc:100.00%, val_loss:2.1700, val_acc:43.75%
#  Epoch 620: iteration 19/19
# Epoch 620 --> loss:0.0070, acc:100.00%, val_loss:2.0103, val_acc:41.25%
#  Epoch 621: iteration 19/19
# Epoch 621 --> loss:0.0053, acc:100.00%, val_loss:2.5982, val_acc:41.25%
#  Epoch 622: iteration 19/19
# Epoch 622 --> loss:0.0066, acc:100.00%, val_loss:2.3928, val_acc:42.50%
#  Epoch 623: iteration 19/19
# Epoch 623 --> loss:0.0058, acc:100.00%, val_loss:2.1302, val_acc:42.50%
#  Epoch 624: iteration 19/19
# Epoch 624 --> loss:0.0066, acc:100.00%, val_loss:1.9145, val_acc:40.00%
#  Epoch 625: iteration 19/19
# Epoch 625 --> loss:0.0074, acc:100.00%, val_loss:2.2281, val_acc:42.50%
#  Epoch 626: iteration 19/19
# Epoch 626 --> loss:0.0055, acc:100.00%, val_loss:2.0409, val_acc:43.75%
#  Epoch 627: iteration 19/19
# Epoch 627 --> loss:0.0064, acc:100.00%, val_loss:2.2057, val_acc:41.25%
#  Epoch 628: iteration 19/19
# Epoch 628 --> loss:0.0049, acc:100.00%, val_loss:2.3787, val_acc:40.00%
#  Epoch 629: iteration 19/19
# Epoch 629 --> loss:0.0064, acc:100.00%, val_loss:2.3809, val_acc:40.00%
#  Epoch 630: iteration 19/19
# Epoch 630 --> loss:0.0069, acc:100.00%, val_loss:1.9103, val_acc:43.75%
#  Epoch 631: iteration 19/19
# Epoch 631 --> loss:0.0071, acc:100.00%, val_loss:1.9140, val_acc:42.50%
#  Epoch 632: iteration 19/19
# Epoch 632 --> loss:0.0125, acc:100.00%, val_loss:1.8974, val_acc:48.75%
#  Epoch 633: iteration 19/19
# Epoch 633 --> loss:0.0113, acc:99.84%, val_loss:1.8603, val_acc:52.50%
#  Epoch 634: iteration 19/19
# Epoch 634 --> loss:0.0186, acc:100.00%, val_loss:1.8025, val_acc:45.00%
#  Epoch 635: iteration 19/19
# Epoch 635 --> loss:0.0103, acc:100.00%, val_loss:1.9962, val_acc:43.75%
#  Epoch 636: iteration 19/19
# Epoch 636 --> loss:0.0139, acc:99.84%, val_loss:2.3020, val_acc:46.25%
#  Epoch 637: iteration 19/19
# Epoch 637 --> loss:0.0182, acc:100.00%, val_loss:2.6587, val_acc:43.75%
#  Epoch 638: iteration 19/19
# Epoch 638 --> loss:0.0118, acc:100.00%, val_loss:2.2107, val_acc:43.75%
#  Epoch 639: iteration 19/19
# Epoch 639 --> loss:0.0102, acc:100.00%, val_loss:1.8849, val_acc:46.25%
#  Epoch 640: iteration 19/19
# Epoch 640 --> loss:0.0095, acc:100.00%, val_loss:1.3827, val_acc:48.75%
#  Epoch 641: iteration 19/19
# Epoch 641 --> loss:0.0134, acc:100.00%, val_loss:2.0594, val_acc:46.25%
#  Epoch 642: iteration 19/19
# Epoch 642 --> loss:0.0076, acc:100.00%, val_loss:1.7841, val_acc:47.50%
#  Epoch 643: iteration 19/19
# Epoch 643 --> loss:0.0104, acc:100.00%, val_loss:1.7750, val_acc:43.75%
#  Epoch 644: iteration 19/19
# Epoch 644 --> loss:0.0084, acc:100.00%, val_loss:2.2236, val_acc:45.00%
#  Epoch 645: iteration 19/19
# Epoch 645 --> loss:0.0075, acc:100.00%, val_loss:2.1120, val_acc:46.25%
#  Epoch 646: iteration 19/19
# Epoch 646 --> loss:0.0098, acc:100.00%, val_loss:1.8176, val_acc:45.00%
#  Epoch 647: iteration 19/19
# Epoch 647 --> loss:0.0064, acc:100.00%, val_loss:2.0505, val_acc:42.50%
#  Epoch 648: iteration 19/19
# Epoch 648 --> loss:0.0078, acc:100.00%, val_loss:1.9533, val_acc:43.75%
#  Epoch 649: iteration 19/19
# Epoch 649 --> loss:0.0114, acc:99.84%, val_loss:1.5880, val_acc:47.50%
#  Epoch 650: iteration 19/19
# Epoch 650 --> loss:0.0404, acc:99.18%, val_loss:2.2839, val_acc:43.75%
#  Epoch 651: iteration 19/19
# Epoch 651 --> loss:0.0217, acc:99.51%, val_loss:2.5529, val_acc:43.75%
#  Epoch 652: iteration 19/19
# Epoch 652 --> loss:0.1332, acc:95.56%, val_loss:2.7328, val_acc:40.00%
#  Epoch 653: iteration 19/19
# Epoch 653 --> loss:0.2935, acc:89.31%, val_loss:3.8533, val_acc:35.00%
#  Epoch 654: iteration 19/19
# Epoch 654 --> loss:0.3712, acc:86.18%, val_loss:3.7121, val_acc:33.75%
#  Epoch 655: iteration 19/19
# Epoch 655 --> loss:0.3513, acc:86.35%, val_loss:5.4641, val_acc:17.50%
#  Epoch 656: iteration 19/19
# Epoch 656 --> loss:1.1741, acc:64.64%, val_loss:6.5459, val_acc:21.25%
#  Epoch 657: iteration 19/19
# Epoch 657 --> loss:0.6039, acc:75.99%, val_loss:1.7448, val_acc:37.50%
#  Epoch 658: iteration 19/19
# Epoch 658 --> loss:0.3930, acc:86.18%, val_loss:2.6719, val_acc:32.50%
#  Epoch 659: iteration 19/19
# Epoch 659 --> loss:0.4312, acc:84.54%, val_loss:3.3827, val_acc:23.75%
#  Epoch 660: iteration 19/19
# Epoch 660 --> loss:0.3083, acc:89.64%, val_loss:2.9869, val_acc:37.50%
#  Epoch 661: iteration 19/19
# Epoch 661 --> loss:0.2194, acc:92.27%, val_loss:1.8946, val_acc:43.75%
#  Epoch 662: iteration 19/19
# Epoch 662 --> loss:0.1270, acc:95.72%, val_loss:1.6755, val_acc:52.50%
#  Epoch 663: iteration 19/19
# Epoch 663 --> loss:0.0836, acc:98.03%, val_loss:1.9463, val_acc:45.00%
#  Epoch 664: iteration 19/19
# Epoch 664 --> loss:0.0484, acc:99.84%, val_loss:1.2172, val_acc:56.25%
#  Epoch 665: iteration 19/19
# Epoch 665 --> loss:0.0412, acc:99.34%, val_loss:1.3751, val_acc:57.50%
#  Epoch 666: iteration 19/19
# Epoch 666 --> loss:0.0383, acc:99.67%, val_loss:1.4825, val_acc:51.25%
#  Epoch 667: iteration 19/19
# Epoch 667 --> loss:0.0623, acc:98.52%, val_loss:1.6377, val_acc:51.25%
#  Epoch 668: iteration 19/19
# Epoch 668 --> loss:0.0301, acc:99.67%, val_loss:1.9830, val_acc:45.00%
#  Epoch 669: iteration 19/19
# Epoch 669 --> loss:0.0253, acc:100.00%, val_loss:1.5827, val_acc:48.75%
#  Epoch 670: iteration 19/19
# Epoch 670 --> loss:0.0229, acc:99.84%, val_loss:2.4968, val_acc:41.25%
#  Epoch 671: iteration 19/19
# Epoch 671 --> loss:0.0250, acc:100.00%, val_loss:1.3358, val_acc:57.50%
#  Epoch 672: iteration 19/19
# Epoch 672 --> loss:0.0233, acc:99.84%, val_loss:1.4959, val_acc:51.25%
#  Epoch 673: iteration 19/19
# Epoch 673 --> loss:0.0378, acc:99.34%, val_loss:1.3116, val_acc:55.00%
#  Epoch 674: iteration 19/19
# Epoch 674 --> loss:0.0308, acc:99.67%, val_loss:1.7623, val_acc:46.25%
#  Epoch 675: iteration 19/19
# Epoch 675 --> loss:0.0191, acc:100.00%, val_loss:1.4716, val_acc:50.00%
#  Epoch 676: iteration 19/19
# Epoch 676 --> loss:0.0158, acc:100.00%, val_loss:1.5947, val_acc:48.75%
#  Epoch 677: iteration 19/19
# Epoch 677 --> loss:0.0243, acc:99.34%, val_loss:1.9301, val_acc:45.00%
#  Epoch 678: iteration 19/19
# Epoch 678 --> loss:0.0192, acc:99.84%, val_loss:1.7236, val_acc:46.25%
#  Epoch 679: iteration 19/19
# Epoch 679 --> loss:0.0233, acc:100.00%, val_loss:1.7927, val_acc:52.50%
#  Epoch 680: iteration 19/19
# Epoch 680 --> loss:0.0232, acc:99.84%, val_loss:0.8682, val_acc:68.75%
#  Epoch 681: iteration 19/19
# Epoch 681 --> loss:0.0217, acc:99.67%, val_loss:2.0330, val_acc:48.75%
#  Epoch 682: iteration 19/19
# Epoch 682 --> loss:0.0238, acc:99.67%, val_loss:1.4553, val_acc:53.75%
#  Epoch 683: iteration 19/19
# Epoch 683 --> loss:0.0169, acc:100.00%, val_loss:1.5176, val_acc:48.75%
#  Epoch 684: iteration 19/19
# Epoch 684 --> loss:0.0128, acc:100.00%, val_loss:1.8188, val_acc:45.00%
#  Epoch 685: iteration 19/19
# Epoch 685 --> loss:0.0156, acc:100.00%, val_loss:1.5145, val_acc:51.25%
#  Epoch 686: iteration 19/19
# Epoch 686 --> loss:0.0149, acc:100.00%, val_loss:2.0603, val_acc:47.50%
#  Epoch 687: iteration 19/19
# Epoch 687 --> loss:0.0164, acc:100.00%, val_loss:2.0535, val_acc:48.75%
#  Epoch 688: iteration 19/19
# Epoch 688 --> loss:0.0130, acc:100.00%, val_loss:1.4917, val_acc:48.75%
#  Epoch 689: iteration 19/19
# Epoch 689 --> loss:0.0102, acc:100.00%, val_loss:1.6016, val_acc:46.25%
#  Epoch 690: iteration 19/19
# Epoch 690 --> loss:0.0140, acc:100.00%, val_loss:2.1344, val_acc:47.50%
#  Epoch 691: iteration 19/19
# Epoch 691 --> loss:0.0868, acc:97.04%, val_loss:2.8066, val_acc:41.25%
#  Epoch 692: iteration 19/19
# Epoch 692 --> loss:0.1776, acc:94.74%, val_loss:2.7277, val_acc:45.00%
#  Epoch 693: iteration 19/19
# Epoch 693 --> loss:0.0836, acc:97.20%, val_loss:3.8158, val_acc:33.75%
#  Epoch 694: iteration 19/19
# Epoch 694 --> loss:0.0273, acc:99.84%, val_loss:1.7146, val_acc:52.50%
#  Epoch 695: iteration 19/19
# Epoch 695 --> loss:0.0369, acc:99.34%, val_loss:1.3265, val_acc:57.50%
#  Epoch 696: iteration 19/19
# Epoch 696 --> loss:0.0639, acc:98.68%, val_loss:2.0265, val_acc:47.50%
#  Epoch 697: iteration 19/19
# Epoch 697 --> loss:0.0355, acc:99.51%, val_loss:1.3759, val_acc:56.25%
#  Epoch 698: iteration 19/19
# Epoch 698 --> loss:0.0429, acc:99.18%, val_loss:2.9025, val_acc:43.75%
#  Epoch 699: iteration 19/19
# Epoch 699 --> loss:0.0690, acc:98.52%, val_loss:3.6934, val_acc:41.25%

# %% [markdown]
# ### Loss Curve

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train loss','val loss'])

# %%
train_accuracy_array= []
for item_accuracy in train_accuracy:
    numpy_accuracy = item_accuracy.cpu().detach().numpy() 
    train_accuracy_array.append(numpy_accuracy)

# %%
plt.plot(train_accuracy_array,'b')

# %%
validation_accuracy_array= []
for item_accuracy in val_accuracy:
    numpy_accuracy = item_accuracy.cpu().detach().numpy() 
    validation_accuracy_array.append(numpy_accuracy)
    
plt.plot(validation_accuracy_array)

# %% [markdown]
# ### Evaluate the Model on test set

# %%
"""Convert four dimensional test set and label set array to tensor and move to GPU
   tensor float data type for x_test and long for y_test
"""
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function initialized before
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 4.269
# Test accuracy is 45.00%

# %%
print(type(predictions))
print(len(predictions))
print(predictions)
# Out:
# <class 'torch.Tensor'>
# 80
# tensor([4, 2, 4, 6, 6, 6, 0, 0, 0, 6, 4, 2, 2, 4, 4, 4, 4, 6, 4, 4, 2, 2, 2, 2,
#         2, 4, 2, 4, 2, 2, 6, 6, 6, 6, 6, 4, 6, 2, 6, 6, 4, 4, 4, 4, 4, 4, 4, 4,
#         4, 4, 7, 2, 4, 6, 7, 7, 6, 6, 7, 6, 6, 6, 6, 7, 6, 6, 6, 6, 6, 7, 7, 7,
#         7, 6, 7, 7, 6, 7, 7, 4], device='cuda:0')

# %% [markdown]
# ### confusion matrix

# %%
# build confusion matrix and normalized confusion matrix
predictions = predictions.cpu().numpy()
conf_matrix = confusion_matrix(y_test, predictions)
conf_matrix_norm = confusion_matrix(y_test, predictions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in EMOTIONS.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(15,5))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) 
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) 
plt.show()

# %%
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_base_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'Normal_cnn__model.pt')))
# Out:
# Model is saved to C:\Users\janakishyama\Desktop\ESR06\Implementation\my_model\models\Normal_cnn__model.pt
