# %% [markdown]
# # CNN Model Implementation

# %% [markdown]
# ### Four Layer 2D convolutional network implementation.
# ### Model selcted after comparing its performence against three layer CNN model.
# ### Without Data Augmentation and feature engineering the model achieved 58% accuracy.
#
# For efficient train, validation, & test set creation and also for model traning (balanced and well distributed data processing) I adopted the implementation method proposed by "Ilia Zenkov".

# %% [markdown]
# Mel-spectrogram values corresponding to each audio samples are extracted and used it as training feature.
#
# Audio time scale is set as width and set freequency as height,
#
# Extracted features are changed into 4D tensor after adding sigle channel dimension with each audio mel spectrogram matrix.
#
# Selected CNN model as a base line model because of its ability to learn from spatial feature representation.
#
# By doing so we can comapre the model performance of CNN against hybrid parallel CNN-Transformer model

# %% [markdown]
# #### ConvNet - Model Architecture Details :
#
#   CNN BLOCK 1 ===================================
#
#     Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     BatchNorm2d(16, eps=1e-05, momentum=0.1)
#     ReLU()
#     MaxPool2d(kernel_size=2, stride=2, padding=0)
#     Dropout(p=0.3)
#
#   CNN BLOCK 2 ===================================
#
#     Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     BatchNorm2d(32, eps=1e-05, momentum=0.1)
#     ReLU()
#     MaxPool2d(kernel_size=4, stride=4, padding=0)
#     Dropout(p=0.3)
#
#   CNN BLOCK 3 ===================================
#
#     Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     BatchNorm2d(64, eps=1e-05, momentum=0.1)
#     ReLU()
#     MaxPool2d(kernel_size=4, stride=4, padding=0)
#     Dropout(p=0.3)
#
#   CNN BLOCK 4 ===================================
#
#     Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     BatchNorm2d(64, eps=1e-05, momentum=0.1)
#     ReLU()
#     MaxPool2d(kernel_size=4, stride=4, padding=0)
#     Dropout(p=0.3)

# %%
# loading data processing and visualization packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import seaborn as sn

import warnings
warnings.filterwarnings("ignore")

# %%
# loading deep learning Pytorch and librosa audio library
import torch
import torchaudio
import torch.nn as nn
import librosa
import librosa.display
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD
from torchsummary import summary

# %%
# Read the saved label data from CSV file to data frame
signal_data = pd.read_csv('data.csv')
signal_data.head()
# Out:
#                                           Path  Emotion  Emotion_intensity  \
# 0  ./archive/Actor_01/03-01-01-01-01-01-01.wav        1                  1
# 1  ./archive/Actor_01/03-01-01-01-01-02-01.wav        1                  1
# 2  ./archive/Actor_01/03-01-01-01-02-01-01.wav        1                  1
# 3  ./archive/Actor_01/03-01-01-01-02-02-01.wav        1                  1
# 4  ./archive/Actor_01/03-01-02-01-01-01-01.wav        2                  1
#
#   Gender
# 0   male
# 1   male
# 2   male
# 3   male
# 4   male

# %%
# creating copy of the data frame
myDataFrame=signal_data
myDataFrame.set_index('Path')
# Out:
#                                              Emotion  Emotion_intensity  \
# Path
# ./archive/Actor_01/03-01-01-01-01-01-01.wav        1                  1
# ./archive/Actor_01/03-01-01-01-01-02-01.wav        1                  1
# ./archive/Actor_01/03-01-01-01-02-01-01.wav        1                  1
# ./archive/Actor_01/03-01-01-01-02-02-01.wav        1                  1
# ./archive/Actor_01/03-01-02-01-01-01-01.wav        2                  1
# ...                                              ...                ...
# ./archive/Actor_24/03-01-08-01-02-02-24.wav        0                  1
# ./archive/Actor_24/03-01-08-02-01-01-24.wav        0                  2
# ./archive/Actor_24/03-01-08-02-01-02-24.wav        0                  2
# ./archive/Actor_24/03-01-08-02-02-01-24.wav        0                  2
# ./archive/Actor_24/03-01-08-02-02-02-24.wav        0                  2
#
#                                              Gender
# Path
# ./archive/Actor_01/03-01-01-01-01-01-01.wav    male
# ./archive/Actor_01/03-01-01-01-01-02-01.wav    male
# ./archive/Actor_01/03-01-01-01-02-01-01.wav    male
# ./archive/Actor_01/03-01-01-01-02-02-01.wav    male
# ./archive/Actor_01/03-01-02-01-01-01-01.wav    male
# ...                                             ...
# ./archive/Actor_24/03-01-08-01-02-02-24.wav  female
# ./archive/Actor_24/03-01-08-02-01-01-24.wav  female
# ./archive/Actor_24/03-01-08-02-01-02-24.wav  female
# ./archive/Actor_24/03-01-08-02-02-01-24.wav  female
# ./archive/Actor_24/03-01-08-02-02-02-24.wav  female
#
# [1440 rows x 3 columns]

# %%
# assiging the sample rate to a variable that find out using librosa
sample_rate = 48000

# funtion that return the extracted features
def extract_features(waveforms, features, samplerate):

    # counter to track file processing
    file_count = 0
    #wave_lenght = len(waveforms)
    # process each waveform individually to get its mel-spectrogram data
    for waveform in waveforms:
        mel_spec = extract_melspectrogram(waveform, sample_rate)
        features.append(mel_spec)
        file_count += 1
        
        print('\r'+f' Processed {file_count}/{len(waveforms)} waveforms',end='')
        
    
    # return all features from list of waveforms
    return features

# funtion to extrac audio in signal format
def load_waveforms(file):
    # read the full 3 seconds of the file, cut off the first 0.5s of silence
    waveform, _ = librosa.load(file, duration=3, offset=0.5, sr=sample_rate)
    
    # making each vectors homogenious in nature
    waveform_homo = np.zeros((int(sample_rate*3,)))
    waveform_homo[:len(waveform)] = waveform
    
    # return file's waveform                                      
    return waveform_homo

# function to compute mel spectrogram values corresponding to each audio signal.
def extract_melspectrogram(audio, sample_rate):
    # Produce the mel spectrogram for all STFT frames and get the mean of each column of the resulting matrix to create a feature array
    mel_spec = librosa.feature.melspectrogram(y=audio,
                                              sr=sample_rate,
                                              n_fft=1024,
                                              win_length = 512,
                                              window='hamming',
                                              hop_length = 256,
                                              n_mels=128,
                                              fmax=sample_rate/2
                                             )
    # convert from power (amplitude**2) to decibels
    # necessary for network to learn - doesn't converge with raw power spectrograms 
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db

# %%
# extracting and storing each wave form vector
waveforms  = []
# counter to track file processing
file_count = 0
for file in signal_data.Path:
    waveform = load_waveforms(file)
    waveforms.append(waveform)
    file_count += 1
    print('\r'+f' Processed {file_count}/{len(signal_data)} waveforms',end='')
    
# verify the wave form stored
print('\n')
print(len(waveforms))
print(len(waveforms[0]))
print(type(waveforms))
# Out:
#  Processed 1440/1440 waveforms
#
# 1440
# 144000
# <class 'list'>

# %%
# convert the list into numpy multi-dimentional array for test train split.
# convert waveforms to array for processing
signals = np.stack(waveforms,axis=0)
print(signals.ndim)
print(signals.shape)
print(type(signals))
# Out:
# 2
# (1440, 144000)
# <class 'numpy.ndarray'>

# %% [markdown]
# # ===========================================================

# %%
# Create a dictionary and set surprised = 0 insted of 8  for PyTorch
EMOTIONS ={
    '0':'surprised',
    '1':'neutral',
    '2':'calm',
    '3':'happy',
    '4':'sad',
    '5':'angry',
    '6':'fearful',
    '7':'disgust'
}

# %%
# initialize empty list for train, validation, test sets and their indices
train_ind,test_ind,val_ind = [],[],[]
X_train,X_val,X_test = [],[],[]
Y_train,Y_val,Y_test = [],[],[]

# %%
# process each emotion separately to make sure we builf balanced train/valid/test sets
for emotion in range(len(EMOTIONS)):
    # Extract and store all indices corrsponding to individual emotion seperately - ie one emotion per iteration
    emotion_ind = list(signal_data.loc[signal_data.Emotion==emotion,'Emotion'].index)
    # seed and shuffle indicies 
    emotion_ind = np.random.permutation(emotion_ind)
    # Assign length of the emotion list to make indices
    m = len(emotion_ind)
    
    # store indices of training, validation and test sets in 80/10/10 proportion - train set is first 80%
    ind_train = emotion_ind[:int(0.8*m)]
    # validation set is next 10% (between 80% and 90%)
    ind_val = emotion_ind[int(0.8*m):int(0.9*m)]
    # test set is last 10% (between 90% - end/100%)
    ind_test = emotion_ind[int(0.9*m):]
    
     # create train waveforms/labels sets
    X_train.append(signals[ind_train,:])
    Y_train.append(np.array([emotion]*len(ind_train),dtype=np.int32))
    # create validation waveforms/labels sets
    X_val.append(signals[ind_val,:])
    Y_val.append(np.array([emotion]*len(ind_val),dtype=np.int32))
    # create test waveforms/labels sets
    X_test.append(signals[ind_test,:])
    Y_test.append(np.array([emotion]*len(ind_test),dtype=np.int32))
    
    # store indices for each emotion set to verify uniqueness between sets
    train_ind.append(ind_train)
    test_ind.append(ind_test)
    val_ind.append(ind_val)
    
# concatenate, in order, all waveforms back into one array     
X_train = np.concatenate(X_train,0)
X_val = np.concatenate(X_val,0)
X_test = np.concatenate(X_test,0)
Y_train = np.concatenate(Y_train,0)
Y_val = np.concatenate(Y_val,0)
Y_test = np.concatenate(Y_test,0)

# print shape of each set
print(f'X_train:{X_train.shape}, Y_train:{Y_train.shape}')
print(f'X_val:{X_val.shape}, Y_val:{Y_val.shape}')
print(f'X_test:{X_test.shape}, Y_test:{Y_test.shape}')
# Out:
# X_train:(1147, 144000), Y_train:(1147,)
# X_val:(143, 144000), Y_val:(143,)
# X_test:(150, 144000), Y_test:(150,)

# %% [markdown]
# ## Feature Extraction

# %%
# initialize feature arrays
# Extract Mel-spectrogram features from waveforms and store in respective 'features' array
features_train, features_valid, features_test = [],[],[]

print('Train waveforms:') # get training set features 
features_train = extract_features(X_train, features_train, sample_rate)

print('\n\nValidation waveforms:') # get validation set features
features_valid = extract_features(X_val, features_valid, sample_rate)

print('\n\nTest waveforms:') # get test set features 
features_test = extract_features(X_test, features_test, sample_rate)

print(f'\n\nFeatures set: {len(features_train)+len(features_test)+len(features_valid)} total, {len(features_train)} train, {len(features_valid)} validation, {len(features_test)} test samples')
print(f'Features (Mel-Spectrogram matrix) shape: {len(features_train[0])} x {len(features_train[0][1])}')
# Out:
# Train waveforms:
#  Processed 1147/1147 waveforms
#
# Validation waveforms:
#  Processed 143/143 waveforms
#
# Test waveforms:
#  Processed 150/150 waveforms
#
# Features set: 1440 total, 1147 train, 143 validation, 150 test samples
# Features (Mel-Spectrogram matrix) shape: 128 x 563

# %%
# Convert each list into numpy array for pytorch and stored them in corresponding train arrays
features_train = np.stack(features_train,axis=0)
features_valid = np.stack(features_valid,axis=0)
features_test = np.stack(features_test,axis=0)

# %%
print(type(features_train))
print(len(features_train))
# Out:
# <class 'numpy.ndarray'>
# 1147

# %%
"""
Here we have 1 signal intensity channel, because we are using gray scale signal representation,
to feed the data in to a 2D convolutional network in pytorch we need to define a 4D Tensor Array
We need an input channel dim to expand to output channels using CNN filters. 
We create a dummy channel dim ie 1 to expand features into 2D-CNN-ready 4D tensor format: N x C x H x W.
"""

# need to make dummy input channel for CNN input feature tensor
X_train = np.expand_dims(features_train,1)
X_val = np.expand_dims(features_valid, 1)
X_test = np.expand_dims(features_test,1)

# convert emotion labels from list back to numpy arrays for PyTorch to work with 
y_train = np.array(Y_train)
y_val = np.array(Y_val)
y_test = np.array(Y_test)

# %%
print(type(X_train))
# Out:
# <class 'numpy.ndarray'>

# %%
#Print (batch, channel, width, height)
print(f'X_train:{X_train.shape}, y_train:{y_train.shape}')
print(f'X_val:{X_val.shape}, y_val:{y_val.shape}')
print(f'X_test:{X_test.shape}, y_test:{y_test.shape}')
# Out:
# X_train:(1147, 1, 128, 563), y_train:(1147,)
# X_val:(143, 1, 128, 563), y_val:(143,)
# X_test:(150, 1, 128, 563), y_test:(150,)

# %% [markdown]
# ## Model Definition

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super(ConvNet, self).__init__()
        self.conv2Dblock = nn.Sequential(
            # First convolutional layer   (input : 1x128x563)
            nn.Conv2d(in_channels=1,
                       out_channels=16,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # First convolutional pooling layer
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout(p=0.3),
            # Second convolutional layer  (input : 16x64x281)
            nn.Conv2d(in_channels=16,
                       out_channels=32,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # Second convolutional pooling layer
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # Third convolutional layer  (input : 32x16x70)
            nn.Conv2d(in_channels=32,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # Third convolutional pooling layer
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3),
            # Fourth convolutional layer  (input : 64x4x17)
            nn.Conv2d(in_channels=64,
                       out_channels=64,
                       kernel_size=3,
                       stride=1,
                       padding=1
                      ),
            # Fourth convolutional layer  (input : 64x4x17)
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=4, stride=4),
            nn.Dropout(p=0.3)
        )
        """
        input in to the Linear block (64x1x4 = 256, number of emotions = 8)
        Each full convolution block outputs (64*1*4) embedding flattened to dim 256 1D array
        from 256 input feature create 8 output imotions (256 ==> 8)
        """
        # Linear softmax layer will take final signal embedded tensor 
        self.out_linear = nn.Linear(256,8)
        self.dropout_linear = nn.Dropout(p=0)
        # Softmax layer for the 8 output logits from final FC linear layer 
        self.out_softmax = nn.Softmax(dim=1)
    def forward(self,x):
        # forward pass of input feature tensor
        # create final feature embedding from 2D convolutional sequence block 
        # input features pased through 4 sequential 2D convolutional layers
        signal_embedding = self.conv2Dblock(x)
        
        # flatten final 64*1*4 feature map from convolutional layers to length 256 1D array 
        # skip the 1st minibatch dimension when flattening ie start_dim=1
        conv_embedding = torch.flatten(signal_embedding, start_dim=1)
        
        # final fully connected linear layer, need logits for loss calculation
        output_logits = self.out_linear(conv_embedding)
        output_logits = self.dropout_linear(output_logits)
        
        # final Softmax layer for prediction
        output_softmax = self.out_softmax(output_logits)
        
        return output_logits, output_softmax

# %%
"""
Checking the model architectue based on temporary defined optimizer and loss fuction
"""
# instantiate the model
model = ConvNet()
# defining the optimizer
optimizer = Adam(model.parameters(), lr=0.01)
# defining the loss function
criterion = CrossEntropyLoss()
# checking if GPU is available
if torch.cuda.is_available():
    model = model.cuda()
    criterion = criterion.cuda()
    
print(model)
# Out:
# ConvNet(
#   (conv2Dblock): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.3, inplace=False)
#     (5): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.3, inplace=False)
#     (10): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.3, inplace=False)
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): MaxPool2d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (19): Dropout(p=0.3, inplace=False)
#   )
#   (out_linear): Linear(in_features=256, out_features=8, bias=True)
#   (dropout_linear): Dropout(p=0, inplace=False)
#   (out_softmax): Softmax(dim=1)
# )

# %%
# model summary based on input feature shape.
summary(model, input_size=(1,128,563))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 16, 128, 563]             160
#        BatchNorm2d-2         [-1, 16, 128, 563]              32
#               ReLU-3         [-1, 16, 128, 563]               0
#          MaxPool2d-4          [-1, 16, 64, 281]               0
#            Dropout-5          [-1, 16, 64, 281]               0
#             Conv2d-6          [-1, 32, 64, 281]           4,640
#        BatchNorm2d-7          [-1, 32, 64, 281]              64
#               ReLU-8          [-1, 32, 64, 281]               0
#          MaxPool2d-9           [-1, 32, 16, 70]               0
#           Dropout-10           [-1, 32, 16, 70]               0
#            Conv2d-11           [-1, 64, 16, 70]          18,496
#       BatchNorm2d-12           [-1, 64, 16, 70]             128
#              ReLU-13           [-1, 64, 16, 70]               0
#         MaxPool2d-14            [-1, 64, 4, 17]               0
#           Dropout-15            [-1, 64, 4, 17]               0
#            Conv2d-16            [-1, 64, 4, 17]          36,928
#       BatchNorm2d-17            [-1, 64, 4, 17]             128
#              ReLU-18            [-1, 64, 4, 17]               0
#         MaxPool2d-19             [-1, 64, 1, 4]               0
#           Dropout-20             [-1, 64, 1, 4]               0
#            Linear-21                    [-1, 8]           2,056
#           Dropout-22                    [-1, 8]               0
#           Softmax-23                    [-1, 8]               0
# ================================================================
# Total params: 62,632
# Trainable params: 62,632
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.27
# Forward/backward pass size (MB): 46.31
# Params size (MB): 0.24
# Estimated Total Size (MB): 46.82
# ----------------------------------------------------------------

# %%
#  loss function for the backwards pass of each training iteration
#  We use log softmax for faster gradient optimization.
def loss_function(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions,target=targets)

# %%
# function to create a single step of the each iteration training phase
def train_step_function(model, loss_function, optimizer):
    # training step of the training phase
    def train_step(X,Y):
        # set model to train mode
        model.train()
        # forward pass and output_logits, output_softmax values are returned
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax,dim=1)
        accuracy = torch.sum(Y==predictions)/float(len(Y))
        
        # compute loss and defining back propagation
        loss = loss_function(output_logits, Y)
         # compute gradients for the optimizer to use 
        loss.backward()
        # update network parameters based on gradient stored
        optimizer.step()
        # zero out gradients for next pass (ie accumulates gradients from backwards passe)
        optimizer.zero_grad()
        return loss.item(), accuracy*100
    return train_step

# %%
# define the validation function for each iteration on validation mini batches
def validation_step_function(model,loss_function):  
    def validate(X,Y):
        # use to save memory and compute in validation phase:
        with torch.no_grad():
            # initialize model for validation phase by turning off dropout and batchnorm layers
            model.eval()
            # compute model predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax,dim=1)
            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y==predictions)/float(len(Y))
            # compute error
            loss = loss_function(output_logits,Y)
        return loss.item(), accuracy*100, predictions
    return validate

# %%
# set epoch size
EPOCHS=700
# read and assign train set lenght to variable DATASET_SIZE for define the number of iterations
DATASET_SIZE = X_train.shape[0]
# set batch size
BATCH_SIZE = 32
# set computation device as CUDA if available or CPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Selected device is {}'.format(device))
# Initialize the model in Selected device
model = ConvNet().to(device)
# set SGD as optimizer
OPTIMIZER = torch.optim.SGD(model.parameters(),lr=0.01, weight_decay=1e-3, momentum=0.8)
# call the training step function 
train_step = train_step_function(model, loss_function, optimizer=OPTIMIZER)
# Call the validation function
validate = validation_step_function(model,loss_function)
# define empty lists to store scalar performance metrics for ploating
losses=[]
val_losses = []
# Out:
# Selected device is cuda

# %%
# created a function for training each individual epoches loop for entire training set
def train(optimizer, model, num_epochs, X_train, Y_train, X_valid, Y_valid):
    for epoch in range(EPOCHS):
        
        # schuffle data to randomize minibatch order
        ind = np.random.permutation(DATASET_SIZE)
        
        # shuffle the training set for each epoch:
        X_train = X_train[ind,:,:,:]
        Y_train = Y_train[ind]
        
        epoch_acc = 0
        epoch_loss = 0
        
        # Define number of iterations per epoch to process the entire train set
        iters = int(DATASET_SIZE / BATCH_SIZE)
         # create a loop for each minibatch of 32 samples:
        for i in range(iters):
            # track and update minibatch position based on iteration number to make sure all all data in the samples processd
            batch_start = i * BATCH_SIZE
            # Define bounds of our training set
            batch_end = min(batch_start + BATCH_SIZE, DATASET_SIZE)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start
            # set training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end,:,:,:]
            # Set training minibatch labels 
            Y = Y_train[batch_start:batch_end]
            
            # Convert the train set and lables in to torch tensor format- train in to tensor flot and lables into long double
            X_tensor = torch.tensor(X,device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long,device=device)
            
             # Call the training function and train the model on train set features and lablels for each minibaches
            loss, acc = train_step(X_tensor,Y_tensor)
            
            # Keep track of loss and accuracy chage by aggrigating in to the variable for  measure the training and validation
            epoch_acc += acc*actual_batch_size/DATASET_SIZE
            epoch_loss += loss*actual_batch_size/DATASET_SIZE
            
            # Print details iteration wise training progress
            print(f"\r Epoch {epoch}: iteration {i+1}/{iters}",end='')
            
        # create tensors from validation set
        X_val_tensor = torch.tensor(X_valid,device=device).float()
        Y_val_tensor = torch.tensor(Y_valid,dtype=torch.long,device=device)
        
        # call validation function and keep track of validation set performance
        val_loss, val_acc, predictions = validate(X_val_tensor,Y_val_tensor)
        
        # append scalar performance metrics at each epoch to track and plot later
        losses.append(epoch_loss)
        val_losses.append(val_loss)
        
        print('')
        print(f"Epoch {epoch} --> loss:{epoch_loss:.4f}, acc:{epoch_acc:.2f}%, val_loss:{val_loss:.4f}, val_acc:{val_acc:.2f}%")

# %%
# call the train function and train the model
train(OPTIMIZER, model, EPOCHS, X_train, y_train, X_val, y_val)
# Out:
#  Epoch 0: iteration 35/35
# Epoch 0 --> loss:2.4196, acc:16.13%, val_loss:2.1253, val_acc:16.08%
#  Epoch 1: iteration 35/35
# Epoch 1 --> loss:2.0603, acc:21.53%, val_loss:2.1411, val_acc:13.29%
#  Epoch 2: iteration 35/35
# Epoch 2 --> loss:2.0062, acc:22.49%, val_loss:2.1043, val_acc:13.29%
#  Epoch 3: iteration 35/35
# Epoch 3 --> loss:1.9047, acc:24.06%, val_loss:2.0979, val_acc:13.29%
#  Epoch 4: iteration 35/35
# Epoch 4 --> loss:1.8277, acc:29.21%, val_loss:2.3950, val_acc:23.08%
#  Epoch 5: iteration 35/35
# Epoch 5 --> loss:1.7661, acc:31.73%, val_loss:2.8656, val_acc:15.38%
#  Epoch 6: iteration 35/35
# Epoch 6 --> loss:1.6998, acc:33.83%, val_loss:3.3918, val_acc:13.29%
#  Epoch 7: iteration 35/35
# Epoch 7 --> loss:1.7178, acc:32.61%, val_loss:2.8368, val_acc:26.57%
#  Epoch 8: iteration 35/35
# Epoch 8 --> loss:1.6616, acc:34.09%, val_loss:3.1859, val_acc:23.08%
#  Epoch 9: iteration 35/35
# Epoch 9 --> loss:1.6579, acc:36.09%, val_loss:3.3788, val_acc:24.48%
#  Epoch 10: iteration 35/35
# Epoch 10 --> loss:1.6436, acc:36.09%, val_loss:3.9443, val_acc:23.08%
#  Epoch 11: iteration 35/35
# Epoch 11 --> loss:1.6310, acc:36.27%, val_loss:3.2201, val_acc:18.18%
#  Epoch 12: iteration 35/35
# Epoch 12 --> loss:1.6031, acc:36.97%, val_loss:3.5672, val_acc:20.28%
#  Epoch 13: iteration 35/35
# Epoch 13 --> loss:1.5876, acc:35.92%, val_loss:3.1826, val_acc:26.57%
#  Epoch 14: iteration 35/35
# Epoch 14 --> loss:1.5711, acc:38.19%, val_loss:3.3675, val_acc:28.67%
#  Epoch 15: iteration 35/35
# Epoch 15 --> loss:1.5230, acc:40.63%, val_loss:3.2428, val_acc:25.87%
#  Epoch 16: iteration 35/35
# Epoch 16 --> loss:1.5580, acc:38.71%, val_loss:3.2321, val_acc:21.68%
#  Epoch 17: iteration 35/35
# Epoch 17 --> loss:1.5073, acc:40.10%, val_loss:3.2729, val_acc:27.27%
#  Epoch 18: iteration 35/35
# Epoch 18 --> loss:1.5053, acc:41.76%, val_loss:3.0376, val_acc:27.97%
#  Epoch 19: iteration 35/35
# Epoch 19 --> loss:1.4819, acc:41.41%, val_loss:3.1584, val_acc:24.48%
#  Epoch 20: iteration 35/35
# Epoch 20 --> loss:1.4876, acc:42.72%, val_loss:3.2500, val_acc:27.27%
#  Epoch 21: iteration 35/35
# Epoch 21 --> loss:1.4579, acc:42.46%, val_loss:3.0248, val_acc:26.57%
#  Epoch 22: iteration 35/35
# Epoch 22 --> loss:1.4685, acc:42.37%, val_loss:3.0460, val_acc:22.38%
#  Epoch 23: iteration 35/35
# Epoch 23 --> loss:1.4646, acc:42.98%, val_loss:2.8609, val_acc:27.97%
#  Epoch 24: iteration 35/35
# Epoch 24 --> loss:1.3888, acc:46.73%, val_loss:3.1660, val_acc:20.28%
#  Epoch 25: iteration 35/35
# Epoch 25 --> loss:1.4097, acc:45.68%, val_loss:3.1736, val_acc:23.78%
#  Epoch 26: iteration 35/35
# Epoch 26 --> loss:1.4063, acc:45.51%, val_loss:3.3794, val_acc:20.98%
#  Epoch 27: iteration 35/35
# Epoch 27 --> loss:1.3999, acc:45.77%, val_loss:3.0980, val_acc:22.38%
#  Epoch 28: iteration 35/35
# Epoch 28 --> loss:1.3497, acc:46.73%, val_loss:2.8247, val_acc:30.07%
#  Epoch 29: iteration 35/35
# Epoch 29 --> loss:1.3776, acc:45.51%, val_loss:3.4619, val_acc:20.98%
#  Epoch 30: iteration 35/35
# Epoch 30 --> loss:1.3662, acc:46.21%, val_loss:2.7777, val_acc:26.57%
#  Epoch 31: iteration 35/35
# Epoch 31 --> loss:1.3674, acc:44.03%, val_loss:2.9761, val_acc:23.08%
#  Epoch 32: iteration 35/35
# Epoch 32 --> loss:1.3771, acc:46.56%, val_loss:2.8594, val_acc:27.27%
#  Epoch 33: iteration 35/35
# Epoch 33 --> loss:1.3630, acc:45.95%, val_loss:3.1112, val_acc:29.37%
#  Epoch 34: iteration 35/35
# Epoch 34 --> loss:1.3241, acc:48.47%, val_loss:2.9804, val_acc:24.48%
#  Epoch 35: iteration 35/35
# Epoch 35 --> loss:1.3269, acc:47.95%, val_loss:3.0960, val_acc:25.17%
#  Epoch 36: iteration 35/35
# Epoch 36 --> loss:1.3213, acc:48.65%, val_loss:2.8093, val_acc:27.27%
#  Epoch 37: iteration 35/35
# Epoch 37 --> loss:1.2875, acc:49.87%, val_loss:2.5292, val_acc:33.57%
#  Epoch 38: iteration 35/35
# Epoch 38 --> loss:1.2822, acc:48.82%, val_loss:2.9122, val_acc:23.78%
#  Epoch 39: iteration 35/35
# Epoch 39 --> loss:1.2914, acc:49.08%, val_loss:2.6515, val_acc:27.97%
#  Epoch 40: iteration 35/35
# Epoch 40 --> loss:1.2846, acc:50.48%, val_loss:2.5046, val_acc:28.67%
#  Epoch 41: iteration 35/35
# Epoch 41 --> loss:1.2912, acc:49.17%, val_loss:2.4814, val_acc:30.07%
#  Epoch 42: iteration 35/35
# Epoch 42 --> loss:1.2593, acc:51.87%, val_loss:2.5962, val_acc:23.08%
#  Epoch 43: iteration 35/35
# Epoch 43 --> loss:1.2669, acc:49.87%, val_loss:2.4196, val_acc:32.87%
#  Epoch 44: iteration 35/35
# Epoch 44 --> loss:1.2464, acc:49.52%, val_loss:2.4089, val_acc:27.27%
#  Epoch 45: iteration 35/35
# Epoch 45 --> loss:1.2407, acc:50.04%, val_loss:2.5868, val_acc:20.98%
#  Epoch 46: iteration 35/35
# Epoch 46 --> loss:1.2655, acc:48.74%, val_loss:2.6152, val_acc:27.27%
#  Epoch 47: iteration 35/35
# Epoch 47 --> loss:1.2006, acc:52.57%, val_loss:2.7640, val_acc:23.78%
#  Epoch 48: iteration 35/35
# Epoch 48 --> loss:1.2377, acc:52.57%, val_loss:2.9917, val_acc:20.28%
#  Epoch 49: iteration 35/35
# Epoch 49 --> loss:1.1871, acc:53.97%, val_loss:2.6562, val_acc:30.77%
#  Epoch 50: iteration 35/35
# Epoch 50 --> loss:1.1777, acc:52.66%, val_loss:2.7465, val_acc:20.28%
#  Epoch 51: iteration 35/35
# Epoch 51 --> loss:1.2001, acc:52.83%, val_loss:2.3343, val_acc:32.87%
#  Epoch 52: iteration 35/35
# Epoch 52 --> loss:1.2147, acc:50.48%, val_loss:2.5434, val_acc:28.67%
#  Epoch 53: iteration 35/35
# Epoch 53 --> loss:1.1719, acc:55.88%, val_loss:2.7092, val_acc:24.48%
#  Epoch 54: iteration 35/35
# Epoch 54 --> loss:1.1613, acc:53.10%, val_loss:2.2526, val_acc:31.47%
#  Epoch 55: iteration 35/35
# Epoch 55 --> loss:1.1920, acc:53.27%, val_loss:2.5754, val_acc:22.38%
#  Epoch 56: iteration 35/35
# Epoch 56 --> loss:1.1867, acc:53.79%, val_loss:2.3599, val_acc:28.67%
#  Epoch 57: iteration 35/35
# Epoch 57 --> loss:1.1508, acc:55.62%, val_loss:2.5793, val_acc:26.57%
#  Epoch 58: iteration 35/35
# Epoch 58 --> loss:1.1534, acc:54.40%, val_loss:2.3670, val_acc:28.67%
#  Epoch 59: iteration 35/35
# Epoch 59 --> loss:1.1566, acc:55.71%, val_loss:2.3034, val_acc:34.97%
#  Epoch 60: iteration 35/35
# Epoch 60 --> loss:1.1232, acc:55.71%, val_loss:2.4690, val_acc:27.27%
#  Epoch 61: iteration 35/35
# Epoch 61 --> loss:1.1523, acc:55.45%, val_loss:2.4201, val_acc:21.68%
#  Epoch 62: iteration 35/35
# Epoch 62 --> loss:1.1212, acc:56.06%, val_loss:3.2043, val_acc:15.38%
#  Epoch 63: iteration 35/35
# Epoch 63 --> loss:1.1108, acc:56.67%, val_loss:2.3489, val_acc:28.67%
#  Epoch 64: iteration 35/35
# Epoch 64 --> loss:1.1601, acc:53.44%, val_loss:2.4002, val_acc:28.67%
#  Epoch 65: iteration 35/35
# Epoch 65 --> loss:1.1260, acc:56.23%, val_loss:2.3789, val_acc:20.28%
#  Epoch 66: iteration 35/35
# Epoch 66 --> loss:1.1056, acc:56.50%, val_loss:3.1893, val_acc:16.78%
#  Epoch 67: iteration 35/35
# Epoch 67 --> loss:1.0826, acc:56.15%, val_loss:2.1156, val_acc:31.47%
#  Epoch 68: iteration 35/35
# Epoch 68 --> loss:1.0969, acc:56.93%, val_loss:2.3496, val_acc:23.08%
#  Epoch 69: iteration 35/35
# Epoch 69 --> loss:1.0627, acc:58.76%, val_loss:2.4274, val_acc:30.77%
#  Epoch 70: iteration 35/35
# Epoch 70 --> loss:1.0822, acc:55.71%, val_loss:2.9440, val_acc:18.18%
#  Epoch 71: iteration 35/35
# Epoch 71 --> loss:1.0405, acc:59.11%, val_loss:2.5791, val_acc:23.08%
#  Epoch 72: iteration 35/35
# Epoch 72 --> loss:1.0788, acc:57.02%, val_loss:2.1008, val_acc:32.17%
#  Epoch 73: iteration 35/35
# Epoch 73 --> loss:1.1106, acc:55.45%, val_loss:2.7098, val_acc:17.48%
#  Epoch 74: iteration 35/35
# Epoch 74 --> loss:1.0439, acc:59.29%, val_loss:2.2898, val_acc:27.97%
#  Epoch 75: iteration 35/35
# Epoch 75 --> loss:1.0163, acc:60.16%, val_loss:2.5682, val_acc:25.17%
#  Epoch 76: iteration 35/35
# Epoch 76 --> loss:1.0228, acc:60.85%, val_loss:2.6476, val_acc:22.38%
#  Epoch 77: iteration 35/35
# Epoch 77 --> loss:1.0339, acc:59.46%, val_loss:2.2823, val_acc:32.17%
#  Epoch 78: iteration 35/35
# Epoch 78 --> loss:1.0637, acc:59.55%, val_loss:3.2186, val_acc:16.78%
#  Epoch 79: iteration 35/35
# Epoch 79 --> loss:1.0752, acc:58.15%, val_loss:2.3397, val_acc:23.78%
#  Epoch 80: iteration 35/35
# Epoch 80 --> loss:1.0530, acc:57.28%, val_loss:2.0857, val_acc:32.87%
#  Epoch 81: iteration 35/35
# Epoch 81 --> loss:1.0292, acc:59.29%, val_loss:2.6881, val_acc:18.18%
#  Epoch 82: iteration 35/35
# Epoch 82 --> loss:1.0418, acc:59.29%, val_loss:2.1953, val_acc:27.27%
#  Epoch 83: iteration 35/35
# Epoch 83 --> loss:0.9762, acc:61.46%, val_loss:2.5775, val_acc:20.28%
#  Epoch 84: iteration 35/35
# Epoch 84 --> loss:0.9994, acc:61.03%, val_loss:2.0911, val_acc:29.37%
#  Epoch 85: iteration 35/35
# Epoch 85 --> loss:1.0003, acc:59.46%, val_loss:1.9569, val_acc:31.47%
#  Epoch 86: iteration 35/35
# Epoch 86 --> loss:0.9947, acc:60.51%, val_loss:1.6721, val_acc:40.56%
#  Epoch 87: iteration 35/35
# Epoch 87 --> loss:0.9465, acc:64.69%, val_loss:2.0894, val_acc:30.77%
#  Epoch 88: iteration 35/35
# Epoch 88 --> loss:0.9572, acc:63.30%, val_loss:2.2593, val_acc:22.38%
#  Epoch 89: iteration 35/35
# Epoch 89 --> loss:0.9465, acc:63.30%, val_loss:2.1585, val_acc:28.67%
#  Epoch 90: iteration 35/35
# Epoch 90 --> loss:0.9918, acc:59.37%, val_loss:2.2389, val_acc:30.07%
#  Epoch 91: iteration 35/35
# Epoch 91 --> loss:0.9322, acc:63.99%, val_loss:2.2488, val_acc:26.57%
#  Epoch 92: iteration 35/35
# Epoch 92 --> loss:0.9667, acc:63.64%, val_loss:1.8022, val_acc:32.17%
#  Epoch 93: iteration 35/35
# Epoch 93 --> loss:0.9533, acc:61.90%, val_loss:1.9593, val_acc:32.87%
#  Epoch 94: iteration 35/35
# Epoch 94 --> loss:0.9344, acc:63.03%, val_loss:1.7626, val_acc:39.16%
#  Epoch 95: iteration 35/35
# Epoch 95 --> loss:0.9428, acc:63.21%, val_loss:2.3805, val_acc:20.98%
#  Epoch 96: iteration 35/35
# Epoch 96 --> loss:0.9180, acc:64.17%, val_loss:1.9676, val_acc:30.77%
#  Epoch 97: iteration 35/35
# Epoch 97 --> loss:0.8863, acc:66.52%, val_loss:2.0399, val_acc:32.17%
#  Epoch 98: iteration 35/35
# Epoch 98 --> loss:0.9248, acc:63.64%, val_loss:2.3264, val_acc:22.38%
#  Epoch 99: iteration 35/35
# Epoch 99 --> loss:0.9003, acc:63.56%, val_loss:2.4537, val_acc:22.38%
#  Epoch 100: iteration 35/35
# Epoch 100 --> loss:0.9515, acc:61.20%, val_loss:1.9272, val_acc:34.27%
#  Epoch 101: iteration 35/35
# Epoch 101 --> loss:0.8726, acc:64.43%, val_loss:2.0702, val_acc:30.77%
#  Epoch 102: iteration 35/35
# Epoch 102 --> loss:0.9139, acc:65.48%, val_loss:1.8385, val_acc:33.57%
#  Epoch 103: iteration 35/35
# Epoch 103 --> loss:0.9068, acc:63.38%, val_loss:1.6445, val_acc:38.46%
#  Epoch 104: iteration 35/35
# Epoch 104 --> loss:0.9193, acc:63.12%, val_loss:1.6719, val_acc:41.96%
#  Epoch 105: iteration 35/35
# Epoch 105 --> loss:0.8812, acc:65.65%, val_loss:2.3398, val_acc:23.78%
#  Epoch 106: iteration 35/35
# Epoch 106 --> loss:0.9190, acc:64.25%, val_loss:2.1413, val_acc:30.07%
#  Epoch 107: iteration 35/35
# Epoch 107 --> loss:0.8643, acc:66.26%, val_loss:2.4702, val_acc:20.28%
#  Epoch 108: iteration 35/35
# Epoch 108 --> loss:0.8091, acc:68.61%, val_loss:1.8202, val_acc:34.27%
#  Epoch 109: iteration 35/35
# Epoch 109 --> loss:0.8789, acc:63.91%, val_loss:1.8259, val_acc:37.06%
#  Epoch 110: iteration 35/35
# Epoch 110 --> loss:0.9089, acc:63.38%, val_loss:1.6677, val_acc:39.86%
#  Epoch 111: iteration 35/35
# Epoch 111 --> loss:0.8451, acc:65.65%, val_loss:1.5640, val_acc:45.45%
#  Epoch 112: iteration 35/35
# Epoch 112 --> loss:0.8837, acc:64.17%, val_loss:2.8290, val_acc:18.18%
#  Epoch 113: iteration 35/35
# Epoch 113 --> loss:0.7805, acc:68.44%, val_loss:1.6228, val_acc:48.25%
#  Epoch 114: iteration 35/35
# Epoch 114 --> loss:0.8365, acc:65.82%, val_loss:1.7962, val_acc:37.06%
#  Epoch 115: iteration 35/35
# Epoch 115 --> loss:0.8513, acc:67.83%, val_loss:1.7094, val_acc:40.56%
#  Epoch 116: iteration 35/35
# Epoch 116 --> loss:0.8067, acc:68.88%, val_loss:1.7840, val_acc:37.76%
#  Epoch 117: iteration 35/35
# Epoch 117 --> loss:0.8228, acc:68.27%, val_loss:1.9618, val_acc:35.66%
#  Epoch 118: iteration 35/35
# Epoch 118 --> loss:0.8317, acc:67.48%, val_loss:1.7956, val_acc:32.87%
#  Epoch 119: iteration 35/35
# Epoch 119 --> loss:0.8140, acc:68.09%, val_loss:1.7104, val_acc:39.16%
#  Epoch 120: iteration 35/35
# Epoch 120 --> loss:0.8163, acc:67.83%, val_loss:1.7104, val_acc:36.36%
#  Epoch 121: iteration 35/35
# Epoch 121 --> loss:0.8144, acc:67.04%, val_loss:2.5727, val_acc:22.38%
#  Epoch 122: iteration 35/35
# Epoch 122 --> loss:0.8020, acc:68.18%, val_loss:1.8922, val_acc:31.47%
#  Epoch 123: iteration 35/35
# Epoch 123 --> loss:0.8355, acc:67.13%, val_loss:1.7067, val_acc:41.26%
#  Epoch 124: iteration 35/35
# Epoch 124 --> loss:0.8383, acc:67.65%, val_loss:1.8324, val_acc:35.66%
#  Epoch 125: iteration 35/35
# Epoch 125 --> loss:0.7621, acc:70.53%, val_loss:1.4678, val_acc:46.85%
#  Epoch 126: iteration 35/35
# Epoch 126 --> loss:0.7947, acc:68.18%, val_loss:2.3708, val_acc:24.48%
#  Epoch 127: iteration 35/35
# Epoch 127 --> loss:0.7974, acc:67.48%, val_loss:1.5939, val_acc:43.36%
#  Epoch 128: iteration 35/35
# Epoch 128 --> loss:0.7590, acc:70.71%, val_loss:1.5247, val_acc:45.45%
#  Epoch 129: iteration 35/35
# Epoch 129 --> loss:0.7633, acc:70.18%, val_loss:1.7647, val_acc:37.76%
#  Epoch 130: iteration 35/35
# Epoch 130 --> loss:0.7833, acc:68.70%, val_loss:1.8658, val_acc:37.76%
#  Epoch 131: iteration 35/35
# Epoch 131 --> loss:0.7301, acc:71.75%, val_loss:1.7832, val_acc:37.06%
#  Epoch 132: iteration 35/35
# Epoch 132 --> loss:0.7810, acc:70.36%, val_loss:1.7750, val_acc:37.06%
#  Epoch 133: iteration 35/35
# Epoch 133 --> loss:0.7730, acc:68.88%, val_loss:1.5507, val_acc:45.45%
#  Epoch 134: iteration 35/35
# Epoch 134 --> loss:0.7414, acc:71.58%, val_loss:1.6909, val_acc:37.76%
#  Epoch 135: iteration 35/35
# Epoch 135 --> loss:0.7596, acc:70.97%, val_loss:1.6858, val_acc:37.06%
#  Epoch 136: iteration 35/35
# Epoch 136 --> loss:0.7513, acc:70.01%, val_loss:1.5093, val_acc:45.45%
#  Epoch 137: iteration 35/35
# Epoch 137 --> loss:0.7592, acc:67.65%, val_loss:1.7521, val_acc:34.97%
#  Epoch 138: iteration 35/35
# Epoch 138 --> loss:0.7243, acc:70.10%, val_loss:1.6133, val_acc:42.66%
#  Epoch 139: iteration 35/35
# Epoch 139 --> loss:0.7148, acc:72.54%, val_loss:1.3275, val_acc:54.55%
#  Epoch 140: iteration 35/35
# Epoch 140 --> loss:0.7253, acc:70.36%, val_loss:1.6636, val_acc:37.76%
#  Epoch 141: iteration 35/35
# Epoch 141 --> loss:0.7132, acc:73.06%, val_loss:1.8355, val_acc:37.06%
#  Epoch 142: iteration 35/35
# Epoch 142 --> loss:0.7187, acc:72.45%, val_loss:1.6694, val_acc:41.96%
#  Epoch 143: iteration 35/35
# Epoch 143 --> loss:0.7469, acc:71.67%, val_loss:1.9425, val_acc:34.97%
#  Epoch 144: iteration 35/35
# Epoch 144 --> loss:0.7212, acc:71.49%, val_loss:1.6369, val_acc:40.56%
#  Epoch 145: iteration 35/35
# Epoch 145 --> loss:0.6857, acc:72.01%, val_loss:1.8485, val_acc:35.66%
#  Epoch 146: iteration 35/35
# Epoch 146 --> loss:0.6925, acc:73.50%, val_loss:1.3359, val_acc:51.75%
#  Epoch 147: iteration 35/35
# Epoch 147 --> loss:0.7001, acc:70.62%, val_loss:1.6711, val_acc:39.16%
#  Epoch 148: iteration 35/35
# Epoch 148 --> loss:0.6943, acc:72.10%, val_loss:1.3042, val_acc:53.15%
#  Epoch 149: iteration 35/35
# Epoch 149 --> loss:0.6621, acc:73.84%, val_loss:1.7386, val_acc:41.96%
#  Epoch 150: iteration 35/35
# Epoch 150 --> loss:0.6608, acc:74.02%, val_loss:1.6938, val_acc:40.56%
#  Epoch 151: iteration 35/35
# Epoch 151 --> loss:0.6421, acc:74.28%, val_loss:2.0466, val_acc:31.47%
#  Epoch 152: iteration 35/35
# Epoch 152 --> loss:0.6838, acc:72.10%, val_loss:1.7468, val_acc:37.06%
#  Epoch 153: iteration 35/35
# Epoch 153 --> loss:0.7093, acc:72.36%, val_loss:1.6427, val_acc:44.76%
#  Epoch 154: iteration 35/35
# Epoch 154 --> loss:0.6467, acc:72.36%, val_loss:1.7919, val_acc:37.06%
#  Epoch 155: iteration 35/35
# Epoch 155 --> loss:0.6449, acc:74.72%, val_loss:1.9978, val_acc:31.47%
#  Epoch 156: iteration 35/35
# Epoch 156 --> loss:0.6380, acc:74.80%, val_loss:1.5568, val_acc:42.66%
#  Epoch 157: iteration 35/35
# Epoch 157 --> loss:0.6414, acc:73.15%, val_loss:1.7755, val_acc:38.46%
#  Epoch 158: iteration 35/35
# Epoch 158 --> loss:0.6531, acc:74.19%, val_loss:1.5244, val_acc:46.15%
#  Epoch 159: iteration 35/35
# Epoch 159 --> loss:0.6468, acc:74.11%, val_loss:1.3205, val_acc:56.64%
#  Epoch 160: iteration 35/35
# Epoch 160 --> loss:0.6248, acc:76.29%, val_loss:1.7325, val_acc:39.86%
#  Epoch 161: iteration 35/35
# Epoch 161 --> loss:0.6481, acc:75.15%, val_loss:1.4001, val_acc:48.25%
#  Epoch 162: iteration 35/35
# Epoch 162 --> loss:0.6465, acc:74.46%, val_loss:1.3375, val_acc:53.85%
#  Epoch 163: iteration 35/35
# Epoch 163 --> loss:0.6354, acc:74.89%, val_loss:1.4255, val_acc:49.65%
#  Epoch 164: iteration 35/35
# Epoch 164 --> loss:0.5849, acc:76.37%, val_loss:1.4529, val_acc:52.45%
#  Epoch 165: iteration 35/35
# Epoch 165 --> loss:0.6351, acc:73.23%, val_loss:1.3645, val_acc:55.24%
#  Epoch 166: iteration 35/35
# Epoch 166 --> loss:0.6180, acc:74.98%, val_loss:1.3346, val_acc:50.35%
#  Epoch 167: iteration 35/35
# Epoch 167 --> loss:0.5970, acc:75.59%, val_loss:1.2885, val_acc:53.85%
#  Epoch 168: iteration 35/35
# Epoch 168 --> loss:0.5852, acc:77.86%, val_loss:1.4169, val_acc:53.15%
#  Epoch 169: iteration 35/35
# Epoch 169 --> loss:0.6038, acc:76.37%, val_loss:1.6904, val_acc:42.66%
#  Epoch 170: iteration 35/35
# Epoch 170 --> loss:0.5913, acc:76.46%, val_loss:1.3705, val_acc:53.85%
#  Epoch 171: iteration 35/35
# Epoch 171 --> loss:0.5949, acc:76.11%, val_loss:1.6347, val_acc:43.36%
#  Epoch 172: iteration 35/35
# Epoch 172 --> loss:0.6276, acc:75.41%, val_loss:1.3666, val_acc:55.24%
#  Epoch 173: iteration 35/35
# Epoch 173 --> loss:0.5704, acc:77.86%, val_loss:1.6881, val_acc:41.26%
#  Epoch 174: iteration 35/35
# Epoch 174 --> loss:0.5707, acc:74.46%, val_loss:1.3465, val_acc:53.85%
#  Epoch 175: iteration 35/35
# Epoch 175 --> loss:0.6189, acc:76.20%, val_loss:1.2518, val_acc:53.85%
#  Epoch 176: iteration 35/35
# Epoch 176 --> loss:0.5758, acc:76.55%, val_loss:1.3967, val_acc:51.75%
#  Epoch 177: iteration 35/35
# Epoch 177 --> loss:0.5498, acc:78.73%, val_loss:1.8193, val_acc:38.46%
#  Epoch 178: iteration 35/35
# Epoch 178 --> loss:0.5541, acc:77.77%, val_loss:1.5623, val_acc:46.85%
#  Epoch 179: iteration 35/35
# Epoch 179 --> loss:0.5908, acc:76.02%, val_loss:1.3306, val_acc:50.35%
#  Epoch 180: iteration 35/35
# Epoch 180 --> loss:0.5512, acc:77.86%, val_loss:1.1889, val_acc:54.55%
#  Epoch 181: iteration 35/35
# Epoch 181 --> loss:0.5242, acc:79.77%, val_loss:1.4807, val_acc:50.35%
#  Epoch 182: iteration 35/35
# Epoch 182 --> loss:0.5150, acc:79.16%, val_loss:1.6403, val_acc:41.96%
#  Epoch 183: iteration 35/35
# Epoch 183 --> loss:0.5362, acc:77.59%, val_loss:1.5680, val_acc:45.45%
#  Epoch 184: iteration 35/35
# Epoch 184 --> loss:0.5573, acc:78.64%, val_loss:1.8173, val_acc:40.56%
#  Epoch 185: iteration 35/35
# Epoch 185 --> loss:0.5379, acc:78.29%, val_loss:1.1407, val_acc:55.24%
#  Epoch 186: iteration 35/35
# Epoch 186 --> loss:0.5817, acc:76.98%, val_loss:1.5013, val_acc:50.35%
#  Epoch 187: iteration 35/35
# Epoch 187 --> loss:0.5385, acc:80.56%, val_loss:1.3928, val_acc:54.55%
#  Epoch 188: iteration 35/35
# Epoch 188 --> loss:0.5354, acc:78.55%, val_loss:1.4196, val_acc:53.15%
#  Epoch 189: iteration 35/35
# Epoch 189 --> loss:0.5351, acc:78.64%, val_loss:1.7330, val_acc:41.26%
#  Epoch 190: iteration 35/35
# Epoch 190 --> loss:0.4969, acc:79.34%, val_loss:1.6533, val_acc:44.06%
#  Epoch 191: iteration 35/35
# Epoch 191 --> loss:0.5357, acc:79.16%, val_loss:1.7781, val_acc:40.56%
#  Epoch 192: iteration 35/35
# Epoch 192 --> loss:0.5361, acc:78.90%, val_loss:1.3155, val_acc:52.45%
#  Epoch 193: iteration 35/35
# Epoch 193 --> loss:0.5247, acc:78.99%, val_loss:1.5624, val_acc:44.76%
#  Epoch 194: iteration 35/35
# Epoch 194 --> loss:0.5520, acc:77.42%, val_loss:1.3285, val_acc:55.24%
#  Epoch 195: iteration 35/35
# Epoch 195 --> loss:0.5146, acc:80.03%, val_loss:1.6231, val_acc:42.66%
#  Epoch 196: iteration 35/35
# Epoch 196 --> loss:0.4729, acc:80.03%, val_loss:1.5573, val_acc:44.76%
#  Epoch 197: iteration 35/35
# Epoch 197 --> loss:0.5006, acc:78.64%, val_loss:1.2442, val_acc:54.55%
#  Epoch 198: iteration 35/35
# Epoch 198 --> loss:0.4668, acc:81.60%, val_loss:1.4225, val_acc:50.35%
#  Epoch 199: iteration 35/35
# Epoch 199 --> loss:0.4834, acc:80.21%, val_loss:1.7386, val_acc:43.36%
#  Epoch 200: iteration 35/35
# Epoch 200 --> loss:0.4801, acc:79.95%, val_loss:1.2595, val_acc:54.55%
#  Epoch 201: iteration 35/35
# Epoch 201 --> loss:0.4715, acc:81.60%, val_loss:1.3216, val_acc:52.45%
#  Epoch 202: iteration 35/35
# Epoch 202 --> loss:0.4994, acc:79.51%, val_loss:1.3689, val_acc:50.35%
#  Epoch 203: iteration 35/35
# Epoch 203 --> loss:0.4545, acc:82.21%, val_loss:1.4885, val_acc:48.95%
#  Epoch 204: iteration 35/35
# Epoch 204 --> loss:0.4899, acc:79.95%, val_loss:1.3211, val_acc:58.74%
#  Epoch 205: iteration 35/35
# Epoch 205 --> loss:0.4860, acc:80.03%, val_loss:1.3804, val_acc:51.75%
#  Epoch 206: iteration 35/35
# Epoch 206 --> loss:0.5022, acc:79.86%, val_loss:1.4987, val_acc:48.25%
#  Epoch 207: iteration 35/35
# Epoch 207 --> loss:0.4380, acc:81.60%, val_loss:1.4080, val_acc:44.06%
#  Epoch 208: iteration 35/35
# Epoch 208 --> loss:0.4495, acc:81.60%, val_loss:1.4079, val_acc:50.35%
#  Epoch 209: iteration 35/35
# Epoch 209 --> loss:0.5001, acc:78.20%, val_loss:1.5637, val_acc:46.85%
#  Epoch 210: iteration 35/35
# Epoch 210 --> loss:0.4828, acc:80.03%, val_loss:1.2712, val_acc:53.15%
#  Epoch 211: iteration 35/35
# Epoch 211 --> loss:0.4430, acc:81.95%, val_loss:1.2381, val_acc:56.64%
#  Epoch 212: iteration 35/35
# Epoch 212 --> loss:0.4171, acc:83.52%, val_loss:1.6079, val_acc:46.15%
#  Epoch 213: iteration 35/35
# Epoch 213 --> loss:0.4602, acc:81.43%, val_loss:1.5829, val_acc:46.85%
#  Epoch 214: iteration 35/35
# Epoch 214 --> loss:0.4465, acc:81.95%, val_loss:1.4415, val_acc:50.35%
#  Epoch 215: iteration 35/35
# Epoch 215 --> loss:0.4245, acc:82.48%, val_loss:1.3421, val_acc:46.15%
#  Epoch 216: iteration 35/35
# Epoch 216 --> loss:0.4316, acc:83.09%, val_loss:1.3806, val_acc:51.05%
#  Epoch 217: iteration 35/35
# Epoch 217 --> loss:0.4469, acc:81.17%, val_loss:1.2329, val_acc:56.64%
#  Epoch 218: iteration 35/35
# Epoch 218 --> loss:0.4466, acc:81.69%, val_loss:1.5125, val_acc:48.95%
#  Epoch 219: iteration 35/35
# Epoch 219 --> loss:0.4432, acc:82.39%, val_loss:1.3453, val_acc:51.75%
#  Epoch 220: iteration 35/35
# Epoch 220 --> loss:0.5031, acc:80.12%, val_loss:1.2031, val_acc:55.24%
#  Epoch 221: iteration 35/35
# Epoch 221 --> loss:0.4502, acc:82.30%, val_loss:1.4219, val_acc:47.55%
#  Epoch 222: iteration 35/35
# Epoch 222 --> loss:0.4148, acc:83.09%, val_loss:1.2418, val_acc:57.34%
#  Epoch 223: iteration 35/35
# Epoch 223 --> loss:0.4289, acc:82.74%, val_loss:1.3017, val_acc:51.05%
#  Epoch 224: iteration 35/35
# Epoch 224 --> loss:0.3969, acc:82.04%, val_loss:1.4175, val_acc:49.65%
#  Epoch 225: iteration 35/35
# Epoch 225 --> loss:0.4262, acc:82.82%, val_loss:1.1596, val_acc:55.24%
#  Epoch 226: iteration 35/35
# Epoch 226 --> loss:0.4436, acc:80.99%, val_loss:1.4517, val_acc:50.35%
#  Epoch 227: iteration 35/35
# Epoch 227 --> loss:0.3821, acc:84.22%, val_loss:1.4118, val_acc:53.15%
#  Epoch 228: iteration 35/35
# Epoch 228 --> loss:0.4018, acc:83.61%, val_loss:1.3549, val_acc:55.94%
#  Epoch 229: iteration 35/35
# Epoch 229 --> loss:0.4377, acc:81.95%, val_loss:1.4010, val_acc:50.35%
#  Epoch 230: iteration 35/35
# Epoch 230 --> loss:0.4227, acc:81.95%, val_loss:1.4644, val_acc:49.65%
#  Epoch 231: iteration 35/35
# Epoch 231 --> loss:0.4018, acc:83.96%, val_loss:1.4221, val_acc:50.35%
#  Epoch 232: iteration 35/35
# Epoch 232 --> loss:0.4126, acc:83.17%, val_loss:1.2032, val_acc:59.44%
#  Epoch 233: iteration 35/35
# Epoch 233 --> loss:0.4484, acc:82.04%, val_loss:1.4129, val_acc:53.15%
#  Epoch 234: iteration 35/35
# Epoch 234 --> loss:0.4061, acc:82.65%, val_loss:1.6860, val_acc:43.36%
#  Epoch 235: iteration 35/35
# Epoch 235 --> loss:0.4211, acc:83.09%, val_loss:1.3603, val_acc:57.34%
#  Epoch 236: iteration 35/35
# Epoch 236 --> loss:0.3915, acc:84.13%, val_loss:1.5251, val_acc:45.45%
#  Epoch 237: iteration 35/35
# Epoch 237 --> loss:0.4200, acc:82.56%, val_loss:1.1674, val_acc:60.84%
#  Epoch 238: iteration 35/35
# Epoch 238 --> loss:0.3663, acc:85.00%, val_loss:1.2026, val_acc:58.74%
#  Epoch 239: iteration 35/35
# Epoch 239 --> loss:0.4115, acc:83.26%, val_loss:1.6954, val_acc:45.45%
#  Epoch 240: iteration 35/35
# Epoch 240 --> loss:0.4477, acc:81.95%, val_loss:1.2159, val_acc:57.34%
#  Epoch 241: iteration 35/35
# Epoch 241 --> loss:0.3858, acc:84.48%, val_loss:1.5259, val_acc:51.05%
#  Epoch 242: iteration 35/35
# Epoch 242 --> loss:0.3924, acc:83.61%, val_loss:1.2898, val_acc:51.05%
#  Epoch 243: iteration 35/35
# Epoch 243 --> loss:0.4057, acc:83.26%, val_loss:1.3289, val_acc:48.95%
#  Epoch 244: iteration 35/35
# Epoch 244 --> loss:0.3573, acc:85.18%, val_loss:1.4180, val_acc:50.35%
#  Epoch 245: iteration 35/35
# Epoch 245 --> loss:0.4015, acc:82.91%, val_loss:1.6845, val_acc:46.85%
#  Epoch 246: iteration 35/35
# Epoch 246 --> loss:0.3939, acc:82.82%, val_loss:1.4990, val_acc:49.65%
#  Epoch 247: iteration 35/35
# Epoch 247 --> loss:0.3888, acc:83.61%, val_loss:1.1497, val_acc:58.74%
#  Epoch 248: iteration 35/35
# Epoch 248 --> loss:0.3590, acc:83.87%, val_loss:1.3354, val_acc:53.85%
#  Epoch 249: iteration 35/35
# Epoch 249 --> loss:0.3776, acc:83.52%, val_loss:1.6690, val_acc:44.06%
#  Epoch 250: iteration 35/35
# Epoch 250 --> loss:0.3954, acc:82.48%, val_loss:1.3844, val_acc:53.15%
#  Epoch 251: iteration 35/35
# Epoch 251 --> loss:0.3727, acc:83.96%, val_loss:1.3408, val_acc:53.85%
#  Epoch 252: iteration 35/35
# Epoch 252 --> loss:0.3803, acc:85.00%, val_loss:1.2911, val_acc:51.05%
#  Epoch 253: iteration 35/35
# Epoch 253 --> loss:0.3828, acc:83.96%, val_loss:1.4135, val_acc:49.65%
#  Epoch 254: iteration 35/35
# Epoch 254 --> loss:0.3953, acc:82.56%, val_loss:1.4134, val_acc:51.75%
#  Epoch 255: iteration 35/35
# Epoch 255 --> loss:0.3919, acc:84.39%, val_loss:1.4804, val_acc:50.35%
#  Epoch 256: iteration 35/35
# Epoch 256 --> loss:0.3661, acc:84.92%, val_loss:1.4998, val_acc:51.05%
#  Epoch 257: iteration 35/35
# Epoch 257 --> loss:0.3795, acc:84.39%, val_loss:1.4296, val_acc:52.45%
#  Epoch 258: iteration 35/35
# Epoch 258 --> loss:0.3441, acc:85.79%, val_loss:1.6778, val_acc:47.55%
#  Epoch 259: iteration 35/35
# Epoch 259 --> loss:0.3950, acc:83.44%, val_loss:1.3368, val_acc:54.55%
#  Epoch 260: iteration 35/35
# Epoch 260 --> loss:0.3885, acc:84.31%, val_loss:1.4226, val_acc:51.05%
#  Epoch 261: iteration 35/35
# Epoch 261 --> loss:0.3835, acc:83.35%, val_loss:1.4633, val_acc:51.05%
#  Epoch 262: iteration 35/35
# Epoch 262 --> loss:0.3289, acc:86.14%, val_loss:1.3237, val_acc:56.64%
#  Epoch 263: iteration 35/35
# Epoch 263 --> loss:0.3463, acc:85.70%, val_loss:1.4001, val_acc:55.24%
#  Epoch 264: iteration 35/35
# Epoch 264 --> loss:0.3682, acc:84.31%, val_loss:1.2205, val_acc:53.15%
#  Epoch 265: iteration 35/35
# Epoch 265 --> loss:0.3506, acc:85.35%, val_loss:1.2402, val_acc:59.44%
#  Epoch 266: iteration 35/35
# Epoch 266 --> loss:0.3495, acc:85.18%, val_loss:1.5767, val_acc:47.55%
#  Epoch 267: iteration 35/35
# Epoch 267 --> loss:0.3455, acc:85.35%, val_loss:1.3583, val_acc:58.04%
#  Epoch 268: iteration 35/35
# Epoch 268 --> loss:0.3897, acc:83.35%, val_loss:1.2442, val_acc:58.74%
#  Epoch 269: iteration 35/35
# Epoch 269 --> loss:0.3356, acc:85.79%, val_loss:1.5064, val_acc:48.95%
#  Epoch 270: iteration 35/35
# Epoch 270 --> loss:0.3597, acc:85.09%, val_loss:1.2518, val_acc:58.04%
#  Epoch 271: iteration 35/35
# Epoch 271 --> loss:0.3546, acc:85.88%, val_loss:1.6478, val_acc:48.25%
#  Epoch 272: iteration 35/35
# Epoch 272 --> loss:0.3559, acc:85.27%, val_loss:1.2925, val_acc:62.24%
#  Epoch 273: iteration 35/35
# Epoch 273 --> loss:0.3808, acc:84.05%, val_loss:1.2311, val_acc:56.64%
#  Epoch 274: iteration 35/35
# Epoch 274 --> loss:0.3422, acc:86.05%, val_loss:1.2960, val_acc:55.24%
#  Epoch 275: iteration 35/35
# Epoch 275 --> loss:0.3356, acc:85.53%, val_loss:1.3339, val_acc:58.04%
#  Epoch 276: iteration 35/35
# Epoch 276 --> loss:0.3477, acc:85.44%, val_loss:1.3875, val_acc:53.15%
#  Epoch 277: iteration 35/35
# Epoch 277 --> loss:0.3492, acc:85.96%, val_loss:1.6060, val_acc:46.15%
#  Epoch 278: iteration 35/35
# Epoch 278 --> loss:0.3533, acc:84.92%, val_loss:1.4954, val_acc:49.65%
#  Epoch 279: iteration 35/35
# Epoch 279 --> loss:0.3086, acc:86.92%, val_loss:1.3328, val_acc:52.45%
#  Epoch 280: iteration 35/35
# Epoch 280 --> loss:0.3227, acc:86.31%, val_loss:1.4855, val_acc:54.55%
#  Epoch 281: iteration 35/35
# Epoch 281 --> loss:0.3240, acc:86.40%, val_loss:1.4178, val_acc:55.94%
#  Epoch 282: iteration 35/35
# Epoch 282 --> loss:0.3337, acc:85.53%, val_loss:1.6697, val_acc:42.66%
#  Epoch 283: iteration 35/35
# Epoch 283 --> loss:0.2933, acc:88.75%, val_loss:1.5805, val_acc:45.45%
#  Epoch 284: iteration 35/35
# Epoch 284 --> loss:0.3512, acc:84.48%, val_loss:1.3574, val_acc:51.75%
#  Epoch 285: iteration 35/35
# Epoch 285 --> loss:0.3538, acc:84.74%, val_loss:1.6269, val_acc:50.35%
#  Epoch 286: iteration 35/35
# Epoch 286 --> loss:0.3510, acc:85.35%, val_loss:1.9457, val_acc:39.16%
#  Epoch 287: iteration 35/35
# Epoch 287 --> loss:0.3437, acc:85.88%, val_loss:1.4143, val_acc:58.74%
#  Epoch 288: iteration 35/35
# Epoch 288 --> loss:0.3154, acc:86.40%, val_loss:1.5616, val_acc:47.55%
#  Epoch 289: iteration 35/35
# Epoch 289 --> loss:0.3181, acc:86.75%, val_loss:1.2441, val_acc:57.34%
#  Epoch 290: iteration 35/35
# Epoch 290 --> loss:0.3413, acc:85.09%, val_loss:1.0630, val_acc:60.14%
#  Epoch 291: iteration 35/35
# Epoch 291 --> loss:0.3075, acc:87.27%, val_loss:1.2236, val_acc:59.44%
#  Epoch 292: iteration 35/35
# Epoch 292 --> loss:0.3009, acc:87.97%, val_loss:1.3985, val_acc:53.85%
#  Epoch 293: iteration 35/35
# Epoch 293 --> loss:0.3085, acc:87.62%, val_loss:1.2263, val_acc:56.64%
#  Epoch 294: iteration 35/35
# Epoch 294 --> loss:0.3241, acc:86.22%, val_loss:1.2380, val_acc:59.44%
#  Epoch 295: iteration 35/35
# Epoch 295 --> loss:0.3170, acc:86.84%, val_loss:1.3288, val_acc:51.75%
#  Epoch 296: iteration 35/35
# Epoch 296 --> loss:0.3306, acc:86.14%, val_loss:1.3471, val_acc:55.24%
#  Epoch 297: iteration 35/35
# Epoch 297 --> loss:0.3273, acc:86.57%, val_loss:1.2528, val_acc:58.04%
#  Epoch 298: iteration 35/35
# Epoch 298 --> loss:0.3046, acc:88.06%, val_loss:1.2234, val_acc:58.74%
#  Epoch 299: iteration 35/35
# Epoch 299 --> loss:0.3192, acc:85.96%, val_loss:1.7564, val_acc:48.25%
#  Epoch 300: iteration 35/35
# Epoch 300 --> loss:0.2883, acc:87.97%, val_loss:1.3434, val_acc:54.55%
#  Epoch 301: iteration 35/35
# Epoch 301 --> loss:0.3186, acc:86.84%, val_loss:1.2992, val_acc:57.34%
#  Epoch 302: iteration 35/35
# Epoch 302 --> loss:0.3050, acc:87.27%, val_loss:1.5537, val_acc:49.65%
#  Epoch 303: iteration 35/35
# Epoch 303 --> loss:0.3076, acc:86.75%, val_loss:1.3804, val_acc:58.04%
#  Epoch 304: iteration 35/35
# Epoch 304 --> loss:0.3276, acc:86.84%, val_loss:1.5448, val_acc:53.15%
#  Epoch 305: iteration 35/35
# Epoch 305 --> loss:0.2688, acc:89.10%, val_loss:1.3050, val_acc:57.34%
#  Epoch 306: iteration 35/35
# Epoch 306 --> loss:0.3204, acc:86.84%, val_loss:1.1775, val_acc:60.84%
#  Epoch 307: iteration 35/35
# Epoch 307 --> loss:0.2975, acc:87.36%, val_loss:1.2297, val_acc:58.04%
#  Epoch 308: iteration 35/35
# Epoch 308 --> loss:0.2923, acc:87.36%, val_loss:1.3672, val_acc:53.85%
#  Epoch 309: iteration 35/35
# Epoch 309 --> loss:0.3235, acc:86.14%, val_loss:1.1481, val_acc:57.34%
#  Epoch 310: iteration 35/35
# Epoch 310 --> loss:0.3334, acc:86.31%, val_loss:1.1780, val_acc:61.54%
#  Epoch 311: iteration 35/35
# Epoch 311 --> loss:0.2865, acc:87.36%, val_loss:1.4855, val_acc:57.34%
#  Epoch 312: iteration 35/35
# Epoch 312 --> loss:0.2912, acc:87.45%, val_loss:1.4774, val_acc:53.15%
#  Epoch 313: iteration 35/35
# Epoch 313 --> loss:0.2917, acc:87.88%, val_loss:1.6404, val_acc:45.45%
#  Epoch 314: iteration 35/35
# Epoch 314 --> loss:0.2870, acc:87.79%, val_loss:1.3880, val_acc:53.85%
#  Epoch 315: iteration 35/35
# Epoch 315 --> loss:0.2959, acc:86.40%, val_loss:1.2761, val_acc:56.64%
#  Epoch 316: iteration 35/35
# Epoch 316 --> loss:0.2663, acc:88.40%, val_loss:1.3769, val_acc:56.64%
#  Epoch 317: iteration 35/35
# Epoch 317 --> loss:0.3038, acc:87.62%, val_loss:1.3622, val_acc:55.24%
#  Epoch 318: iteration 35/35
# Epoch 318 --> loss:0.3219, acc:85.53%, val_loss:1.1714, val_acc:57.34%
#  Epoch 319: iteration 35/35
# Epoch 319 --> loss:0.2898, acc:88.06%, val_loss:1.3595, val_acc:56.64%
#  Epoch 320: iteration 35/35
# Epoch 320 --> loss:0.3141, acc:86.84%, val_loss:1.3694, val_acc:57.34%
#  Epoch 321: iteration 35/35
# Epoch 321 --> loss:0.2578, acc:87.79%, val_loss:1.4901, val_acc:53.15%
#  Epoch 322: iteration 35/35
# Epoch 322 --> loss:0.2951, acc:87.18%, val_loss:1.1812, val_acc:57.34%
#  Epoch 323: iteration 35/35
# Epoch 323 --> loss:0.2975, acc:87.10%, val_loss:1.5480, val_acc:49.65%
#  Epoch 324: iteration 35/35
# Epoch 324 --> loss:0.3136, acc:86.40%, val_loss:1.4356, val_acc:51.05%
#  Epoch 325: iteration 35/35
# Epoch 325 --> loss:0.2998, acc:86.57%, val_loss:1.2936, val_acc:58.74%
#  Epoch 326: iteration 35/35
# Epoch 326 --> loss:0.2629, acc:88.23%, val_loss:1.4697, val_acc:49.65%
#  Epoch 327: iteration 35/35
# Epoch 327 --> loss:0.2929, acc:87.36%, val_loss:1.4275, val_acc:55.24%
#  Epoch 328: iteration 35/35
# Epoch 328 --> loss:0.2978, acc:87.18%, val_loss:1.3100, val_acc:51.05%
#  Epoch 329: iteration 35/35
# Epoch 329 --> loss:0.2750, acc:87.79%, val_loss:1.2654, val_acc:57.34%
#  Epoch 330: iteration 35/35
# Epoch 330 --> loss:0.2811, acc:87.45%, val_loss:1.3496, val_acc:48.95%
#  Epoch 331: iteration 35/35
# Epoch 331 --> loss:0.2901, acc:87.71%, val_loss:1.4262, val_acc:51.05%
#  Epoch 332: iteration 35/35
# Epoch 332 --> loss:0.2721, acc:89.01%, val_loss:1.4103, val_acc:53.15%
#  Epoch 333: iteration 35/35
# Epoch 333 --> loss:0.2732, acc:88.23%, val_loss:1.3375, val_acc:55.94%
#  Epoch 334: iteration 35/35
# Epoch 334 --> loss:0.2651, acc:87.88%, val_loss:1.3255, val_acc:55.94%
#  Epoch 335: iteration 35/35
# Epoch 335 --> loss:0.2780, acc:88.14%, val_loss:1.2759, val_acc:56.64%
#  Epoch 336: iteration 35/35
# Epoch 336 --> loss:0.3147, acc:86.31%, val_loss:1.3332, val_acc:52.45%
#  Epoch 337: iteration 35/35
# Epoch 337 --> loss:0.2757, acc:88.75%, val_loss:1.4364, val_acc:51.75%
#  Epoch 338: iteration 35/35
# Epoch 338 --> loss:0.3040, acc:87.01%, val_loss:1.4045, val_acc:51.05%
#  Epoch 339: iteration 35/35
# Epoch 339 --> loss:0.2966, acc:87.36%, val_loss:1.0635, val_acc:60.84%
#  Epoch 340: iteration 35/35
# Epoch 340 --> loss:0.2777, acc:88.32%, val_loss:1.3765, val_acc:55.94%
#  Epoch 341: iteration 35/35
# Epoch 341 --> loss:0.2633, acc:89.01%, val_loss:1.3007, val_acc:60.14%
#  Epoch 342: iteration 35/35
# Epoch 342 --> loss:0.2970, acc:87.36%, val_loss:1.0981, val_acc:60.84%
#  Epoch 343: iteration 35/35
# Epoch 343 --> loss:0.2673, acc:88.67%, val_loss:1.3670, val_acc:53.15%
#  Epoch 344: iteration 35/35
# Epoch 344 --> loss:0.2516, acc:89.45%, val_loss:1.4629, val_acc:54.55%
#  Epoch 345: iteration 35/35
# Epoch 345 --> loss:0.2617, acc:88.49%, val_loss:1.4390, val_acc:51.05%
#  Epoch 346: iteration 35/35
# Epoch 346 --> loss:0.2756, acc:88.06%, val_loss:1.4163, val_acc:54.55%
#  Epoch 347: iteration 35/35
# Epoch 347 --> loss:0.3141, acc:86.75%, val_loss:1.3191, val_acc:55.24%
#  Epoch 348: iteration 35/35
# Epoch 348 --> loss:0.2670, acc:89.01%, val_loss:1.3885, val_acc:51.05%
#  Epoch 349: iteration 35/35
# Epoch 349 --> loss:0.2542, acc:89.10%, val_loss:1.3779, val_acc:53.85%
#  Epoch 350: iteration 35/35
# Epoch 350 --> loss:0.2745, acc:88.14%, val_loss:1.2099, val_acc:60.14%
#  Epoch 351: iteration 35/35
# Epoch 351 --> loss:0.2659, acc:88.14%, val_loss:1.3481, val_acc:57.34%
#  Epoch 352: iteration 35/35
# Epoch 352 --> loss:0.2818, acc:87.97%, val_loss:1.3518, val_acc:55.24%
#  Epoch 353: iteration 35/35
# Epoch 353 --> loss:0.2571, acc:89.01%, val_loss:1.4195, val_acc:58.74%
#  Epoch 354: iteration 35/35
# Epoch 354 --> loss:0.2904, acc:87.71%, val_loss:1.2916, val_acc:55.24%
#  Epoch 355: iteration 35/35
# Epoch 355 --> loss:0.2648, acc:88.49%, val_loss:1.2849, val_acc:58.74%
#  Epoch 356: iteration 35/35
# Epoch 356 --> loss:0.2537, acc:88.67%, val_loss:1.1067, val_acc:55.94%
#  Epoch 357: iteration 35/35
# Epoch 357 --> loss:0.2789, acc:87.88%, val_loss:1.3210, val_acc:55.24%
#  Epoch 358: iteration 35/35
# Epoch 358 --> loss:0.2568, acc:88.23%, val_loss:1.1525, val_acc:60.14%
#  Epoch 359: iteration 35/35
# Epoch 359 --> loss:0.2820, acc:88.40%, val_loss:1.3830, val_acc:55.94%
#  Epoch 360: iteration 35/35
# Epoch 360 --> loss:0.2359, acc:90.32%, val_loss:1.3315, val_acc:53.15%
#  Epoch 361: iteration 35/35
# Epoch 361 --> loss:0.2539, acc:89.10%, val_loss:1.1420, val_acc:51.75%
#  Epoch 362: iteration 35/35
# Epoch 362 --> loss:0.2718, acc:88.32%, val_loss:1.1666, val_acc:63.64%
#  Epoch 363: iteration 35/35
# Epoch 363 --> loss:0.2469, acc:89.71%, val_loss:1.2638, val_acc:58.74%
#  Epoch 364: iteration 35/35
# Epoch 364 --> loss:0.2655, acc:88.49%, val_loss:1.2672, val_acc:56.64%
#  Epoch 365: iteration 35/35
# Epoch 365 --> loss:0.2522, acc:89.01%, val_loss:1.6060, val_acc:49.65%
#  Epoch 366: iteration 35/35
# Epoch 366 --> loss:0.2767, acc:88.40%, val_loss:1.0699, val_acc:64.34%
#  Epoch 367: iteration 35/35
# Epoch 367 --> loss:0.2677, acc:87.88%, val_loss:1.2539, val_acc:58.74%
#  Epoch 368: iteration 35/35
# Epoch 368 --> loss:0.2566, acc:88.67%, val_loss:1.2512, val_acc:58.74%
#  Epoch 369: iteration 35/35
# Epoch 369 --> loss:0.2325, acc:89.80%, val_loss:1.3039, val_acc:58.74%
#  Epoch 370: iteration 35/35
# Epoch 370 --> loss:0.2383, acc:89.10%, val_loss:1.2732, val_acc:58.04%
#  Epoch 371: iteration 35/35
# Epoch 371 --> loss:0.2725, acc:87.88%, val_loss:1.7805, val_acc:44.76%
#  Epoch 372: iteration 35/35
# Epoch 372 --> loss:0.2440, acc:88.67%, val_loss:1.2541, val_acc:56.64%
#  Epoch 373: iteration 35/35
# Epoch 373 --> loss:0.2851, acc:88.06%, val_loss:1.3688, val_acc:56.64%
#  Epoch 374: iteration 35/35
# Epoch 374 --> loss:0.2915, acc:87.97%, val_loss:1.4964, val_acc:57.34%
#  Epoch 375: iteration 35/35
# Epoch 375 --> loss:0.2368, acc:89.89%, val_loss:1.4794, val_acc:52.45%
#  Epoch 376: iteration 35/35
# Epoch 376 --> loss:0.2614, acc:88.14%, val_loss:1.5013, val_acc:51.05%
#  Epoch 377: iteration 35/35
# Epoch 377 --> loss:0.2784, acc:87.36%, val_loss:1.3522, val_acc:56.64%
#  Epoch 378: iteration 35/35
# Epoch 378 --> loss:0.2450, acc:89.63%, val_loss:0.9685, val_acc:62.94%
#  Epoch 379: iteration 35/35
# Epoch 379 --> loss:0.2394, acc:90.06%, val_loss:1.4598, val_acc:52.45%
#  Epoch 380: iteration 35/35
# Epoch 380 --> loss:0.2384, acc:89.97%, val_loss:1.2224, val_acc:58.74%
#  Epoch 381: iteration 35/35
# Epoch 381 --> loss:0.2588, acc:88.49%, val_loss:1.2659, val_acc:53.15%
#  Epoch 382: iteration 35/35
# Epoch 382 --> loss:0.2639, acc:88.40%, val_loss:1.2123, val_acc:61.54%
#  Epoch 383: iteration 35/35
# Epoch 383 --> loss:0.2392, acc:89.54%, val_loss:1.2872, val_acc:57.34%
#  Epoch 384: iteration 35/35
# Epoch 384 --> loss:0.2507, acc:89.28%, val_loss:1.3237, val_acc:57.34%
#  Epoch 385: iteration 35/35
# Epoch 385 --> loss:0.2504, acc:89.89%, val_loss:1.1823, val_acc:56.64%
#  Epoch 386: iteration 35/35
# Epoch 386 --> loss:0.2552, acc:88.40%, val_loss:1.1134, val_acc:60.14%
#  Epoch 387: iteration 35/35
# Epoch 387 --> loss:0.2433, acc:88.84%, val_loss:1.9819, val_acc:36.36%
#  Epoch 388: iteration 35/35
# Epoch 388 --> loss:0.2608, acc:88.67%, val_loss:1.4170, val_acc:52.45%
#  Epoch 389: iteration 35/35
# Epoch 389 --> loss:0.2499, acc:89.45%, val_loss:1.5184, val_acc:56.64%
#  Epoch 390: iteration 35/35
# Epoch 390 --> loss:0.2752, acc:88.32%, val_loss:1.0907, val_acc:61.54%
#  Epoch 391: iteration 35/35
# Epoch 391 --> loss:0.2509, acc:89.10%, val_loss:1.6113, val_acc:48.25%
#  Epoch 392: iteration 35/35
# Epoch 392 --> loss:0.2336, acc:89.71%, val_loss:1.0936, val_acc:58.74%
#  Epoch 393: iteration 35/35
# Epoch 393 --> loss:0.2410, acc:88.93%, val_loss:1.5704, val_acc:49.65%
#  Epoch 394: iteration 35/35
# Epoch 394 --> loss:0.2250, acc:89.45%, val_loss:1.4192, val_acc:52.45%
#  Epoch 395: iteration 35/35
# Epoch 395 --> loss:0.2526, acc:89.89%, val_loss:1.1907, val_acc:58.74%
#  Epoch 396: iteration 35/35
# Epoch 396 --> loss:0.2677, acc:88.75%, val_loss:1.2157, val_acc:53.85%
#  Epoch 397: iteration 35/35
# Epoch 397 --> loss:0.2645, acc:88.23%, val_loss:1.0869, val_acc:55.24%
#  Epoch 398: iteration 35/35
# Epoch 398 --> loss:0.2470, acc:89.19%, val_loss:1.6702, val_acc:47.55%
#  Epoch 399: iteration 35/35
# Epoch 399 --> loss:0.2431, acc:89.45%, val_loss:1.5806, val_acc:51.75%
#  Epoch 400: iteration 35/35
# Epoch 400 --> loss:0.2458, acc:89.54%, val_loss:1.4375, val_acc:55.24%
#  Epoch 401: iteration 35/35
# Epoch 401 --> loss:0.2451, acc:88.93%, val_loss:1.6281, val_acc:49.65%
#  Epoch 402: iteration 35/35
# Epoch 402 --> loss:0.2263, acc:90.15%, val_loss:1.5922, val_acc:50.35%
#  Epoch 403: iteration 35/35
# Epoch 403 --> loss:0.2428, acc:89.54%, val_loss:1.2477, val_acc:56.64%
#  Epoch 404: iteration 35/35
# Epoch 404 --> loss:0.2523, acc:88.58%, val_loss:1.3695, val_acc:49.65%
#  Epoch 405: iteration 35/35
# Epoch 405 --> loss:0.2522, acc:89.19%, val_loss:1.2827, val_acc:62.94%
#  Epoch 406: iteration 35/35
# Epoch 406 --> loss:0.2251, acc:90.15%, val_loss:1.4048, val_acc:56.64%
#  Epoch 407: iteration 35/35
# Epoch 407 --> loss:0.2486, acc:88.84%, val_loss:1.5829, val_acc:43.36%
#  Epoch 408: iteration 35/35
# Epoch 408 --> loss:0.2491, acc:88.32%, val_loss:1.3381, val_acc:57.34%
#  Epoch 409: iteration 35/35
# Epoch 409 --> loss:0.2250, acc:90.58%, val_loss:1.4197, val_acc:54.55%
#  Epoch 410: iteration 35/35
# Epoch 410 --> loss:0.2571, acc:88.32%, val_loss:1.2966, val_acc:55.94%
#  Epoch 411: iteration 35/35
# Epoch 411 --> loss:0.2441, acc:89.01%, val_loss:1.3108, val_acc:55.24%
#  Epoch 412: iteration 35/35
# Epoch 412 --> loss:0.2113, acc:91.28%, val_loss:1.1662, val_acc:60.84%
#  Epoch 413: iteration 35/35
# Epoch 413 --> loss:0.2352, acc:89.89%, val_loss:1.3839, val_acc:55.94%
#  Epoch 414: iteration 35/35
# Epoch 414 --> loss:0.2405, acc:89.97%, val_loss:1.4147, val_acc:55.24%
#  Epoch 415: iteration 35/35
# Epoch 415 --> loss:0.2651, acc:87.36%, val_loss:1.5401, val_acc:49.65%
#  Epoch 416: iteration 35/35
# Epoch 416 --> loss:0.1882, acc:92.76%, val_loss:1.0764, val_acc:65.73%
#  Epoch 417: iteration 35/35
# Epoch 417 --> loss:0.2828, acc:87.45%, val_loss:1.1627, val_acc:56.64%
#  Epoch 418: iteration 35/35
# Epoch 418 --> loss:0.2679, acc:88.84%, val_loss:1.1810, val_acc:56.64%
#  Epoch 419: iteration 35/35
# Epoch 419 --> loss:0.2319, acc:90.24%, val_loss:1.3878, val_acc:53.15%
#  Epoch 420: iteration 35/35
# Epoch 420 --> loss:0.2244, acc:90.06%, val_loss:1.1103, val_acc:62.24%
#  Epoch 421: iteration 35/35
# Epoch 421 --> loss:0.2384, acc:89.97%, val_loss:1.4926, val_acc:47.55%
#  Epoch 422: iteration 35/35
# Epoch 422 --> loss:0.2271, acc:90.24%, val_loss:1.3144, val_acc:58.74%
#  Epoch 423: iteration 35/35
# Epoch 423 --> loss:0.2195, acc:90.15%, val_loss:1.4877, val_acc:51.75%
#  Epoch 424: iteration 35/35
# Epoch 424 --> loss:0.2115, acc:90.58%, val_loss:1.1720, val_acc:60.84%
#  Epoch 425: iteration 35/35
# Epoch 425 --> loss:0.2104, acc:90.24%, val_loss:1.3800, val_acc:53.85%
#  Epoch 426: iteration 35/35
# Epoch 426 --> loss:0.2395, acc:89.10%, val_loss:1.4873, val_acc:54.55%
#  Epoch 427: iteration 35/35
# Epoch 427 --> loss:0.2273, acc:89.10%, val_loss:1.1289, val_acc:61.54%
#  Epoch 428: iteration 35/35
# Epoch 428 --> loss:0.2269, acc:89.89%, val_loss:1.2835, val_acc:59.44%
#  Epoch 429: iteration 35/35
# Epoch 429 --> loss:0.2335, acc:90.24%, val_loss:1.5007, val_acc:57.34%
#  Epoch 430: iteration 35/35
# Epoch 430 --> loss:0.2532, acc:88.58%, val_loss:1.1998, val_acc:55.94%
#  Epoch 431: iteration 35/35
# Epoch 431 --> loss:0.2439, acc:88.93%, val_loss:1.5123, val_acc:49.65%
#  Epoch 432: iteration 35/35
# Epoch 432 --> loss:0.2626, acc:88.40%, val_loss:0.9865, val_acc:67.13%
#  Epoch 433: iteration 35/35
# Epoch 433 --> loss:0.2156, acc:90.32%, val_loss:1.3309, val_acc:53.15%
#  Epoch 434: iteration 35/35
# Epoch 434 --> loss:0.2063, acc:91.28%, val_loss:1.3110, val_acc:57.34%
#  Epoch 435: iteration 35/35
# Epoch 435 --> loss:0.2300, acc:89.71%, val_loss:1.4305, val_acc:54.55%
#  Epoch 436: iteration 35/35
# Epoch 436 --> loss:0.2133, acc:91.19%, val_loss:1.1716, val_acc:60.14%
#  Epoch 437: iteration 35/35
# Epoch 437 --> loss:0.2493, acc:88.93%, val_loss:1.2148, val_acc:58.04%
#  Epoch 438: iteration 35/35
# Epoch 438 --> loss:0.2331, acc:89.10%, val_loss:1.3479, val_acc:55.94%
#  Epoch 439: iteration 35/35
# Epoch 439 --> loss:0.2335, acc:90.06%, val_loss:1.2115, val_acc:65.03%
#  Epoch 440: iteration 35/35
# Epoch 440 --> loss:0.2202, acc:90.58%, val_loss:1.7305, val_acc:43.36%
#  Epoch 441: iteration 35/35
# Epoch 441 --> loss:0.2353, acc:88.32%, val_loss:1.3576, val_acc:58.74%
#  Epoch 442: iteration 35/35
# Epoch 442 --> loss:0.2147, acc:91.11%, val_loss:1.3368, val_acc:56.64%
#  Epoch 443: iteration 35/35
# Epoch 443 --> loss:0.2217, acc:90.41%, val_loss:1.4472, val_acc:56.64%
#  Epoch 444: iteration 35/35
# Epoch 444 --> loss:0.2110, acc:90.67%, val_loss:1.3058, val_acc:58.04%
#  Epoch 445: iteration 35/35
# Epoch 445 --> loss:0.2229, acc:89.80%, val_loss:1.0734, val_acc:59.44%
#  Epoch 446: iteration 35/35
# Epoch 446 --> loss:0.2073, acc:91.46%, val_loss:1.7371, val_acc:39.86%
#  Epoch 447: iteration 35/35
# Epoch 447 --> loss:0.2395, acc:88.67%, val_loss:1.3312, val_acc:54.55%
#  Epoch 448: iteration 35/35
# Epoch 448 --> loss:0.2220, acc:89.54%, val_loss:1.3584, val_acc:57.34%
#  Epoch 449: iteration 35/35
# Epoch 449 --> loss:0.2325, acc:89.63%, val_loss:1.2360, val_acc:60.84%
#  Epoch 450: iteration 35/35
# Epoch 450 --> loss:0.2094, acc:90.58%, val_loss:1.1901, val_acc:61.54%
#  Epoch 451: iteration 35/35
# Epoch 451 --> loss:0.2106, acc:90.50%, val_loss:1.5351, val_acc:53.15%
#  Epoch 452: iteration 35/35
# Epoch 452 --> loss:0.2343, acc:89.97%, val_loss:1.4412, val_acc:56.64%
#  Epoch 453: iteration 35/35
# Epoch 453 --> loss:0.2232, acc:90.41%, val_loss:1.1512, val_acc:58.74%
#  Epoch 454: iteration 35/35
# Epoch 454 --> loss:0.2205, acc:89.63%, val_loss:1.3061, val_acc:57.34%
#  Epoch 455: iteration 35/35
# Epoch 455 --> loss:0.2288, acc:89.80%, val_loss:1.5082, val_acc:48.95%
#  Epoch 456: iteration 35/35
# Epoch 456 --> loss:0.1979, acc:91.46%, val_loss:1.2262, val_acc:57.34%
#  Epoch 457: iteration 35/35
# Epoch 457 --> loss:0.2167, acc:90.41%, val_loss:1.0714, val_acc:65.03%
#  Epoch 458: iteration 35/35
# Epoch 458 --> loss:0.2087, acc:91.19%, val_loss:1.2088, val_acc:60.84%
#  Epoch 459: iteration 35/35
# Epoch 459 --> loss:0.1975, acc:91.37%, val_loss:0.9865, val_acc:62.24%
#  Epoch 460: iteration 35/35
# Epoch 460 --> loss:0.1948, acc:91.89%, val_loss:1.2184, val_acc:58.04%
#  Epoch 461: iteration 35/35
# Epoch 461 --> loss:0.2355, acc:89.36%, val_loss:1.4561, val_acc:55.94%
#  Epoch 462: iteration 35/35
# Epoch 462 --> loss:0.2364, acc:89.28%, val_loss:1.5265, val_acc:51.75%
#  Epoch 463: iteration 35/35
# Epoch 463 --> loss:0.2102, acc:90.93%, val_loss:1.4238, val_acc:55.94%
#  Epoch 464: iteration 35/35
# Epoch 464 --> loss:0.2231, acc:89.97%, val_loss:1.7154, val_acc:43.36%
#  Epoch 465: iteration 35/35
# Epoch 465 --> loss:0.2423, acc:89.10%, val_loss:1.2898, val_acc:56.64%
#  Epoch 466: iteration 35/35
# Epoch 466 --> loss:0.2214, acc:90.15%, val_loss:1.2850, val_acc:60.84%
#  Epoch 467: iteration 35/35
# Epoch 467 --> loss:0.2220, acc:90.15%, val_loss:1.2445, val_acc:60.84%
#  Epoch 468: iteration 35/35
# Epoch 468 --> loss:0.2000, acc:90.67%, val_loss:1.0660, val_acc:63.64%
#  Epoch 469: iteration 35/35
# Epoch 469 --> loss:0.2124, acc:90.50%, val_loss:1.2753, val_acc:60.14%
#  Epoch 470: iteration 35/35
# Epoch 470 --> loss:0.2115, acc:90.58%, val_loss:1.4221, val_acc:60.14%
#  Epoch 471: iteration 35/35
# Epoch 471 --> loss:0.2121, acc:90.41%, val_loss:1.0479, val_acc:58.04%
#  Epoch 472: iteration 35/35
# Epoch 472 --> loss:0.2163, acc:90.24%, val_loss:0.9927, val_acc:59.44%
#  Epoch 473: iteration 35/35
# Epoch 473 --> loss:0.2211, acc:90.67%, val_loss:1.1452, val_acc:55.94%
#  Epoch 474: iteration 35/35
# Epoch 474 --> loss:0.2023, acc:90.58%, val_loss:1.2446, val_acc:63.64%
#  Epoch 475: iteration 35/35
# Epoch 475 --> loss:0.1994, acc:91.28%, val_loss:1.5092, val_acc:56.64%
#  Epoch 476: iteration 35/35
# Epoch 476 --> loss:0.2069, acc:90.58%, val_loss:0.9746, val_acc:64.34%
#  Epoch 477: iteration 35/35
# Epoch 477 --> loss:0.2317, acc:90.41%, val_loss:1.4531, val_acc:49.65%
#  Epoch 478: iteration 35/35
# Epoch 478 --> loss:0.2198, acc:90.85%, val_loss:1.3121, val_acc:60.84%
#  Epoch 479: iteration 35/35
# Epoch 479 --> loss:0.2243, acc:90.41%, val_loss:1.4046, val_acc:54.55%
#  Epoch 480: iteration 35/35
# Epoch 480 --> loss:0.2143, acc:90.85%, val_loss:1.3809, val_acc:58.74%
#  Epoch 481: iteration 35/35
# Epoch 481 --> loss:0.2019, acc:90.58%, val_loss:1.2557, val_acc:61.54%
#  Epoch 482: iteration 35/35
# Epoch 482 --> loss:0.2157, acc:91.11%, val_loss:0.9730, val_acc:62.24%
#  Epoch 483: iteration 35/35
# Epoch 483 --> loss:0.2053, acc:90.58%, val_loss:1.2219, val_acc:57.34%
#  Epoch 484: iteration 35/35
# Epoch 484 --> loss:0.2325, acc:89.71%, val_loss:1.1153, val_acc:65.03%
#  Epoch 485: iteration 35/35
# Epoch 485 --> loss:0.2129, acc:90.24%, val_loss:1.4919, val_acc:53.15%
#  Epoch 486: iteration 35/35
# Epoch 486 --> loss:0.2070, acc:91.19%, val_loss:1.0786, val_acc:62.24%
# ...
#  Epoch 539: iteration 35/35
# Epoch 539 --> loss:0.2278, acc:90.76%, val_loss:1.2681, val_acc:63.64%
#  Epoch 540: iteration 35/35
# Epoch 540 --> loss:0.2144, acc:90.32%, val_loss:1.3370, val_acc:55.24%
#  Epoch 541: iteration 35/35
# Epoch 541 --> loss:0.2084, acc:90.50%, val_loss:0.9162, val_acc:69.23%
#  Epoch 542: iteration 35/35
# Epoch 542 --> loss:0.1734, acc:92.59%, val_loss:1.2291, val_acc:59.44%
#  Epoch 543: iteration 35/35
# Epoch 543 --> loss:0.1724, acc:92.24%, val_loss:1.3204, val_acc:54.55%
#  Epoch 544: iteration 35/35
# Epoch 544 --> loss:0.2029, acc:91.11%, val_loss:1.1947, val_acc:60.84%
#  Epoch 545: iteration 35/35
# Epoch 545 --> loss:0.1934, acc:91.37%, val_loss:1.4244, val_acc:55.24%
#  Epoch 546: iteration 35/35
# Epoch 546 --> loss:0.2063, acc:91.28%, val_loss:1.3843, val_acc:55.24%
#  Epoch 547: iteration 35/35
# Epoch 547 --> loss:0.2050, acc:91.98%, val_loss:1.3298, val_acc:56.64%
#  Epoch 548: iteration 35/35
# Epoch 548 --> loss:0.2190, acc:90.06%, val_loss:1.1089, val_acc:59.44%
#  Epoch 549: iteration 35/35
# Epoch 549 --> loss:0.1921, acc:91.98%, val_loss:1.4870, val_acc:46.85%
#  Epoch 550: iteration 35/35
# Epoch 550 --> loss:0.2034, acc:91.80%, val_loss:1.2440, val_acc:56.64%
#  Epoch 551: iteration 35/35
# Epoch 551 --> loss:0.2176, acc:90.41%, val_loss:1.2115, val_acc:62.94%
#  Epoch 552: iteration 35/35
# Epoch 552 --> loss:0.2221, acc:89.89%, val_loss:1.0177, val_acc:62.24%
#  Epoch 553: iteration 35/35
# Epoch 553 --> loss:0.1766, acc:92.24%, val_loss:1.1417, val_acc:62.24%
#  Epoch 554: iteration 35/35
# Epoch 554 --> loss:0.2183, acc:90.76%, val_loss:1.1761, val_acc:59.44%
#  Epoch 555: iteration 35/35
# Epoch 555 --> loss:0.1943, acc:91.80%, val_loss:1.1464, val_acc:60.14%
#  Epoch 556: iteration 35/35
# Epoch 556 --> loss:0.2195, acc:90.32%, val_loss:1.2842, val_acc:56.64%
#  Epoch 557: iteration 35/35
# Epoch 557 --> loss:0.1967, acc:91.46%, val_loss:1.1481, val_acc:66.43%
#  Epoch 558: iteration 35/35
# Epoch 558 --> loss:0.1629, acc:92.24%, val_loss:1.3743, val_acc:53.85%
#  Epoch 559: iteration 35/35
# Epoch 559 --> loss:0.1754, acc:92.07%, val_loss:1.1431, val_acc:63.64%
#  Epoch 560: iteration 35/35
# Epoch 560 --> loss:0.1894, acc:91.63%, val_loss:1.3628, val_acc:58.04%
#  Epoch 561: iteration 35/35
# Epoch 561 --> loss:0.1912, acc:91.63%, val_loss:1.0978, val_acc:64.34%
#  Epoch 562: iteration 35/35
# Epoch 562 --> loss:0.2036, acc:90.58%, val_loss:1.1174, val_acc:59.44%
#  Epoch 563: iteration 35/35
# Epoch 563 --> loss:0.1951, acc:91.80%, val_loss:1.0974, val_acc:61.54%
#  Epoch 564: iteration 35/35
# Epoch 564 --> loss:0.1798, acc:91.63%, val_loss:1.1637, val_acc:62.24%
#  Epoch 565: iteration 35/35
# Epoch 565 --> loss:0.1964, acc:91.54%, val_loss:1.2898, val_acc:56.64%
#  Epoch 566: iteration 35/35
# Epoch 566 --> loss:0.2246, acc:89.80%, val_loss:1.1403, val_acc:62.94%
#  Epoch 567: iteration 35/35
# Epoch 567 --> loss:0.1957, acc:91.37%, val_loss:1.1517, val_acc:57.34%
#  Epoch 568: iteration 35/35
# Epoch 568 --> loss:0.1737, acc:91.46%, val_loss:1.3076, val_acc:62.24%
#  Epoch 569: iteration 35/35
# Epoch 569 --> loss:0.2007, acc:91.11%, val_loss:1.1139, val_acc:65.03%
#  Epoch 570: iteration 35/35
# Epoch 570 --> loss:0.1999, acc:90.85%, val_loss:1.6242, val_acc:53.15%
#  Epoch 571: iteration 35/35
# Epoch 571 --> loss:0.1945, acc:91.46%, val_loss:1.2298, val_acc:57.34%
#  Epoch 572: iteration 35/35
# Epoch 572 --> loss:0.1772, acc:91.72%, val_loss:1.2455, val_acc:58.74%
#  Epoch 573: iteration 35/35
# Epoch 573 --> loss:0.1948, acc:91.37%, val_loss:1.4309, val_acc:51.05%
#  Epoch 574: iteration 35/35
# Epoch 574 --> loss:0.1886, acc:91.19%, val_loss:1.2124, val_acc:60.84%
#  Epoch 575: iteration 35/35
# Epoch 575 --> loss:0.1859, acc:92.42%, val_loss:0.8569, val_acc:69.23%
#  Epoch 576: iteration 35/35
# Epoch 576 --> loss:0.2497, acc:88.32%, val_loss:1.1493, val_acc:60.14%
#  Epoch 577: iteration 35/35
# Epoch 577 --> loss:0.1980, acc:90.41%, val_loss:1.2604, val_acc:62.94%
#  Epoch 578: iteration 35/35
# Epoch 578 --> loss:0.1769, acc:91.46%, val_loss:1.1674, val_acc:64.34%
#  Epoch 579: iteration 35/35
# Epoch 579 --> loss:0.1846, acc:91.72%, val_loss:1.6301, val_acc:49.65%
#  Epoch 580: iteration 35/35
# Epoch 580 --> loss:0.2118, acc:90.41%, val_loss:1.5416, val_acc:48.95%
#  Epoch 581: iteration 35/35
# Epoch 581 --> loss:0.1934, acc:92.07%, val_loss:1.1568, val_acc:61.54%
#  Epoch 582: iteration 35/35
# Epoch 582 --> loss:0.1965, acc:90.50%, val_loss:1.1832, val_acc:60.14%
#  Epoch 583: iteration 35/35
# Epoch 583 --> loss:0.1906, acc:91.02%, val_loss:0.9910, val_acc:64.34%
#  Epoch 584: iteration 35/35
# Epoch 584 --> loss:0.1978, acc:91.02%, val_loss:1.1298, val_acc:62.24%
#  Epoch 585: iteration 35/35
# Epoch 585 --> loss:0.2025, acc:91.02%, val_loss:1.0421, val_acc:68.53%
#  Epoch 586: iteration 35/35
# Epoch 586 --> loss:0.2186, acc:90.58%, val_loss:1.4100, val_acc:55.94%
#  Epoch 587: iteration 35/35
# Epoch 587 --> loss:0.2506, acc:89.01%, val_loss:1.0409, val_acc:60.84%
#  Epoch 588: iteration 35/35
# Epoch 588 --> loss:0.2053, acc:90.76%, val_loss:1.2224, val_acc:55.24%
#  Epoch 589: iteration 35/35
# Epoch 589 --> loss:0.1954, acc:90.85%, val_loss:1.3096, val_acc:58.04%
#  Epoch 590: iteration 35/35
# Epoch 590 --> loss:0.2102, acc:91.19%, val_loss:1.2195, val_acc:58.04%
#  Epoch 591: iteration 35/35
# Epoch 591 --> loss:0.1804, acc:91.89%, val_loss:1.0747, val_acc:60.14%
#  Epoch 592: iteration 35/35
# Epoch 592 --> loss:0.1545, acc:93.37%, val_loss:1.2542, val_acc:58.04%
#  Epoch 593: iteration 35/35
# Epoch 593 --> loss:0.1748, acc:91.54%, val_loss:1.0171, val_acc:63.64%
#  Epoch 594: iteration 35/35
# Epoch 594 --> loss:0.1713, acc:92.68%, val_loss:1.2422, val_acc:56.64%
#  Epoch 595: iteration 35/35
# Epoch 595 --> loss:0.1768, acc:91.46%, val_loss:1.2925, val_acc:58.74%
#  Epoch 596: iteration 35/35
# Epoch 596 --> loss:0.1931, acc:91.28%, val_loss:1.3839, val_acc:50.35%
#  Epoch 597: iteration 35/35
# Epoch 597 --> loss:0.2215, acc:89.80%, val_loss:1.1952, val_acc:62.24%
#  Epoch 598: iteration 35/35
# Epoch 598 --> loss:0.1718, acc:92.15%, val_loss:1.2989, val_acc:58.74%
#  Epoch 599: iteration 35/35
# Epoch 599 --> loss:0.1677, acc:91.98%, val_loss:1.3821, val_acc:55.94%
#  Epoch 600: iteration 35/35
# Epoch 600 --> loss:0.2009, acc:91.11%, val_loss:0.9887, val_acc:65.73%
#  Epoch 601: iteration 35/35
# Epoch 601 --> loss:0.1814, acc:92.15%, val_loss:1.1835, val_acc:56.64%
#  Epoch 602: iteration 35/35
# Epoch 602 --> loss:0.1901, acc:91.46%, val_loss:1.0885, val_acc:57.34%
#  Epoch 603: iteration 35/35
# Epoch 603 --> loss:0.1907, acc:91.54%, val_loss:1.0443, val_acc:64.34%
#  Epoch 604: iteration 35/35
# Epoch 604 --> loss:0.1694, acc:91.63%, val_loss:1.3156, val_acc:58.74%
#  Epoch 605: iteration 35/35
# Epoch 605 --> loss:0.2030, acc:90.93%, val_loss:1.0996, val_acc:63.64%
#  Epoch 606: iteration 35/35
# Epoch 606 --> loss:0.1689, acc:92.33%, val_loss:1.2092, val_acc:58.04%
#  Epoch 607: iteration 35/35
# Epoch 607 --> loss:0.2075, acc:91.98%, val_loss:1.2182, val_acc:59.44%
#  Epoch 608: iteration 35/35
# Epoch 608 --> loss:0.2066, acc:90.15%, val_loss:1.3162, val_acc:60.84%
#  Epoch 609: iteration 35/35
# Epoch 609 --> loss:0.1980, acc:91.19%, val_loss:1.1879, val_acc:62.94%
#  Epoch 610: iteration 35/35
# Epoch 610 --> loss:0.1610, acc:92.33%, val_loss:1.4146, val_acc:53.15%
#  Epoch 611: iteration 35/35
# Epoch 611 --> loss:0.1695, acc:92.24%, val_loss:1.3244, val_acc:56.64%
#  Epoch 612: iteration 35/35
# Epoch 612 --> loss:0.1672, acc:92.50%, val_loss:1.3704, val_acc:57.34%
#  Epoch 613: iteration 35/35
# Epoch 613 --> loss:0.1877, acc:90.93%, val_loss:1.3494, val_acc:54.55%
#  Epoch 614: iteration 35/35
# Epoch 614 --> loss:0.1809, acc:91.63%, val_loss:1.0912, val_acc:59.44%
#  Epoch 615: iteration 35/35
# Epoch 615 --> loss:0.2161, acc:90.15%, val_loss:1.3100, val_acc:60.84%
#  Epoch 616: iteration 35/35
# Epoch 616 --> loss:0.1903, acc:91.63%, val_loss:1.2737, val_acc:55.94%
#  Epoch 617: iteration 35/35
# Epoch 617 --> loss:0.1872, acc:91.72%, val_loss:1.1243, val_acc:57.34%
#  Epoch 618: iteration 35/35
# Epoch 618 --> loss:0.1984, acc:90.67%, val_loss:1.1875, val_acc:59.44%
#  Epoch 619: iteration 35/35
# Epoch 619 --> loss:0.2199, acc:90.24%, val_loss:1.0195, val_acc:61.54%
#  Epoch 620: iteration 35/35
# Epoch 620 --> loss:0.1983, acc:90.58%, val_loss:1.3653, val_acc:54.55%
#  Epoch 621: iteration 35/35
# Epoch 621 --> loss:0.1946, acc:91.28%, val_loss:1.2953, val_acc:57.34%
#  Epoch 622: iteration 35/35
# Epoch 622 --> loss:0.1821, acc:91.46%, val_loss:1.4434, val_acc:53.15%
#  Epoch 623: iteration 35/35
# Epoch 623 --> loss:0.1969, acc:90.93%, val_loss:1.1998, val_acc:60.14%
#  Epoch 624: iteration 35/35
# Epoch 624 --> loss:0.2025, acc:90.93%, val_loss:1.4145, val_acc:54.55%
#  Epoch 625: iteration 35/35
# Epoch 625 --> loss:0.2035, acc:91.19%, val_loss:1.1901, val_acc:61.54%
#  Epoch 626: iteration 35/35
# Epoch 626 --> loss:0.1797, acc:91.19%, val_loss:1.1035, val_acc:60.84%
#  Epoch 627: iteration 35/35
# Epoch 627 --> loss:0.1809, acc:91.98%, val_loss:1.2349, val_acc:60.14%
#  Epoch 628: iteration 35/35
# Epoch 628 --> loss:0.1556, acc:92.94%, val_loss:1.1113, val_acc:64.34%
#  Epoch 629: iteration 35/35
# Epoch 629 --> loss:0.1750, acc:92.42%, val_loss:1.6137, val_acc:50.35%
#  Epoch 630: iteration 35/35
# Epoch 630 --> loss:0.2000, acc:91.02%, val_loss:1.5106, val_acc:50.35%
#  Epoch 631: iteration 35/35
# Epoch 631 --> loss:0.1887, acc:92.07%, val_loss:1.3874, val_acc:54.55%
#  Epoch 632: iteration 35/35
# Epoch 632 --> loss:0.1978, acc:91.89%, val_loss:1.2704, val_acc:59.44%
#  Epoch 633: iteration 35/35
# Epoch 633 --> loss:0.1877, acc:92.33%, val_loss:1.4288, val_acc:56.64%
#  Epoch 634: iteration 35/35
# Epoch 634 --> loss:0.2030, acc:91.37%, val_loss:1.3501, val_acc:55.24%
#  Epoch 635: iteration 35/35
# Epoch 635 --> loss:0.1591, acc:92.94%, val_loss:1.4230, val_acc:55.24%
#  Epoch 636: iteration 35/35
# Epoch 636 --> loss:0.1640, acc:92.94%, val_loss:1.4064, val_acc:58.74%
#  Epoch 637: iteration 35/35
# Epoch 637 --> loss:0.1823, acc:91.89%, val_loss:1.4134, val_acc:52.45%
#  Epoch 638: iteration 35/35
# Epoch 638 --> loss:0.1945, acc:91.02%, val_loss:1.1166, val_acc:64.34%
#  Epoch 639: iteration 35/35
# Epoch 639 --> loss:0.1656, acc:91.72%, val_loss:1.1554, val_acc:61.54%
#  Epoch 640: iteration 35/35
# Epoch 640 --> loss:0.1871, acc:91.02%, val_loss:1.1816, val_acc:62.94%
#  Epoch 641: iteration 35/35
# Epoch 641 --> loss:0.1779, acc:92.33%, val_loss:1.3065, val_acc:54.55%
#  Epoch 642: iteration 35/35
# Epoch 642 --> loss:0.1901, acc:91.37%, val_loss:1.4185, val_acc:56.64%
#  Epoch 643: iteration 35/35
# Epoch 643 --> loss:0.1767, acc:92.33%, val_loss:1.1254, val_acc:62.24%
#  Epoch 644: iteration 35/35
# Epoch 644 --> loss:0.1842, acc:91.89%, val_loss:1.0320, val_acc:65.03%
#  Epoch 645: iteration 35/35
# Epoch 645 --> loss:0.1982, acc:90.85%, val_loss:1.3941, val_acc:54.55%
#  Epoch 646: iteration 35/35
# Epoch 646 --> loss:0.1833, acc:91.11%, val_loss:1.4600, val_acc:54.55%
#  Epoch 647: iteration 35/35
# Epoch 647 --> loss:0.1449, acc:93.20%, val_loss:1.3179, val_acc:56.64%
#  Epoch 648: iteration 35/35
# Epoch 648 --> loss:0.1340, acc:93.72%, val_loss:1.3032, val_acc:55.24%
#  Epoch 649: iteration 35/35
# Epoch 649 --> loss:0.1896, acc:90.32%, val_loss:1.1629, val_acc:58.74%
#  Epoch 650: iteration 35/35
# Epoch 650 --> loss:0.1911, acc:90.41%, val_loss:1.1880, val_acc:58.04%
#  Epoch 651: iteration 35/35
# Epoch 651 --> loss:0.1642, acc:92.50%, val_loss:0.9675, val_acc:62.94%
#  Epoch 652: iteration 35/35
# Epoch 652 --> loss:0.1768, acc:91.02%, val_loss:1.2270, val_acc:57.34%
#  Epoch 653: iteration 35/35
# Epoch 653 --> loss:0.1848, acc:92.15%, val_loss:0.9911, val_acc:65.03%
#  Epoch 654: iteration 35/35
# Epoch 654 --> loss:0.1938, acc:91.11%, val_loss:0.9504, val_acc:64.34%
#  Epoch 655: iteration 35/35
# Epoch 655 --> loss:0.2038, acc:90.32%, val_loss:1.0278, val_acc:63.64%
#  Epoch 656: iteration 35/35
# Epoch 656 --> loss:0.1802, acc:91.02%, val_loss:1.2326, val_acc:60.84%
#  Epoch 657: iteration 35/35
# Epoch 657 --> loss:0.1937, acc:91.11%, val_loss:1.0749, val_acc:67.83%
#  Epoch 658: iteration 35/35
# Epoch 658 --> loss:0.2086, acc:91.46%, val_loss:1.2806, val_acc:54.55%
#  Epoch 659: iteration 35/35
# Epoch 659 --> loss:0.1851, acc:91.72%, val_loss:1.1994, val_acc:59.44%
#  Epoch 660: iteration 35/35
# Epoch 660 --> loss:0.1564, acc:92.94%, val_loss:1.2100, val_acc:60.14%
#  Epoch 661: iteration 35/35
# Epoch 661 --> loss:0.1885, acc:90.93%, val_loss:1.2266, val_acc:57.34%
#  Epoch 662: iteration 35/35
# Epoch 662 --> loss:0.1837, acc:92.15%, val_loss:1.3999, val_acc:57.34%
#  Epoch 663: iteration 35/35
# Epoch 663 --> loss:0.1973, acc:91.02%, val_loss:1.3879, val_acc:56.64%
#  Epoch 664: iteration 35/35
# Epoch 664 --> loss:0.1773, acc:91.98%, val_loss:1.3095, val_acc:58.04%
#  Epoch 665: iteration 35/35
# Epoch 665 --> loss:0.1832, acc:91.98%, val_loss:1.1446, val_acc:62.94%
#  Epoch 666: iteration 35/35
# Epoch 666 --> loss:0.1904, acc:91.28%, val_loss:1.2486, val_acc:56.64%
#  Epoch 667: iteration 35/35
# Epoch 667 --> loss:0.1930, acc:91.54%, val_loss:1.1319, val_acc:63.64%
#  Epoch 668: iteration 35/35
# Epoch 668 --> loss:0.1902, acc:91.02%, val_loss:1.2950, val_acc:62.24%
#  Epoch 669: iteration 35/35
# Epoch 669 --> loss:0.1612, acc:93.55%, val_loss:1.0775, val_acc:62.24%
#  Epoch 670: iteration 35/35
# Epoch 670 --> loss:0.2032, acc:90.32%, val_loss:1.4630, val_acc:55.94%
#  Epoch 671: iteration 35/35
# Epoch 671 --> loss:0.1787, acc:92.07%, val_loss:1.2221, val_acc:62.94%
#  Epoch 672: iteration 35/35
# Epoch 672 --> loss:0.1621, acc:91.72%, val_loss:1.0442, val_acc:65.03%
#  Epoch 673: iteration 35/35
# Epoch 673 --> loss:0.1785, acc:91.89%, val_loss:1.2308, val_acc:55.94%
#  Epoch 674: iteration 35/35
# Epoch 674 --> loss:0.1968, acc:91.11%, val_loss:1.5950, val_acc:53.85%
#  Epoch 675: iteration 35/35
# Epoch 675 --> loss:0.1572, acc:92.94%, val_loss:1.2631, val_acc:58.74%
#  Epoch 676: iteration 35/35
# Epoch 676 --> loss:0.1742, acc:91.54%, val_loss:1.5052, val_acc:59.44%
#  Epoch 677: iteration 35/35
# Epoch 677 --> loss:0.1865, acc:91.80%, val_loss:1.5132, val_acc:52.45%
#  Epoch 678: iteration 35/35
# Epoch 678 --> loss:0.1896, acc:91.19%, val_loss:0.9440, val_acc:66.43%
#  Epoch 679: iteration 35/35
# Epoch 679 --> loss:0.1918, acc:90.85%, val_loss:0.9911, val_acc:63.64%
#  Epoch 680: iteration 35/35
# Epoch 680 --> loss:0.1890, acc:91.63%, val_loss:1.3555, val_acc:60.14%
#  Epoch 681: iteration 35/35
# Epoch 681 --> loss:0.1885, acc:91.80%, val_loss:1.3618, val_acc:54.55%
#  Epoch 682: iteration 35/35
# Epoch 682 --> loss:0.1889, acc:91.54%, val_loss:1.6422, val_acc:53.15%
#  Epoch 683: iteration 35/35
# Epoch 683 --> loss:0.1601, acc:93.11%, val_loss:1.1944, val_acc:58.74%
#  Epoch 684: iteration 35/35
# Epoch 684 --> loss:0.1805, acc:91.89%, val_loss:1.1963, val_acc:57.34%
#  Epoch 685: iteration 35/35
# Epoch 685 --> loss:0.2043, acc:90.32%, val_loss:1.4608, val_acc:50.35%
#  Epoch 686: iteration 35/35
# Epoch 686 --> loss:0.1880, acc:91.72%, val_loss:1.1401, val_acc:60.14%
#  Epoch 687: iteration 35/35
# Epoch 687 --> loss:0.1821, acc:92.15%, val_loss:1.1292, val_acc:61.54%
#  Epoch 688: iteration 35/35
# Epoch 688 --> loss:0.2065, acc:90.67%, val_loss:1.1585, val_acc:60.84%
#  Epoch 689: iteration 35/35
# Epoch 689 --> loss:0.1704, acc:92.07%, val_loss:1.1801, val_acc:60.14%
#  Epoch 690: iteration 35/35
# Epoch 690 --> loss:0.1491, acc:92.94%, val_loss:1.1158, val_acc:59.44%
#  Epoch 691: iteration 35/35
# Epoch 691 --> loss:0.1717, acc:92.24%, val_loss:1.2258, val_acc:61.54%
#  Epoch 692: iteration 35/35
# Epoch 692 --> loss:0.1688, acc:92.24%, val_loss:1.1007, val_acc:65.03%
#  Epoch 693: iteration 35/35
# Epoch 693 --> loss:0.1801, acc:91.46%, val_loss:1.1244, val_acc:59.44%
#  Epoch 694: iteration 35/35
# Epoch 694 --> loss:0.1872, acc:91.02%, val_loss:1.3596, val_acc:57.34%
#  Epoch 695: iteration 35/35
# Epoch 695 --> loss:0.1861, acc:91.19%, val_loss:1.0376, val_acc:64.34%
#  Epoch 696: iteration 35/35
# Epoch 696 --> loss:0.2078, acc:91.46%, val_loss:1.0189, val_acc:64.34%
#  Epoch 697: iteration 35/35
# Epoch 697 --> loss:0.1885, acc:90.93%, val_loss:1.3158, val_acc:58.04%
#  Epoch 698: iteration 35/35
# Epoch 698 --> loss:0.1887, acc:92.24%, val_loss:1.3328, val_acc:55.94%
#  Epoch 699: iteration 35/35
# Epoch 699 --> loss:0.1761, acc:91.89%, val_loss:1.2890, val_acc:58.74%

# %% [markdown]
# ### Loss Curve

# %%
plt.plot(losses,'b')
plt.plot(val_losses,'r')
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(['train loss','val loss'])

# %% [markdown]
# ### Evaluate the Model on test set

# %%
# Convert 4D test set and label set array to tensor and move to GPU
X_test_tensor = torch.tensor(X_test,device=device).float()
Y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)

# Get the model's performance metrics using the validation function initialized before
test_loss, test_acc, predictions = validate(X_test_tensor,Y_test_tensor)
print(f'Test loss is {test_loss:.3f}')
print(f'Test accuracy is {test_acc:.2f}%')
# Out:
# Test loss is 1.277
# Test accuracy is 57.33%

# %%
print(type(predictions))
print(len(predictions))
print(predictions)
# Out:
# <class 'torch.Tensor'>
# 150
# tensor([7, 7, 0, 0, 0, 2, 0, 0, 6, 6, 7, 0, 0, 0, 0, 6, 0, 0, 0, 0, 3, 2, 1, 0,
#         7, 2, 2, 7, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 6, 5, 6, 5, 6, 0, 3, 6, 0, 2, 4, 7, 5, 7, 5, 5, 7, 0, 3, 6, 2, 2,
#         2, 7, 6, 6, 4, 4, 7, 7, 0, 4, 2, 2, 6, 2, 2, 2, 4, 2, 5, 5, 0, 5, 5, 5,
#         6, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5, 5, 7, 0, 6, 4, 6, 6, 6, 6, 6, 6, 6, 6,
#         0, 6, 6, 6, 6, 6, 6, 0, 6, 6, 2, 7, 2, 7, 2, 7, 7, 7, 7, 7, 7, 7, 4, 7,
#         7, 2, 7, 7, 7, 7], device='cuda:0')

# %% [markdown]
# ### confusion matrix

# %%
# build confusion matrix and normalized confusion matrix
predictions = predictions.cpu().numpy()
conf_matrix = confusion_matrix(y_test, predictions)
conf_matrix_norm = confusion_matrix(y_test, predictions,normalize='true')

# set labels for matrix axes from emotions
emotion_names = [emotion for emotion in EMOTIONS.values()]

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(15,5))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

plt.show()

# %%
SAVE_PATH = os.path.join(os.getcwd(),'models')
os.makedirs('models',exist_ok=True)
torch.save(model.state_dict(),os.path.join(SAVE_PATH,'cnn_base_model.pt'))
print('Model is saved to {}'.format(os.path.join(SAVE_PATH,'cnn_base_model.pt')))
# Out:
# Model is saved to C:\Users\janakishyama\Desktop\ESR06\Implementation\my_model\models\cnn_base_model.pt
